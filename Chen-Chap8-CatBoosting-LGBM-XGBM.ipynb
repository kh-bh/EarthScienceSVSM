# %% [markdown]
# # K-Fold CV for Boosting Methods Using SKLearn

# %%
#Importing required libraries
from sklearn.datasets import load_breast_cancer
import pandas as pd
import numpy as np

from sklearn.model_selection import KFold 
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import LeaveOneOut

from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix, classification_report

# %%
import xgboost as xgb
from sklearn import metrics
from lightgbm import LGBMClassifier

import lightgbm
import lightgbm as lgb
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.dpi'] = 70 #display 70 dpi in Jupyter Notebook, may consider100 dpi 
plt.rcParams['savefig.dpi'] = 300 #define 300 dpi for saving figures

import seaborn as sns
## here are some settings 
sns.set_style('whitegrid')
sns.set(rc={"figure.dpi":70, 'savefig.dpi':300}) #defining dpi setting
sns.set_context('notebook')
sns.set_style("ticks")
from IPython.display import set_matplotlib_formats

# %% [markdown]
# ### To load sklearn dataset
# sklearn.datasets.load_breast_cancer(*, return_X_y=False, as_frame=False)[source]¶
#
# Load and return the breast cancer wisconsin dataset (classification).

# %%
data = load_breast_cancer(as_frame = True); 
df = data.frame; 
print(df.shape)
# Out:
# (569, 31)

# %%
df.head(5)
# df.info()
# df.describe()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                 0.07871  ...          17.33           184.60      2019.0
# 1                 0.05667  ...          23.41           158.80      1956.0
# 2                 0.05999  ...          25.53           152.50      1709.0
# 3                 0.09744  ...          26.50            98.87       567.7
# 4                 0.05883  ...          16.67           152.20      1575.0
#
#    worst smoothness  worst compactness  worst concavity  worst concave points  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    worst symmetry  worst fractal dimension  target
# 0          0.4601                  0.11890       0
# 1          0.2750                  0.08902       0
# 2          0.3613                  0.08758       0
# 3          0.6638                  0.17300       0
# 4          0.2364                  0.07678       0
#
# [5 rows x 31 columns]

# %% [markdown]
# # Extreme Gradient Boosting

# %%
# https://xgboost.readthedocs.io/en/latest/python/python_api.html#module-xgboost.sklearn

# check xgboost version
import xgboost
import xgboost as xgb
from xgboost import XGBClassifier
print(xgboost.__version__)
from matplotlib import pyplot
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve, auc
import sklearn.metrics as metrics

#Implementing cross validation 
kf = KFold(n_splits=5, random_state=1, shuffle=True)
# Create the Extreme GBM
model = XGBClassifier(n_estimators=100, learning_rate = 0.1,use_label_encoder =False,verbose=None,
                max_depth = 5, eval_metric='logloss')
    
from time import time
import timeit #imports timeit module
start_time = timeit.default_timer() #defines start time so computational time can be calculated

acc_score = [];
Truth = [];
Output = [];
 
for train_index , test_index in kf.split(df):
    
    X_train , X_test = df.iloc[train_index,:-1], df.iloc[test_index,:-1]
    y_train , y_test = df.iloc[train_index,-1], df.iloc[test_index,-1]
    
    
    model.fit(X_train,y_train)

    pred_values = model.predict(X_test)
    pred_prob = model.predict_proba(X_test)[:, 1]
     
    acc = accuracy_score(y_test, pred_values)
    acc_score.append(acc)
    
    Truth.extend(y_test.values.reshape(y_test.shape[0])); ## it is a list
    Output.extend(pred_values); ## it is a list 
    
    #print(model.feature_importances_)
    Importance = pd.DataFrame({'Importance':(model.feature_importances_*100)[0:10]}, 
                          index = (X_train.columns)[0:10])
    Importance.sort_values(by = 'Importance', 
                       axis = 0, 
                       ascending = True).plot(kind = 'barh', 
                                              color = 'r')
    plt.xlabel('Variable Importance')
    plt.gca().legend_ = None
    plt.show()
    #plt.savefig('plot1.png')
    
    ##################################################
    #https://scikit-learn.org/stable/modules/generated/sklearn.metrics.roc_auc_score.html
    #Compute Area Under the Receiver Operating Characteristic Curve (ROC AUC) from prediction scores.
    print("roc_auc_score", roc_auc_score(y_test, pred_prob))
    
    # calculate the fpr and tpr for all thresholds of the classification
    #fpr, tpr, threshold = metrics.roc_curve(y_test, pred_prob)
    #roc_auc = metrics.auc(fpr, tpr)
    # method I: plt
    #import matplotlib.pyplot as plt
    #plt.title('Receiver Operating Characteristic')
    #plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
    #plt.legend(loc = 'lower right')
    #plt.plot([0, 1], [0, 1],'r--')
    #plt.xlim([-0.05, 1])
    #plt.ylim([0, 1.05])
    #plt.ylabel('True Positive Rate')
    #plt.xlabel('False Positive Rate')
    #plt.show()
    ##################################################
    
elapsed = timeit.default_timer() - start_time #gives total computation time
print("---Run time is %s seconds ---" % elapsed) #prints computation time
print()

print('Accuracy of each fold: \n {}'.format(acc_score))
print()
print('Avg accuracy : \n{}'.format(np.mean(acc_score))); 
print()
print('Std of accuracy : \n{}'.format(np.std(acc_score)))
# Out:
# 1.3.3
# roc_auc_score 0.9871031746031745
# roc_auc_score 0.9930747922437674
# roc_auc_score 0.9911082883455066
# roc_auc_score 0.9983108108108107
# roc_auc_score 0.9937908496732027
# ---Run time is 2.0185195439999006 seconds ---
#
# Accuracy of each fold:
#  [0.956140350877193, 0.956140350877193, 0.9473684210526315, 0.9736842105263158, 0.9823008849557522]
#
# Avg accuracy :
# 0.9631268436578171
#
# Std of accuracy :
# 0.012845636618261042

# %% [markdown]
# # Reference:
#
# https://lightgbm.readthedocs.io/en/latest/pythonapi/lightgbm.LGBMClassifier.html
#
# max_depth (int, optional (default=-1)) – Maximum tree depth for base learners, <=0 means no limit.
#
# learning_rate (float, optional (default=0.1)) – Boosting learning rate. You can use callbacks parameter of fit method to shrink/adapt learning rate in training using reset_parameter callback. Note, that this will ignore the learning_rate argument in training.
#
# n_estimators (int, optional (default=100)) – Number of boosted trees to fit.
#
# eval_metric (str, callable, list or None, optional (default=None)) – If str, it should be a built-in evaluation metric to use. If callable, it should be a custom evaluation metric, see note below for more details. If list, it can be a list of built-in metrics, a list of custom evaluation metrics, or a mix of both. In either case, the metric from the model parameters will be evaluated and used as well.
# Default: ‘l2’ for LGBMRegressor, **‘logloss’ for LGBMClassifier**, ‘ndcg’ for LGBMRanker.

# %%
# https://lightgbm.readthedocs.io/en/latest/pythonapi/lightgbm.LGBMClassifier.html
import lightgbm

#Implementing cross validation 
kf = KFold(n_splits=5, random_state=1, shuffle=True)
model = lightgbm.LGBMClassifier(learning_rate=0.09,max_depth=-5,random_state=42)

from time import time
import timeit #imports timeit module
start_time = timeit.default_timer() #defines start time so computational time can be calculated

acc_score = [];
Truth = [];
Output = [];
 
for train_index , test_index in kf.split(df):
    
    X_train , X_test = df.iloc[train_index,:-1], df.iloc[test_index,:-1]
    y_train , y_test = df.iloc[train_index,-1], df.iloc[test_index,-1]
    
    # Create the LightGBM data containers
    model.fit(X_train,y_train,eval_set=[(X_test,y_test),(X_train,y_train)],
          eval_metric='logloss')

    pred_values = model.predict(X_test)
     
    acc = accuracy_score(y_test, pred_values)
    acc_score.append(acc)
    
    Truth.extend(y_test.values.reshape(y_test.shape[0])); ## it is a list
    Output.extend(pred_values); ## it is a list  
    
    #print(model.feature_importances_)
    Importance = pd.DataFrame({'Importance':(model.feature_importances_*100)[0:10]}, 
                          index = (X_train.columns)[0:10])
    Importance.sort_values(by = 'Importance', 
                       axis = 0, 
                       ascending = True).plot(kind = 'barh', 
                                              color = 'r')
    plt.xlabel('Variable Importance')
    plt.gca().legend_ = None
    #plt.savefig('plot1.png')


elapsed = timeit.default_timer() - start_time #gives total computation time
print("---Run time is %s seconds ---" % elapsed) #prints computation time
print()

print('Accuracy of each fold: \n {}'.format(acc_score))
print()
print('Avg accuracy : \n{}'.format(np.mean(acc_score))); 
print()
print('Std of accuracy : \n{}'.format(np.std(acc_score)))
# Out:
# [1]	training's binary_logloss: 0.586917	valid_0's binary_logloss: 0.599831
# [2]	training's binary_logloss: 0.526563	valid_0's binary_logloss: 0.552581
# [3]	training's binary_logloss: 0.473859	valid_0's binary_logloss: 0.506398
# [4]	training's binary_logloss: 0.431731	valid_0's binary_logloss: 0.469811
# [5]	training's binary_logloss: 0.394351	valid_0's binary_logloss: 0.441414
# [6]	training's binary_logloss: 0.360195	valid_0's binary_logloss: 0.41253
# [7]	training's binary_logloss: 0.331338	valid_0's binary_logloss: 0.39399
# [8]	training's binary_logloss: 0.304714	valid_0's binary_logloss: 0.368247
# [9]	training's binary_logloss: 0.281358	valid_0's binary_logloss: 0.34715
# [10]	training's binary_logloss: 0.258696	valid_0's binary_logloss: 0.32717
# [11]	training's binary_logloss: 0.239231	valid_0's binary_logloss: 0.310101
# [12]	training's binary_logloss: 0.221615	valid_0's binary_logloss: 0.298585
# [13]	training's binary_logloss: 0.204932	valid_0's binary_logloss: 0.283397
# [14]	training's binary_logloss: 0.191052	valid_0's binary_logloss: 0.269987
# [15]	training's binary_logloss: 0.178246	valid_0's binary_logloss: 0.263179
# [16]	training's binary_logloss: 0.16637	valid_0's binary_logloss: 0.252764
# [17]	training's binary_logloss: 0.155618	valid_0's binary_logloss: 0.241292
# [18]	training's binary_logloss: 0.145791	valid_0's binary_logloss: 0.23618
# [19]	training's binary_logloss: 0.136354	valid_0's binary_logloss: 0.226288
# [20]	training's binary_logloss: 0.128035	valid_0's binary_logloss: 0.218912
# [21]	training's binary_logloss: 0.120286	valid_0's binary_logloss: 0.21543
# [22]	training's binary_logloss: 0.113188	valid_0's binary_logloss: 0.208857
# [23]	training's binary_logloss: 0.106149	valid_0's binary_logloss: 0.206184
# [24]	training's binary_logloss: 0.0996686	valid_0's binary_logloss: 0.200369
# [25]	training's binary_logloss: 0.0935899	valid_0's binary_logloss: 0.195543
# [26]	training's binary_logloss: 0.088121	valid_0's binary_logloss: 0.190555
# [27]	training's binary_logloss: 0.0828487	valid_0's binary_logloss: 0.189709
# [28]	training's binary_logloss: 0.0784365	valid_0's binary_logloss: 0.185232
# [29]	training's binary_logloss: 0.0734301	valid_0's binary_logloss: 0.181538
# [30]	training's binary_logloss: 0.0691928	valid_0's binary_logloss: 0.180966
# [31]	training's binary_logloss: 0.0653057	valid_0's binary_logloss: 0.177832
# [32]	training's binary_logloss: 0.0611477	valid_0's binary_logloss: 0.17593
# [33]	training's binary_logloss: 0.0570957	valid_0's binary_logloss: 0.172304
# [34]	training's binary_logloss: 0.053479	valid_0's binary_logloss: 0.169801
# [35]	training's binary_logloss: 0.0500265	valid_0's binary_logloss: 0.168073
# [36]	training's binary_logloss: 0.0466701	valid_0's binary_logloss: 0.164488
# [37]	training's binary_logloss: 0.0436464	valid_0's binary_logloss: 0.163836
# [38]	training's binary_logloss: 0.0412853	valid_0's binary_logloss: 0.16274
# [39]	training's binary_logloss: 0.0387219	valid_0's binary_logloss: 0.161129
# [40]	training's binary_logloss: 0.0363872	valid_0's binary_logloss: 0.15957
# [41]	training's binary_logloss: 0.0340034	valid_0's binary_logloss: 0.158
# [42]	training's binary_logloss: 0.0319374	valid_0's binary_logloss: 0.157299
# [43]	training's binary_logloss: 0.0300826	valid_0's binary_logloss: 0.156417
# [44]	training's binary_logloss: 0.0282983	valid_0's binary_logloss: 0.154887
# [45]	training's binary_logloss: 0.02643	valid_0's binary_logloss: 0.155499
# [46]	training's binary_logloss: 0.0248147	valid_0's binary_logloss: 0.155799
# [47]	training's binary_logloss: 0.0231941	valid_0's binary_logloss: 0.155615
# [48]	training's binary_logloss: 0.0217228	valid_0's binary_logloss: 0.156629
# [49]	training's binary_logloss: 0.020448	valid_0's binary_logloss: 0.157831
# [50]	training's binary_logloss: 0.0191851	valid_0's binary_logloss: 0.158937
# [51]	training's binary_logloss: 0.0180249	valid_0's binary_logloss: 0.158172
# [52]	training's binary_logloss: 0.0169535	valid_0's binary_logloss: 0.159655
# [53]	training's binary_logloss: 0.0158653	valid_0's binary_logloss: 0.159513
# [54]	training's binary_logloss: 0.0146429	valid_0's binary_logloss: 0.157607
# [55]	training's binary_logloss: 0.0138628	valid_0's binary_logloss: 0.157688
# [56]	training's binary_logloss: 0.0130186	valid_0's binary_logloss: 0.15912
# [57]	training's binary_logloss: 0.0121146	valid_0's binary_logloss: 0.158932
# [58]	training's binary_logloss: 0.0112672	valid_0's binary_logloss: 0.157283
# [59]	training's binary_logloss: 0.0105846	valid_0's binary_logloss: 0.157407
# [60]	training's binary_logloss: 0.00995727	valid_0's binary_logloss: 0.15932
# [61]	training's binary_logloss: 0.009357	valid_0's binary_logloss: 0.161017
# [62]	training's binary_logloss: 0.00880821	valid_0's binary_logloss: 0.162148
# [63]	training's binary_logloss: 0.00829951	valid_0's binary_logloss: 0.162763
# [64]	training's binary_logloss: 0.00774661	valid_0's binary_logloss: 0.161803
# [65]	training's binary_logloss: 0.007325	valid_0's binary_logloss: 0.16242
# [66]	training's binary_logloss: 0.0069353	valid_0's binary_logloss: 0.16428
# [67]	training's binary_logloss: 0.00656297	valid_0's binary_logloss: 0.165446
# [68]	training's binary_logloss: 0.00619356	valid_0's binary_logloss: 0.166534
# [69]	training's binary_logloss: 0.00584174	valid_0's binary_logloss: 0.168543
# [70]	training's binary_logloss: 0.00550558	valid_0's binary_logloss: 0.169833
# [71]	training's binary_logloss: 0.00520051	valid_0's binary_logloss: 0.170797
# [72]	training's binary_logloss: 0.004896	valid_0's binary_logloss: 0.17164
# [73]	training's binary_logloss: 0.00461362	valid_0's binary_logloss: 0.171827
# [74]	training's binary_logloss: 0.00433539	valid_0's binary_logloss: 0.172106
# [75]	training's binary_logloss: 0.00410521	valid_0's binary_logloss: 0.173898
# [76]	training's binary_logloss: 0.00381362	valid_0's binary_logloss: 0.172476
# [77]	training's binary_logloss: 0.00351358	valid_0's binary_logloss: 0.171525
# [78]	training's binary_logloss: 0.00324099	valid_0's binary_logloss: 0.170663
# [79]	training's binary_logloss: 0.00302846	valid_0's binary_logloss: 0.17119
# [80]	training's binary_logloss: 0.00287028	valid_0's binary_logloss: 0.171162
# [81]	training's binary_logloss: 0.0027147	valid_0's binary_logloss: 0.17196
# [82]	training's binary_logloss: 0.00256309	valid_0's binary_logloss: 0.1742
# [83]	training's binary_logloss: 0.00243218	valid_0's binary_logloss: 0.17471
# [84]	training's binary_logloss: 0.00230251	valid_0's binary_logloss: 0.176013
# [85]	training's binary_logloss: 0.0021931	valid_0's binary_logloss: 0.177313
# [86]	training's binary_logloss: 0.00205542	valid_0's binary_logloss: 0.177384
# [87]	training's binary_logloss: 0.00192602	valid_0's binary_logloss: 0.179628
# [88]	training's binary_logloss: 0.00179905	valid_0's binary_logloss: 0.180684
# [89]	training's binary_logloss: 0.00169268	valid_0's binary_logloss: 0.181356
# [90]	training's binary_logloss: 0.00158426	valid_0's binary_logloss: 0.180104
# [91]	training's binary_logloss: 0.00148674	valid_0's binary_logloss: 0.182477
# [92]	training's binary_logloss: 0.00140979	valid_0's binary_logloss: 0.182903
# [93]	training's binary_logloss: 0.00134469	valid_0's binary_logloss: 0.184285
# [94]	training's binary_logloss: 0.00124798	valid_0's binary_logloss: 0.184621
# [95]	training's binary_logloss: 0.00117704	valid_0's binary_logloss: 0.18502
# [96]	training's binary_logloss: 0.00111186	valid_0's binary_logloss: 0.187208
# [97]	training's binary_logloss: 0.00105222	valid_0's binary_logloss: 0.188702
# [98]	training's binary_logloss: 0.00100184	valid_0's binary_logloss: 0.190078
# [99]	training's binary_logloss: 0.000948551	valid_0's binary_logloss: 0.19119
# [100]	training's binary_logloss: 0.000889255	valid_0's binary_logloss: 0.190281
# [1]	training's binary_logloss: 0.594501	valid_0's binary_logloss: 0.578551
# [2]	training's binary_logloss: 0.536455	valid_0's binary_logloss: 0.528005
# [3]	training's binary_logloss: 0.487809	valid_0's binary_logloss: 0.484844
# [4]	training's binary_logloss: 0.445638	valid_0's binary_logloss: 0.450993
# [5]	training's binary_logloss: 0.406981	valid_0's binary_logloss: 0.421098
# [6]	training's binary_logloss: 0.372989	valid_0's binary_logloss: 0.39114
# [7]	training's binary_logloss: 0.343315	valid_0's binary_logloss: 0.366848
# [8]	training's binary_logloss: 0.317209	valid_0's binary_logloss: 0.34692
# [9]	training's binary_logloss: 0.292842	valid_0's binary_logloss: 0.324512
# [10]	training's binary_logloss: 0.271924	valid_0's binary_logloss: 0.309151
# [11]	training's binary_logloss: 0.252375	valid_0's binary_logloss: 0.291142
# [12]	training's binary_logloss: 0.234312	valid_0's binary_logloss: 0.274219
# [13]	training's binary_logloss: 0.218998	valid_0's binary_logloss: 0.264278
# [14]	training's binary_logloss: 0.203267	valid_0's binary_logloss: 0.249482
# [15]	training's binary_logloss: 0.189314	valid_0's binary_logloss: 0.238763
# [16]	training's binary_logloss: 0.177996	valid_0's binary_logloss: 0.229524
# [17]	training's binary_logloss: 0.16792	valid_0's binary_logloss: 0.220858
# [18]	training's binary_logloss: 0.157707	valid_0's binary_logloss: 0.211318
# [19]	training's binary_logloss: 0.148003	valid_0's binary_logloss: 0.206136
# [20]	training's binary_logloss: 0.137254	valid_0's binary_logloss: 0.196144
# [21]	training's binary_logloss: 0.128019	valid_0's binary_logloss: 0.186651
# [22]	training's binary_logloss: 0.118932	valid_0's binary_logloss: 0.180591
# [23]	training's binary_logloss: 0.112182	valid_0's binary_logloss: 0.177083
# [24]	training's binary_logloss: 0.105304	valid_0's binary_logloss: 0.169766
# [25]	training's binary_logloss: 0.0982912	valid_0's binary_logloss: 0.165062
# [26]	training's binary_logloss: 0.0925809	valid_0's binary_logloss: 0.161287
# [27]	training's binary_logloss: 0.0873189	valid_0's binary_logloss: 0.157642
# [28]	training's binary_logloss: 0.0819114	valid_0's binary_logloss: 0.153463
# [29]	training's binary_logloss: 0.0772309	valid_0's binary_logloss: 0.146858
# [30]	training's binary_logloss: 0.0737094	valid_0's binary_logloss: 0.143655
# [31]	training's binary_logloss: 0.0699585	valid_0's binary_logloss: 0.142125
# [32]	training's binary_logloss: 0.0652269	valid_0's binary_logloss: 0.136415
# [33]	training's binary_logloss: 0.0607495	valid_0's binary_logloss: 0.132587
# [34]	training's binary_logloss: 0.0568901	valid_0's binary_logloss: 0.129485
# [35]	training's binary_logloss: 0.0534662	valid_0's binary_logloss: 0.127796
# [36]	training's binary_logloss: 0.0502709	valid_0's binary_logloss: 0.122209
# [37]	training's binary_logloss: 0.0469041	valid_0's binary_logloss: 0.119877
# [38]	training's binary_logloss: 0.0439667	valid_0's binary_logloss: 0.117678
# [39]	training's binary_logloss: 0.0411468	valid_0's binary_logloss: 0.11389
# [40]	training's binary_logloss: 0.0384555	valid_0's binary_logloss: 0.111059
# [41]	training's binary_logloss: 0.035645	valid_0's binary_logloss: 0.107669
# [42]	training's binary_logloss: 0.0334773	valid_0's binary_logloss: 0.10684
# [43]	training's binary_logloss: 0.0315956	valid_0's binary_logloss: 0.104441
# [44]	training's binary_logloss: 0.0294141	valid_0's binary_logloss: 0.1023
# [45]	training's binary_logloss: 0.0272858	valid_0's binary_logloss: 0.0989354
# [46]	training's binary_logloss: 0.0257071	valid_0's binary_logloss: 0.0963028
# [47]	training's binary_logloss: 0.0240108	valid_0's binary_logloss: 0.0936396
# [48]	training's binary_logloss: 0.022445	valid_0's binary_logloss: 0.092898
# [49]	training's binary_logloss: 0.0208174	valid_0's binary_logloss: 0.0919118
# [50]	training's binary_logloss: 0.0194851	valid_0's binary_logloss: 0.0901803
# [51]	training's binary_logloss: 0.0183361	valid_0's binary_logloss: 0.0891283
# [52]	training's binary_logloss: 0.0172472	valid_0's binary_logloss: 0.0876036
# [53]	training's binary_logloss: 0.0162091	valid_0's binary_logloss: 0.0873594
# [54]	training's binary_logloss: 0.0152841	valid_0's binary_logloss: 0.0871101
# [55]	training's binary_logloss: 0.014242	valid_0's binary_logloss: 0.0853751
# [56]	training's binary_logloss: 0.013431	valid_0's binary_logloss: 0.0841578
# [57]	training's binary_logloss: 0.0126765	valid_0's binary_logloss: 0.0843842
# [58]	training's binary_logloss: 0.0117774	valid_0's binary_logloss: 0.0818902
# [59]	training's binary_logloss: 0.0110976	valid_0's binary_logloss: 0.0809597
# [60]	training's binary_logloss: 0.0103671	valid_0's binary_logloss: 0.0800841
# [61]	training's binary_logloss: 0.00984968	valid_0's binary_logloss: 0.0789456
# [62]	training's binary_logloss: 0.00917888	valid_0's binary_logloss: 0.0803999
# [63]	training's binary_logloss: 0.00856539	valid_0's binary_logloss: 0.0804558
# [64]	training's binary_logloss: 0.00801061	valid_0's binary_logloss: 0.0804159
# [65]	training's binary_logloss: 0.00753924	valid_0's binary_logloss: 0.0802869
# [66]	training's binary_logloss: 0.00713291	valid_0's binary_logloss: 0.0802707
# [67]	training's binary_logloss: 0.0067134	valid_0's binary_logloss: 0.0807707
# [68]	training's binary_logloss: 0.00635135	valid_0's binary_logloss: 0.0783599
# [69]	training's binary_logloss: 0.00591062	valid_0's binary_logloss: 0.0801043
# [70]	training's binary_logloss: 0.00557216	valid_0's binary_logloss: 0.0807713
# [71]	training's binary_logloss: 0.00521867	valid_0's binary_logloss: 0.081716
# [72]	training's binary_logloss: 0.00496629	valid_0's binary_logloss: 0.0809807
# [73]	training's binary_logloss: 0.00469014	valid_0's binary_logloss: 0.0815919
# [74]	training's binary_logloss: 0.00442072	valid_0's binary_logloss: 0.0792823
# [75]	training's binary_logloss: 0.0041955	valid_0's binary_logloss: 0.0796248
# [76]	training's binary_logloss: 0.00392945	valid_0's binary_logloss: 0.0793893
# [77]	training's binary_logloss: 0.00375379	valid_0's binary_logloss: 0.0795563
# [78]	training's binary_logloss: 0.0035698	valid_0's binary_logloss: 0.0795173
# [79]	training's binary_logloss: 0.00334338	valid_0's binary_logloss: 0.0781009
# [80]	training's binary_logloss: 0.00313963	valid_0's binary_logloss: 0.0781211
# [81]	training's binary_logloss: 0.00293733	valid_0's binary_logloss: 0.0781293
# [82]	training's binary_logloss: 0.0027996	valid_0's binary_logloss: 0.0782129
# [83]	training's binary_logloss: 0.00261079	valid_0's binary_logloss: 0.0786009
# [84]	training's binary_logloss: 0.00246544	valid_0's binary_logloss: 0.0769314
# [85]	training's binary_logloss: 0.00233513	valid_0's binary_logloss: 0.0778524
# [86]	training's binary_logloss: 0.00219045	valid_0's binary_logloss: 0.0773023
# [87]	training's binary_logloss: 0.00207161	valid_0's binary_logloss: 0.0772182
# [88]	training's binary_logloss: 0.00196658	valid_0's binary_logloss: 0.0782452
# [89]	training's binary_logloss: 0.00186577	valid_0's binary_logloss: 0.0759642
# [90]	training's binary_logloss: 0.00177105	valid_0's binary_logloss: 0.074026
# [91]	training's binary_logloss: 0.00167089	valid_0's binary_logloss: 0.0733036
# [92]	training's binary_logloss: 0.00156036	valid_0's binary_logloss: 0.0744292
# [93]	training's binary_logloss: 0.0014589	valid_0's binary_logloss: 0.0760046
# [94]	training's binary_logloss: 0.00137952	valid_0's binary_logloss: 0.0760981
# [95]	training's binary_logloss: 0.00129946	valid_0's binary_logloss: 0.0763501
# [96]	training's binary_logloss: 0.00123572	valid_0's binary_logloss: 0.0771806
# [97]	training's binary_logloss: 0.00116237	valid_0's binary_logloss: 0.0756367
# [98]	training's binary_logloss: 0.00110186	valid_0's binary_logloss: 0.0745919
# [99]	training's binary_logloss: 0.00103619	valid_0's binary_logloss: 0.0743431
# [100]	training's binary_logloss: 0.000982788	valid_0's binary_logloss: 0.0744834
# [1]	training's binary_logloss: 0.582543	valid_0's binary_logloss: 0.61499
# [2]	training's binary_logloss: 0.523888	valid_0's binary_logloss: 0.559303
# [3]	training's binary_logloss: 0.4747	valid_0's binary_logloss: 0.51437
# [4]	training's binary_logloss: 0.432107	valid_0's binary_logloss: 0.46921
# [5]	training's binary_logloss: 0.395609	valid_0's binary_logloss: 0.433144
# [6]	training's binary_logloss: 0.363697	valid_0's binary_logloss: 0.406415
# [7]	training's binary_logloss: 0.335158	valid_0's binary_logloss: 0.377358
# [8]	training's binary_logloss: 0.308771	valid_0's binary_logloss: 0.352721
# [9]	training's binary_logloss: 0.285638	valid_0's binary_logloss: 0.330059
# [10]	training's binary_logloss: 0.265246	valid_0's binary_logloss: 0.311921
# [11]	training's binary_logloss: 0.244424	valid_0's binary_logloss: 0.296042
# [12]	training's binary_logloss: 0.227385	valid_0's binary_logloss: 0.277297
# [13]	training's binary_logloss: 0.210167	valid_0's binary_logloss: 0.263523
# [14]	training's binary_logloss: 0.195234	valid_0's binary_logloss: 0.249957
# [15]	training's binary_logloss: 0.183511	valid_0's binary_logloss: 0.238093
# [16]	training's binary_logloss: 0.172536	valid_0's binary_logloss: 0.228477
# [17]	training's binary_logloss: 0.160196	valid_0's binary_logloss: 0.221006
# [18]	training's binary_logloss: 0.149495	valid_0's binary_logloss: 0.21399
# [19]	training's binary_logloss: 0.140657	valid_0's binary_logloss: 0.204148
# [20]	training's binary_logloss: 0.130395	valid_0's binary_logloss: 0.197335
# [21]	training's binary_logloss: 0.121449	valid_0's binary_logloss: 0.191283
# [22]	training's binary_logloss: 0.114591	valid_0's binary_logloss: 0.18712
# [23]	training's binary_logloss: 0.106915	valid_0's binary_logloss: 0.181973
# [24]	training's binary_logloss: 0.100852	valid_0's binary_logloss: 0.177336
# [25]	training's binary_logloss: 0.0944335	valid_0's binary_logloss: 0.174033
# [26]	training's binary_logloss: 0.0887658	valid_0's binary_logloss: 0.171232
# [27]	training's binary_logloss: 0.0839627	valid_0's binary_logloss: 0.163641
# [28]	training's binary_logloss: 0.0789486	valid_0's binary_logloss: 0.162
# [29]	training's binary_logloss: 0.0738853	valid_0's binary_logloss: 0.159277
# [30]	training's binary_logloss: 0.0693638	valid_0's binary_logloss: 0.157928
# [31]	training's binary_logloss: 0.0649147	valid_0's binary_logloss: 0.155957
# [32]	training's binary_logloss: 0.0610025	valid_0's binary_logloss: 0.149251
# [33]	training's binary_logloss: 0.0570227	valid_0's binary_logloss: 0.145153
# [34]	training's binary_logloss: 0.0533563	valid_0's binary_logloss: 0.144461
# [35]	training's binary_logloss: 0.0502111	valid_0's binary_logloss: 0.14365
# [36]	training's binary_logloss: 0.0468591	valid_0's binary_logloss: 0.143538
# [37]	training's binary_logloss: 0.0435188	valid_0's binary_logloss: 0.142388
# [38]	training's binary_logloss: 0.0402917	valid_0's binary_logloss: 0.140879
# [39]	training's binary_logloss: 0.0376958	valid_0's binary_logloss: 0.140905
# [40]	training's binary_logloss: 0.0353746	valid_0's binary_logloss: 0.139233
# [41]	training's binary_logloss: 0.033173	valid_0's binary_logloss: 0.138071
# [42]	training's binary_logloss: 0.0308546	valid_0's binary_logloss: 0.138316
# [43]	training's binary_logloss: 0.0287515	valid_0's binary_logloss: 0.13766
# [44]	training's binary_logloss: 0.0269956	valid_0's binary_logloss: 0.137189
# [45]	training's binary_logloss: 0.0253102	valid_0's binary_logloss: 0.136322
# [46]	training's binary_logloss: 0.023767	valid_0's binary_logloss: 0.137757
# [47]	training's binary_logloss: 0.0222245	valid_0's binary_logloss: 0.137866
# [48]	training's binary_logloss: 0.020838	valid_0's binary_logloss: 0.138082
# [49]	training's binary_logloss: 0.0193291	valid_0's binary_logloss: 0.138874
# [50]	training's binary_logloss: 0.0182763	valid_0's binary_logloss: 0.140183
# [51]	training's binary_logloss: 0.0169496	valid_0's binary_logloss: 0.13919
# [52]	training's binary_logloss: 0.0157545	valid_0's binary_logloss: 0.138413
# [53]	training's binary_logloss: 0.0146725	valid_0's binary_logloss: 0.13623
# [54]	training's binary_logloss: 0.0137338	valid_0's binary_logloss: 0.1348
# [55]	training's binary_logloss: 0.0130345	valid_0's binary_logloss: 0.134609
# [56]	training's binary_logloss: 0.0123424	valid_0's binary_logloss: 0.136583
# [57]	training's binary_logloss: 0.0114582	valid_0's binary_logloss: 0.135641
# [58]	training's binary_logloss: 0.0108205	valid_0's binary_logloss: 0.133984
# [59]	training's binary_logloss: 0.0101097	valid_0's binary_logloss: 0.133784
# [60]	training's binary_logloss: 0.0094547	valid_0's binary_logloss: 0.133453
# [61]	training's binary_logloss: 0.00884765	valid_0's binary_logloss: 0.133433
# [62]	training's binary_logloss: 0.00827294	valid_0's binary_logloss: 0.132168
# [63]	training's binary_logloss: 0.00775957	valid_0's binary_logloss: 0.132348
# [64]	training's binary_logloss: 0.00726237	valid_0's binary_logloss: 0.130468
# [65]	training's binary_logloss: 0.00682682	valid_0's binary_logloss: 0.127111
# [66]	training's binary_logloss: 0.00639988	valid_0's binary_logloss: 0.128709
# [67]	training's binary_logloss: 0.00601359	valid_0's binary_logloss: 0.129454
# [68]	training's binary_logloss: 0.00569404	valid_0's binary_logloss: 0.132149
# [69]	training's binary_logloss: 0.00532111	valid_0's binary_logloss: 0.132794
# [70]	training's binary_logloss: 0.00497493	valid_0's binary_logloss: 0.130563
# [71]	training's binary_logloss: 0.00466201	valid_0's binary_logloss: 0.132077
# [72]	training's binary_logloss: 0.00442617	valid_0's binary_logloss: 0.128955
# [73]	training's binary_logloss: 0.00415847	valid_0's binary_logloss: 0.1307
# [74]	training's binary_logloss: 0.00391596	valid_0's binary_logloss: 0.132587
# [75]	training's binary_logloss: 0.00366576	valid_0's binary_logloss: 0.134051
# [76]	training's binary_logloss: 0.00343669	valid_0's binary_logloss: 0.134764
# [77]	training's binary_logloss: 0.00318862	valid_0's binary_logloss: 0.136993
# [78]	training's binary_logloss: 0.00302545	valid_0's binary_logloss: 0.139896
# [79]	training's binary_logloss: 0.00281394	valid_0's binary_logloss: 0.141485
# [80]	training's binary_logloss: 0.00265489	valid_0's binary_logloss: 0.143146
# [81]	training's binary_logloss: 0.00248165	valid_0's binary_logloss: 0.142841
# [82]	training's binary_logloss: 0.00233201	valid_0's binary_logloss: 0.142586
# [83]	training's binary_logloss: 0.0021903	valid_0's binary_logloss: 0.142431
# [84]	training's binary_logloss: 0.00204763	valid_0's binary_logloss: 0.141429
# [85]	training's binary_logloss: 0.00191156	valid_0's binary_logloss: 0.140823
# [86]	training's binary_logloss: 0.00177594	valid_0's binary_logloss: 0.142244
# [87]	training's binary_logloss: 0.00165876	valid_0's binary_logloss: 0.142487
# [88]	training's binary_logloss: 0.0015558	valid_0's binary_logloss: 0.143662
# [89]	training's binary_logloss: 0.00146462	valid_0's binary_logloss: 0.142963
# [90]	training's binary_logloss: 0.00137248	valid_0's binary_logloss: 0.142402
# [91]	training's binary_logloss: 0.0012891	valid_0's binary_logloss: 0.143355
# [92]	training's binary_logloss: 0.00121344	valid_0's binary_logloss: 0.145223
# [93]	training's binary_logloss: 0.00114474	valid_0's binary_logloss: 0.146851
# [94]	training's binary_logloss: 0.00106657	valid_0's binary_logloss: 0.149606
# [95]	training's binary_logloss: 0.000998612	valid_0's binary_logloss: 0.150166
# [96]	training's binary_logloss: 0.000931763	valid_0's binary_logloss: 0.152185
# [97]	training's binary_logloss: 0.000874949	valid_0's binary_logloss: 0.154522
# [98]	training's binary_logloss: 0.000831725	valid_0's binary_logloss: 0.156924
# [99]	training's binary_logloss: 0.000783231	valid_0's binary_logloss: 0.157783
# [100]	training's binary_logloss: 0.00073831	valid_0's binary_logloss: 0.160388
# [1]	training's binary_logloss: 0.592831	valid_0's binary_logloss: 0.582308
# [2]	training's binary_logloss: 0.533022	valid_0's binary_logloss: 0.524846
# [3]	training's binary_logloss: 0.483319	valid_0's binary_logloss: 0.478493
# [4]	training's binary_logloss: 0.441015	valid_0's binary_logloss: 0.441204
# [5]	training's binary_logloss: 0.402772	valid_0's binary_logloss: 0.403264
# [6]	training's binary_logloss: 0.370329	valid_0's binary_logloss: 0.368373
# [7]	training's binary_logloss: 0.340919	valid_0's binary_logloss: 0.340243
# [8]	training's binary_logloss: 0.31424	valid_0's binary_logloss: 0.318966
# [9]	training's binary_logloss: 0.291277	valid_0's binary_logloss: 0.29632
# [10]	training's binary_logloss: 0.268931	valid_0's binary_logloss: 0.273788
# [11]	training's binary_logloss: 0.248148	valid_0's binary_logloss: 0.257592
# [12]	training's binary_logloss: 0.22997	valid_0's binary_logloss: 0.24117
# [13]	training's binary_logloss: 0.213813	valid_0's binary_logloss: 0.225021
# [14]	training's binary_logloss: 0.200172	valid_0's binary_logloss: 0.215453
# [15]	training's binary_logloss: 0.187153	valid_0's binary_logloss: 0.201666
# [16]	training's binary_logloss: 0.175794	valid_0's binary_logloss: 0.191404
# [17]	training's binary_logloss: 0.165963	valid_0's binary_logloss: 0.185074
# [18]	training's binary_logloss: 0.155418	valid_0's binary_logloss: 0.172997
# [19]	training's binary_logloss: 0.146353	valid_0's binary_logloss: 0.163443
# [20]	training's binary_logloss: 0.136362	valid_0's binary_logloss: 0.153646
# [21]	training's binary_logloss: 0.127589	valid_0's binary_logloss: 0.144854
# [22]	training's binary_logloss: 0.119686	valid_0's binary_logloss: 0.136956
# [23]	training's binary_logloss: 0.113101	valid_0's binary_logloss: 0.130574
# [24]	training's binary_logloss: 0.105893	valid_0's binary_logloss: 0.123974
# [25]	training's binary_logloss: 0.0984302	valid_0's binary_logloss: 0.117275
# [26]	training's binary_logloss: 0.0926945	valid_0's binary_logloss: 0.111981
# [27]	training's binary_logloss: 0.0874219	valid_0's binary_logloss: 0.107122
# [28]	training's binary_logloss: 0.0823475	valid_0's binary_logloss: 0.103054
# [29]	training's binary_logloss: 0.077377	valid_0's binary_logloss: 0.0992175
# [30]	training's binary_logloss: 0.0729232	valid_0's binary_logloss: 0.0945403
# [31]	training's binary_logloss: 0.0681134	valid_0's binary_logloss: 0.0910399
# [32]	training's binary_logloss: 0.0643514	valid_0's binary_logloss: 0.086985
# [33]	training's binary_logloss: 0.0602058	valid_0's binary_logloss: 0.0839076
# [34]	training's binary_logloss: 0.0568317	valid_0's binary_logloss: 0.0811983
# [35]	training's binary_logloss: 0.0538829	valid_0's binary_logloss: 0.0813179
# [36]	training's binary_logloss: 0.0507996	valid_0's binary_logloss: 0.0805079
# [37]	training's binary_logloss: 0.0481249	valid_0's binary_logloss: 0.0790446
# [38]	training's binary_logloss: 0.0450421	valid_0's binary_logloss: 0.0777415
# [39]	training's binary_logloss: 0.0421195	valid_0's binary_logloss: 0.0762371
# [40]	training's binary_logloss: 0.03913	valid_0's binary_logloss: 0.0753992
# [41]	training's binary_logloss: 0.0365178	valid_0's binary_logloss: 0.0738593
# [42]	training's binary_logloss: 0.034786	valid_0's binary_logloss: 0.0746283
# [43]	training's binary_logloss: 0.0325383	valid_0's binary_logloss: 0.0742613
# [44]	training's binary_logloss: 0.0305355	valid_0's binary_logloss: 0.0734868
# [45]	training's binary_logloss: 0.0285062	valid_0's binary_logloss: 0.0745557
# [46]	training's binary_logloss: 0.0266913	valid_0's binary_logloss: 0.0732053
# [47]	training's binary_logloss: 0.0248514	valid_0's binary_logloss: 0.0733231
# [48]	training's binary_logloss: 0.0231005	valid_0's binary_logloss: 0.0737353
# [49]	training's binary_logloss: 0.0216237	valid_0's binary_logloss: 0.07341
# [50]	training's binary_logloss: 0.0204435	valid_0's binary_logloss: 0.0716755
# [51]	training's binary_logloss: 0.0191572	valid_0's binary_logloss: 0.0707862
# [52]	training's binary_logloss: 0.0179403	valid_0's binary_logloss: 0.0714901
# [53]	training's binary_logloss: 0.0167586	valid_0's binary_logloss: 0.0698221
# [54]	training's binary_logloss: 0.0157938	valid_0's binary_logloss: 0.0694523
# [55]	training's binary_logloss: 0.0146355	valid_0's binary_logloss: 0.0690046
# [56]	training's binary_logloss: 0.0138177	valid_0's binary_logloss: 0.0675605
# [57]	training's binary_logloss: 0.0131035	valid_0's binary_logloss: 0.0681904
# [58]	training's binary_logloss: 0.0122702	valid_0's binary_logloss: 0.0666629
# [59]	training's binary_logloss: 0.0115308	valid_0's binary_logloss: 0.0669268
# [60]	training's binary_logloss: 0.0109127	valid_0's binary_logloss: 0.0649983
# [61]	training's binary_logloss: 0.010239	valid_0's binary_logloss: 0.063336
# [62]	training's binary_logloss: 0.00953047	valid_0's binary_logloss: 0.0643655
# [63]	training's binary_logloss: 0.00901435	valid_0's binary_logloss: 0.0645539
# [64]	training's binary_logloss: 0.0084761	valid_0's binary_logloss: 0.0663363
# [65]	training's binary_logloss: 0.00793609	valid_0's binary_logloss: 0.0675504
# [66]	training's binary_logloss: 0.00734838	valid_0's binary_logloss: 0.0680321
# [67]	training's binary_logloss: 0.00686606	valid_0's binary_logloss: 0.0677741
# [68]	training's binary_logloss: 0.00638192	valid_0's binary_logloss: 0.067095
# [69]	training's binary_logloss: 0.00599068	valid_0's binary_logloss: 0.068507
# [70]	training's binary_logloss: 0.00558504	valid_0's binary_logloss: 0.068766
# [71]	training's binary_logloss: 0.00530445	valid_0's binary_logloss: 0.067476
# [72]	training's binary_logloss: 0.00492465	valid_0's binary_logloss: 0.0679965
# [73]	training's binary_logloss: 0.00465884	valid_0's binary_logloss: 0.0662528
# [74]	training's binary_logloss: 0.00442592	valid_0's binary_logloss: 0.066324
# [75]	training's binary_logloss: 0.00415028	valid_0's binary_logloss: 0.0679361
# [76]	training's binary_logloss: 0.00387654	valid_0's binary_logloss: 0.0679323
# [77]	training's binary_logloss: 0.00364418	valid_0's binary_logloss: 0.0681933
# [78]	training's binary_logloss: 0.00345629	valid_0's binary_logloss: 0.0687406
# [79]	training's binary_logloss: 0.003242	valid_0's binary_logloss: 0.0709064
# [80]	training's binary_logloss: 0.0030398	valid_0's binary_logloss: 0.0727382
# [81]	training's binary_logloss: 0.00284046	valid_0's binary_logloss: 0.0734996
# [82]	training's binary_logloss: 0.00270412	valid_0's binary_logloss: 0.0717976
# [83]	training's binary_logloss: 0.00258175	valid_0's binary_logloss: 0.072465
# [84]	training's binary_logloss: 0.0024048	valid_0's binary_logloss: 0.0732145
# [85]	training's binary_logloss: 0.00225174	valid_0's binary_logloss: 0.0730767
# [86]	training's binary_logloss: 0.00211681	valid_0's binary_logloss: 0.0746464
# [87]	training's binary_logloss: 0.00198872	valid_0's binary_logloss: 0.076173
# [88]	training's binary_logloss: 0.00184823	valid_0's binary_logloss: 0.0768651
# [89]	training's binary_logloss: 0.00172317	valid_0's binary_logloss: 0.0764957
# [90]	training's binary_logloss: 0.00160461	valid_0's binary_logloss: 0.0773213
# [91]	training's binary_logloss: 0.00152332	valid_0's binary_logloss: 0.0790008
# [92]	training's binary_logloss: 0.00142165	valid_0's binary_logloss: 0.080653
# [93]	training's binary_logloss: 0.00133793	valid_0's binary_logloss: 0.0823128
# [94]	training's binary_logloss: 0.00126009	valid_0's binary_logloss: 0.0837092
# [95]	training's binary_logloss: 0.0011802	valid_0's binary_logloss: 0.0842651
# [96]	training's binary_logloss: 0.00110643	valid_0's binary_logloss: 0.0844985
# [97]	training's binary_logloss: 0.00103991	valid_0's binary_logloss: 0.0859519
# [98]	training's binary_logloss: 0.000972489	valid_0's binary_logloss: 0.0876492
# [99]	training's binary_logloss: 0.000912993	valid_0's binary_logloss: 0.0879777
# [100]	training's binary_logloss: 0.000861784	valid_0's binary_logloss: 0.0876827
# [1]	training's binary_logloss: 0.583652	valid_0's binary_logloss: 0.598045
# [2]	training's binary_logloss: 0.521578	valid_0's binary_logloss: 0.535014
# [3]	training's binary_logloss: 0.472072	valid_0's binary_logloss: 0.486145
# [4]	training's binary_logloss: 0.428139	valid_0's binary_logloss: 0.440236
# [5]	training's binary_logloss: 0.390997	valid_0's binary_logloss: 0.404808
# [6]	training's binary_logloss: 0.357919	valid_0's binary_logloss: 0.373389
# [7]	training's binary_logloss: 0.329215	valid_0's binary_logloss: 0.344983
# [8]	training's binary_logloss: 0.303776	valid_0's binary_logloss: 0.319873
# [9]	training's binary_logloss: 0.280296	valid_0's binary_logloss: 0.296594
# [10]	training's binary_logloss: 0.259086	valid_0's binary_logloss: 0.276234
# [11]	training's binary_logloss: 0.240636	valid_0's binary_logloss: 0.256898
# [12]	training's binary_logloss: 0.222312	valid_0's binary_logloss: 0.237678
# [13]	training's binary_logloss: 0.208023	valid_0's binary_logloss: 0.224589
# [14]	training's binary_logloss: 0.195311	valid_0's binary_logloss: 0.213274
# [15]	training's binary_logloss: 0.181331	valid_0's binary_logloss: 0.200473
# [16]	training's binary_logloss: 0.169765	valid_0's binary_logloss: 0.189719
# [17]	training's binary_logloss: 0.158611	valid_0's binary_logloss: 0.178725
# [18]	training's binary_logloss: 0.148886	valid_0's binary_logloss: 0.170771
# [19]	training's binary_logloss: 0.140054	valid_0's binary_logloss: 0.163774
# [20]	training's binary_logloss: 0.131739	valid_0's binary_logloss: 0.155276
# [21]	training's binary_logloss: 0.124455	valid_0's binary_logloss: 0.148199
# [22]	training's binary_logloss: 0.117032	valid_0's binary_logloss: 0.14224
# [23]	training's binary_logloss: 0.111126	valid_0's binary_logloss: 0.137898
# [24]	training's binary_logloss: 0.103761	valid_0's binary_logloss: 0.130504
# [25]	training's binary_logloss: 0.097501	valid_0's binary_logloss: 0.125471
# [26]	training's binary_logloss: 0.0917615	valid_0's binary_logloss: 0.121491
# [27]	training's binary_logloss: 0.085896	valid_0's binary_logloss: 0.115986
# [28]	training's binary_logloss: 0.0809553	valid_0's binary_logloss: 0.111244
# [29]	training's binary_logloss: 0.0761058	valid_0's binary_logloss: 0.10732
# [30]	training's binary_logloss: 0.0717513	valid_0's binary_logloss: 0.10277
# [31]	training's binary_logloss: 0.0674365	valid_0's binary_logloss: 0.100514
# [32]	training's binary_logloss: 0.063252	valid_0's binary_logloss: 0.0974204
# [33]	training's binary_logloss: 0.0597804	valid_0's binary_logloss: 0.0937091
# [34]	training's binary_logloss: 0.0565446	valid_0's binary_logloss: 0.0896346
# [35]	training's binary_logloss: 0.0525283	valid_0's binary_logloss: 0.0868686
# [36]	training's binary_logloss: 0.0489944	valid_0's binary_logloss: 0.0862252
# [37]	training's binary_logloss: 0.0461704	valid_0's binary_logloss: 0.0845802
# [38]	training's binary_logloss: 0.0430825	valid_0's binary_logloss: 0.0808661
# [39]	training's binary_logloss: 0.0402934	valid_0's binary_logloss: 0.0792056
# [40]	training's binary_logloss: 0.0379124	valid_0's binary_logloss: 0.0774489
# [41]	training's binary_logloss: 0.0354042	valid_0's binary_logloss: 0.0763139
# [42]	training's binary_logloss: 0.0331267	valid_0's binary_logloss: 0.0752226
# [43]	training's binary_logloss: 0.0312668	valid_0's binary_logloss: 0.0746813
# [44]	training's binary_logloss: 0.0291643	valid_0's binary_logloss: 0.0729581
# [45]	training's binary_logloss: 0.0276492	valid_0's binary_logloss: 0.0723356
# [46]	training's binary_logloss: 0.0258089	valid_0's binary_logloss: 0.0716418
# [47]	training's binary_logloss: 0.0241365	valid_0's binary_logloss: 0.0708646
# [48]	training's binary_logloss: 0.0228128	valid_0's binary_logloss: 0.0705729
# [49]	training's binary_logloss: 0.021474	valid_0's binary_logloss: 0.0703572
# [50]	training's binary_logloss: 0.0203508	valid_0's binary_logloss: 0.0701948
# [51]	training's binary_logloss: 0.0191619	valid_0's binary_logloss: 0.069263
# [52]	training's binary_logloss: 0.017932	valid_0's binary_logloss: 0.0692394
# [53]	training's binary_logloss: 0.0167815	valid_0's binary_logloss: 0.0686008
# [54]	training's binary_logloss: 0.0159788	valid_0's binary_logloss: 0.0686653
# [55]	training's binary_logloss: 0.014917	valid_0's binary_logloss: 0.0684556
# [56]	training's binary_logloss: 0.0141436	valid_0's binary_logloss: 0.0687694
# [57]	training's binary_logloss: 0.013273	valid_0's binary_logloss: 0.0684672
# [58]	training's binary_logloss: 0.012559	valid_0's binary_logloss: 0.0683219
# [59]	training's binary_logloss: 0.0119646	valid_0's binary_logloss: 0.0681242
# [60]	training's binary_logloss: 0.0112723	valid_0's binary_logloss: 0.0683818
# [61]	training's binary_logloss: 0.0105701	valid_0's binary_logloss: 0.0681162
# [62]	training's binary_logloss: 0.010014	valid_0's binary_logloss: 0.0674419
# [63]	training's binary_logloss: 0.00943215	valid_0's binary_logloss: 0.0677757
# [64]	training's binary_logloss: 0.0087916	valid_0's binary_logloss: 0.0679825
# [65]	training's binary_logloss: 0.00827478	valid_0's binary_logloss: 0.0682306
# [66]	training's binary_logloss: 0.00778575	valid_0's binary_logloss: 0.0690726
# [67]	training's binary_logloss: 0.00730752	valid_0's binary_logloss: 0.0683897
# [68]	training's binary_logloss: 0.00691639	valid_0's binary_logloss: 0.0689218
# [69]	training's binary_logloss: 0.0064839	valid_0's binary_logloss: 0.0680352
# [70]	training's binary_logloss: 0.00609562	valid_0's binary_logloss: 0.0683728
# [71]	training's binary_logloss: 0.00573289	valid_0's binary_logloss: 0.0684679
# [72]	training's binary_logloss: 0.00540446	valid_0's binary_logloss: 0.0679198
# [73]	training's binary_logloss: 0.00510476	valid_0's binary_logloss: 0.0680838
# [74]	training's binary_logloss: 0.00474779	valid_0's binary_logloss: 0.0681611
# [75]	training's binary_logloss: 0.00445235	valid_0's binary_logloss: 0.0677544
# [76]	training's binary_logloss: 0.00420939	valid_0's binary_logloss: 0.0678043
# [77]	training's binary_logloss: 0.00393595	valid_0's binary_logloss: 0.066721
# [78]	training's binary_logloss: 0.00374083	valid_0's binary_logloss: 0.067645
# [79]	training's binary_logloss: 0.0035403	valid_0's binary_logloss: 0.0673831
# [80]	training's binary_logloss: 0.0033265	valid_0's binary_logloss: 0.0685123
# [81]	training's binary_logloss: 0.00316713	valid_0's binary_logloss: 0.0694069
# [82]	training's binary_logloss: 0.00295359	valid_0's binary_logloss: 0.0701867
# [83]	training's binary_logloss: 0.00277406	valid_0's binary_logloss: 0.0699388
# [84]	training's binary_logloss: 0.0026051	valid_0's binary_logloss: 0.0701632
# [85]	training's binary_logloss: 0.00246527	valid_0's binary_logloss: 0.0704776
# [86]	training's binary_logloss: 0.00233495	valid_0's binary_logloss: 0.0708599
# [87]	training's binary_logloss: 0.00219234	valid_0's binary_logloss: 0.0720293
# [88]	training's binary_logloss: 0.0020599	valid_0's binary_logloss: 0.0727858
# [89]	training's binary_logloss: 0.00196111	valid_0's binary_logloss: 0.0737252
# [90]	training's binary_logloss: 0.00184618	valid_0's binary_logloss: 0.0746316
# [91]	training's binary_logloss: 0.00172709	valid_0's binary_logloss: 0.0749699
# [92]	training's binary_logloss: 0.00162963	valid_0's binary_logloss: 0.0749221
# [93]	training's binary_logloss: 0.00155159	valid_0's binary_logloss: 0.0756558
# [94]	training's binary_logloss: 0.00147538	valid_0's binary_logloss: 0.0760819
# [95]	training's binary_logloss: 0.00138853	valid_0's binary_logloss: 0.0759769
# [96]	training's binary_logloss: 0.0013311	valid_0's binary_logloss: 0.0760174
# [97]	training's binary_logloss: 0.00124961	valid_0's binary_logloss: 0.0764899
# [98]	training's binary_logloss: 0.00119377	valid_0's binary_logloss: 0.0773285
# [99]	training's binary_logloss: 0.00111499	valid_0's binary_logloss: 0.0777752
# [100]	training's binary_logloss: 0.00105194	valid_0's binary_logloss: 0.077842
# ---Run time is 1.373599794999791 seconds ---
#
# Accuracy of each fold:
#  [0.9473684210526315, 0.9473684210526315, 0.9473684210526315, 0.9736842105263158, 0.9823008849557522]
#
# Avg accuracy :
# 0.9596180717279925
#
# Std of accuracy :
# 0.01524813497857519

# %%
print(confusion_matrix(Truth, Output))
print(classification_report(Truth, Output))
# Out:
# [[198  14]
#  [  9 348]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.93      0.95       212
#            1       0.96      0.97      0.97       357
#
#     accuracy                           0.96       569
#    macro avg       0.96      0.95      0.96       569
# weighted avg       0.96      0.96      0.96       569

# %% [markdown]
# # CatBoosting

# %%
# https://catboost.ai/en/docs/concepts/python-quickstart
import catboost as cb
from catboost import CatBoostClassifier


print ('catboost version', cb.__version__)
# Out:
# catboost version 1.0.3

# %%
#Implementing cross validation 
kf = KFold(n_splits=5, random_state=1, shuffle=True)

from time import time
import timeit #imports timeit module
start_time = timeit.default_timer() #defines start time so computational time can be calculated

acc_score = [];
Truth = [];
Output = [];
 
for train_index , test_index in kf.split(df):
    
    X_train , X_test = df.iloc[train_index,:-1], df.iloc[test_index,:-1]
    y_train , y_test = df.iloc[train_index,-1], df.iloc[test_index,-1]
    
    # Create CatBoost model
    model = CatBoostClassifier(iterations=100,
                           depth=4,
                           learning_rate=0.1,
                           loss_function='Logloss')
    # train the model
    model.fit(X_train, y_train, verbose=False)
    
    # make the prediction using the resulting model
    pred_values = model.predict(X_test)
    #preds_proba = model.predict_proba(test_data)
    #print("class = ", preds_class)
    #print("proba = ", preds_proba)
     
    acc = accuracy_score(y_test, pred_values)
    acc_score.append(acc)
    
    Truth.extend(y_test.values.reshape(y_test.shape[0])); ## it is a list
    Output.extend(pred_values); ## it is a list  
    
    #print(model.feature_importances_)
    Importance = pd.DataFrame({'Importance':(model.feature_importances_*100)[0:10]}, 
                          index = (X_train.columns)[0:10])
    Importance.sort_values(by = 'Importance', 
                       axis = 0, 
                       ascending = True).plot(kind = 'barh', 
                                              color = 'r')
    plt.xlabel('Variable Importance')
    plt.gca().legend_ = None
    #plt.savefig('plot1.png')


elapsed = timeit.default_timer() - start_time #gives total computation time
print("---Run time is %s seconds ---" % elapsed) #prints computation time
print()

print('Accuracy of each fold: \n {}'.format(acc_score))
print()
print('Avg accuracy : \n{}'.format(np.mean(acc_score))); 
print()
print('Std of accuracy : \n{}'.format(np.std(acc_score)))
# Out:
# ---Run time is 1.224437643999977 seconds ---
#
# Accuracy of each fold:
#  [0.956140350877193, 0.956140350877193, 0.9649122807017544, 0.9824561403508771, 0.9823008849557522]
#
# Avg accuracy :
# 0.968390001552554
#
# Std of accuracy :
# 0.011862304695158518

# %%
print(confusion_matrix(Truth, Output))
print(classification_report(Truth, Output))
# Out:
# [[199  13]
#  [  5 352]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.94      0.96       212
#            1       0.96      0.99      0.98       357
#
#     accuracy                           0.97       569
#    macro avg       0.97      0.96      0.97       569
# weighted avg       0.97      0.97      0.97       569

# %% [markdown]
# # Please neglect: The following are some codes to be developed
#
# https://lightgbm.readthedocs.io/en/latest/pythonapi/lightgbm.Dataset.html

# %% [raw]
# #Implementing cross validation
# kf = KFold(n_splits=5, random_state=1, shuffle=True)
#
# from time import time
# import timeit #imports timeit module
# start_time = timeit.default_timer() #defines start time so computational time can be calculated
#
# acc_score = [];
# Truth = [];
# Output = [];
#
# for train_index , test_index in kf.split(df):
#
#     X_train , X_test = df.iloc[train_index,:-1], df.iloc[test_index,:-1]
#     y_train , y_test = df.iloc[train_index,-1], df.iloc[test_index,-1]
#
#     # Create the LightGBM data containers
#     categorical_features = [c for c, col in enumerate(X_train.columns) if 'cat' in col]
#     train_data = lightgbm.Dataset(X_train, label=y_train, categorical_feature=categorical_features)
#     test_data = lightgbm.Dataset(X_test, label=y_test)
#
#     parameters = {
#     'application': 'binary',
#     'objective': 'binary',
#     'metric': 'auc',
#     'is_unbalance': 'true',
#     'boosting': 'gbdt',
#     'num_leaves': 31,
#     'feature_fraction': 0.5,
#     'bagging_fraction': 0.5,
#     'bagging_freq': 20,
#     'learning_rate': 0.05,
#     'verbose': 0
#     }
#
#     model = lightgbm.train(parameters,
#                        train_data,
#                        valid_sets=test_data,
#                        num_boost_round=50)
# #    model.fit(X_train,y_train) ==> NO fitting for LGBM
#     pred_values = model.predict(X_test)
#
#     acc = accuracy_score(y_test, pred_values)
#     acc_score.append(acc)
#
#     Truth.extend(y_test.values.reshape(y_test.shape[0])); ## it is a list
#     Output.extend(pred_values); ## it is a list
#
# elapsed = timeit.default_timer() - start_time #gives total computation time
# print("---Run time is %s seconds ---" % elapsed) #prints computation time
# print()
#
# print('Accuracy of each fold: \n {}'.format(acc_score))
# print()
# print('Avg accuracy : \n{}'.format(np.mean(acc_score)));
# print()
# print('Std of accuracy : \n{}'.format(np.std(acc_score)))

# %% [raw]
# #https://stackoverflow.com/questions/25009284/how-to-plot-roc-curve-in-python
# import scikitplot as skplt
# skplt.metrics.plot_roc_curve(y_test, pred_prob)
# plt.show()

# %% [raw]
# xgb_model = xgboost.XGBClassifier(num_class=7,
#                                   learning_rate=0.1,
#                                   num_iterations=1000,
#                                   max_depth=10,
#                                   feature_fraction=0.7,
#                                   scale_pos_weight=1.5,
#                                   boosting='gbdt',
#                                   metric='multiclass',
#                                   eval_metric='mlogloss')
