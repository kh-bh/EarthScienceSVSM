# %% [markdown]
# # K-Fold CV for Boosting Methods Using SKLearn

# %%
#Importing required libraries
from sklearn.datasets import load_breast_cancer
import pandas as pd
import numpy as np
from sklearn import neighbors
from sklearn.model_selection import KFold 
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import LeaveOneOut

from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix, classification_report
import random

# %%
conda install -c anaconda py-xgboost
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\hmche\anaconda3
#
#   added / updated specs:
#     - py-xgboost
#
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   conda              conda-forge::conda-4.13.0-py39hcbf530~ --> anaconda::conda-4.13.0-py39haa95532_0
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c conda-forge lightgbm
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working...
# Warning: 8 possible package resolutions (only showing differing packages):
#   - anaconda/win-64::ca-certificates-2022.3.29-haa95532_1, anaconda/win-64::certifi-2021.10.8-py39haa95532_2, anaconda/win-64::openssl-1.1.1n-h2bbff1b_0
#   - anaconda/win-64::certifi-2021.10.8-py39haa95532_2, anaconda/win-64::openssl-1.1.1n-h2bbff1b_0, defaults/win-64::ca-certificates-2022.3.29-haa95532_1
#   - anaconda/win-64::ca-certificates-2022.3.29-haa95532_1, anaconda/win-64::certifi-2021.10.8-py39haa95532_2, defaults/win-64::openssl-1.1.1n-h2bbff1b_0
#   - anaconda/win-64::certifi-2021.10.8-py39haa95532_2, defaults/win-64::ca-certificates-2022.3.29-haa95532_1, defaults/win-64::openssl-1.1.1n-h2bbff1b_0
#   - anaconda/win-64::ca-certificates-2022.3.29-haa95532_1, defaults/win-64::certifi-2021.10.8-py39haa95532_2, defaults/win-64::openssl-1.1.1n-h2bbff1b_0
#   - defaults/win-64::ca-certificates-2022.3.29-haa95532_1, defaults/win-64::certifi-2021.10.8-py39haa95532_2, defaults/win-64::openssl-1.1.1n-h2bbff1b_0
#   - anaconda/win-64::ca-certificates-2022.3.29-haa95532_1, anaconda/win-64::openssl-1.1.1n-h2bbff1b_0, defaults/win-64::certifi-2021.10.8-py39haa95532_2
#   - anaconda/win-64::openssl-1.1.1n-h2bbff1b_0, defaults/win-64::ca-certificates-2022.3.29-haa95532_1, defaults/win-64::certifi-2021.10.8-py39haa95532_2done
#
# ## Package Plan ##
#
#   environment location: C:\Users\hmche\anaconda3
#
#   added / updated specs:
#     - lightgbm
#
#
# The following packages will be UPDATED:
#
#   conda               anaconda::conda-4.13.0-py39haa95532_0 --> conda-forge::conda-4.13.0-py39hcbf5309_1
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import xgboost as xgb
from sklearn import metrics
from lightgbm import LGBMClassifier

import lightgbm
import lightgbm as lgb
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.dpi'] = 70 #display 70 dpi in Jupyter Notebook, may consider100 dpi 
plt.rcParams['savefig.dpi'] = 300 #define 300 dpi for saving figures

import seaborn as sns
## here are some settings 
sns.set_style('whitegrid')
sns.set(rc={"figure.dpi":70, 'savefig.dpi':300}) #defining dpi setting
sns.set_context('notebook')
sns.set_style("ticks")
from IPython.display import set_matplotlib_formats

# %% [markdown]
# ### To load sklearn dataset
# sklearn.datasets.load_breast_cancer(*, return_X_y=False, as_frame=False)[source]¶
#
# Load and return the breast cancer wisconsin dataset (classification).

# %%
#df = pd.read_csv('JORN21_dataset_v1.csv', na_values='?').dropna() 
df = pd.read_csv('JORN17_dataset_v2.csv', na_values='?').dropna()  
#'SRER_2017_training_bi.csv' 
df2 = pd.read_csv('SRER_2017_training_bi.csv' , na_values='?').dropna()
#del df2['Veg_class']
#df2.isnull().sum()
#df2.dropna(axis=0,inplace=True)
#df2['Veg_class'] = ""
#df2 = pd.read_csv('SRER_2017_training_bi.csv', na_values='?').dropna()
#df['year'] = int(2017)
#df2['year'] = int(20'21)
df3 = pd.concat(([df,df2]),ignore_index=True)
df3.isnull().sum()
df3.dropna(axis=0,inplace=True)
df= df.replace('woody',1)
df= df.replace('non-woody',0)
df2= df2.replace('woody',1)
df2= df2.replace('non-woody',0)
df3= df3.replace('woody',1)
df3= df3.replace('non-woody',0)
df3 = df3.reindex(columns=['CH_mean','ARVI_max','ARVI_mean','ARVI_med','EVI_max','EVI_mean','EVI_med','NDVI_max','NDVI_mean','NDVI_med','SAVI_max','SAVI_mean','SAVI_med','year','Veg_class'])
#del df2['Veg_class']
df2
# Out:
#       OID_    Id  gridcode  Shape_Length  Shape_Area   CH_mean  ARVI_max  \
# 0        1     2         2          41.6       17.41  0.190714  0.609099
# 1        2     3         3          31.4        5.05  0.045000  0.387755
# 2        3     5         5          33.4        4.84  0.010000  0.038844
# 3        4     6         6          32.2       14.20  0.011667  0.189842
# 4        5     7         7          28.8       10.73  0.013750  0.322694
# ...    ...   ...       ...           ...         ...       ...       ...
# 4334  4335  4487      4487           8.8        2.30  0.020000  0.290182
# 4335  4336  4488      4488          10.8        2.03  0.020000  0.408320
# 4336  4337  4489      4489          11.8        2.62  0.015000  0.437195
# 4337  4338  4490      4490          11.2        3.09  0.015000  0.570094
# 4338  4339  4491      4491          14.8        3.33  0.865000  0.487398
#
#       ARVI_mean  ARVI_med   EVI_max  EVI_mean   EVI_med  NDVI_max  NDVI_mean  \
# 0      0.344183  0.379428  0.443455  0.292047  0.290985  0.665698   0.476709
# 1      0.245301  0.274936  0.332059  0.252919  0.244477  0.526375   0.406745
# 2      0.004040  0.026805  0.150550  0.131985  0.134891  0.208300   0.181575
# 3      0.033418  0.018961  0.198972  0.141579  0.138338  0.341480   0.207390
# 4      0.080315  0.061453  0.248442  0.158710  0.142326  0.457103   0.247391
# ...         ...       ...       ...       ...       ...       ...        ...
# 4334   0.290182  0.290182  0.283959  0.283959  0.283959  0.419200   0.419200
# 4335   0.408320  0.408320  0.372648  0.372648  0.372648  0.510469   0.510469
# 4336   0.413297  0.413297  0.235606  0.234926  0.234926  0.499074   0.485601
# 4337   0.550652  0.550652  0.416298  0.388085  0.388085  0.640722   0.621694
# 4338   0.484593  0.484593  0.286898  0.277861  0.277861  0.543662   0.540401
#
#       NDVI_med  SAVI_max  SAVI_mean  SAVI_med  Veg_class
# 0     0.507514  0.406991   0.286203  0.288351          1
# 1     0.433791  0.328585   0.254814  0.248126          0
# 2     0.205117  0.150184   0.131642  0.135063          0
# 3     0.197327  0.197330   0.141500  0.138725          0
# 4     0.228112  0.248598   0.158618  0.142817          0
# ...        ...       ...        ...       ...        ...
# 4334  0.419200  0.269486   0.269486  0.269486          1
# 4335  0.510469  0.340879   0.340879  0.340879          1
# 4336  0.485601  0.227606   0.226722  0.226722          1
# 4337  0.621694  0.387576   0.363288  0.363288          1
# 4338  0.540401  0.270742   0.263390  0.263390          1
#
# [4339 rows x 19 columns]

# %% [markdown]
# # Extreme Gradient Boosting

# %%
# https://xgboost.readthedocs.io/en/latest/python/python_api.html#module-xgboost.sklearn

# THIS IS CROSS VALIDATION FOR XGB
import xgboost
import xgboost as xgb
from xgboost import XGBClassifier
print(xgboost.__version__)
from matplotlib import pyplot
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve, auc
import sklearn.metrics as metrics
random.seed(1000)
#Implementing cross validation 
kf = KFold(n_splits=5, random_state=1, shuffle=True)
#random_state = sets the seed
#shuffle = randomization
# Create the Extreme GBM
model = XGBClassifier(n_estimators=100, learning_rate = 0.1,use_label_encoder =False,verbose=None,
                max_depth = 5, eval_metric='logloss')
    
from time import time
import timeit #imports timeit module
start_time = timeit.default_timer() #defines start time so computational time can be calculated

acc_score = [];
Truth = [];
Output = [];

for train_index, test_index in kf.split(df):
    X_train , X_test = df.iloc[train_index,5:18], df.iloc[test_index,5:18]
    Y_train , Y_test = df.iloc[train_index,-1], df.iloc[test_index,-1]
    model.fit(X_train, Y_train)
    pred_values = model.predict(X_test)
    pred_prob = model.predict_proba(X_test)[:, 1]
    
    acc = accuracy_score(Y_test, pred_values)
    acc_score.append(acc)
    Truth.extend(Y_test.values.reshape(Y_test.shape[0])); ## it is a list
    Output.extend(pred_values); ## it is a list 

        #print(model.feature_importances_)
    Importance = pd.DataFrame({'Importance':(model.feature_importances_*100)[0:10]}, index = (X_train.columns)[0:10])
    Importance.sort_values(by = 'Importance', axis = 0, ascending = True).plot(kind = 'barh', color = 'r')
    plt.xlabel('Variable Importance')
    plt.gca().legend_ = None
    plt.show()
        #plt.savefig('plot1.png')

        ##################################################
        #https://scikit-learn.org/stable/modules/generated/sklearn.metrics.roc_auc_score.html
        #Compute Area Under the Receiver Operating Characteristic Curve (ROC AUC) from prediction scores.
    print("roc_auc_score", roc_auc_score(Y_test, pred_prob))

elapsed = timeit.default_timer() - start_time #gives total computation time
print("---Run time is %s seconds ---" % elapsed) #prints computation time
print()

print('Accuracy of each fold: \n {}'.format(acc_score))
print()
print('Avg accuracy : \n{}'.format(np.mean(acc_score))); 
print()
print('Std of accuracy : \n{}'.format(np.std(acc_score)))

#from here

print()
print('Accuracy of each fold: \n {}'.format(acc_score))
print("Avg accuracy: {}".format(np.mean(acc_score)))
print('Std of accuracy : \n{}'.format(np.std(acc_score)))
print()
print(confusion_matrix(Truth, Output))
print()
print(classification_report(Truth, Output))

cm = confusion_matrix(Truth, Output)

sensitivity = cm[0][0]/(cm[0][0]+cm[0][1])
specificity = cm[1][1]/(cm[1][0]+cm[1][1])
precision = (cm[0][0])/(cm[0][0]+cm[1][0])
f1_score = (2*precision*sensitivity)/(precision+sensitivity)

print("sens ",sensitivity)
print("spec ", specificity)
print("prec ", precision)
print("f1_score ", f1_score) 

statallfeatures_dic['Accuracy'].append(np.mean(acc_score))
statallfeatures_dic['Standard Error'].append(np.std(acc_score))
statallfeatures_dic['Sensitivity'].append(sensitivity)
statallfeatures_dic['Specificity'].append(specificity)
statallfeatures_dic['Precision'].append(precision)
statallfeatures_dic['F1_Score'].append(f1_score)

indaccs_dic['XGBoosting']=acc_score
# Out:
# 1.5.0
# C:\Users\hmche\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# roc_auc_score 0.8411894969946219
# C:\Users\hmche\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# roc_auc_score 0.8437679405421341
# C:\Users\hmche\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# roc_auc_score 0.8466278001235293
# C:\Users\hmche\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# roc_auc_score 0.8494155363002617
# C:\Users\hmche\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# roc_auc_score 0.85451197053407
# ---Run time is 4.3720936000026995 seconds ---
#
# Accuracy of each fold:
#  [0.769811320754717, 0.7886792452830189, 0.769811320754717, 0.7773584905660378, 0.77882797731569]
#
# Avg accuracy :
# 0.7768976709348361
#
# Std of accuracy :
# 0.006973903488416977
#
# Accuracy of each fold:
#  [0.769811320754717, 0.7886792452830189, 0.769811320754717, 0.7773584905660378, 0.77882797731569]
# Avg accuracy: 0.7768976709348361
# Std of accuracy :
# 0.006973903488416977
#
# [[ 639  338]
#  [ 253 1419]]
#
#               precision    recall  f1-score   support
#
#            0       0.72      0.65      0.68       977
#            1       0.81      0.85      0.83      1672
#
#     accuracy                           0.78      2649
#    macro avg       0.76      0.75      0.76      2649
# weighted avg       0.77      0.78      0.77      2649
#
# sens  0.654042988741044
# spec  0.8486842105263158
# prec  0.7163677130044843
# f1_score  0.6837881219903691
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [144], in <cell line: 88>()
#      85 print("prec ", precision)
#      86 print("f1_score ", f1_score)
# ---> 88 statallfeatures_dic['Accuracy'].append(np.mean(acc_score))
#      89 statallfeatures_dic['Standard Error'].append(np.std(acc_score))
#      90 statallfeatures_dic['Sensitivity'].append(sensitivity)
#
# NameError: name 'statallfeatures_dic' is not defined

# %%
# fixed for sens/spec
#THIS ISS FOR THE TESTING ONLY 
Truth2 = []
Output2 = []
testing = df2.iloc[:,-1]
model.fit(df.iloc[:,5:18],df.iloc[:,-1])
predicted = model.predict(df2.iloc[:,5:18])
acc = accuracy_score(testing, predicted)
Truth2.extend(testing.values.reshape(testing.shape[0])); ## it is a list
Output2.extend(predicted);
print(confusion_matrix(Truth2, Output2))
print()
print(classification_report(Truth2, Output2))

cm2 = confusion_matrix(Truth2, Output2)

sensitivity = cm2[0][0]/(cm2[0][0]+cm2[0][1])
specificity = cm2[1][1]/(cm2[1][0]+cm2[1][1])
precision = (cm2[0][0])/(cm2[0][0]+cm2[1][0])
f1_score = (2*precision*sensitivity)/(precision+sensitivity)
print("predicted",predicted)
print("acc",acc)
print("sens ",specificity) 
print("spec ", sensitivity) 
print("prec ", precision)
print("f1_score ", f1_score)
# Out:
# C:\Users\hmche\anaconda3\lib\site-packages\xgboost\data.py:250: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [[1424  664]
#  [1359  892]]
#
#               precision    recall  f1-score   support
#
#            0       0.51      0.68      0.58      2088
#            1       0.57      0.40      0.47      2251
#
#     accuracy                           0.53      4339
#    macro avg       0.54      0.54      0.53      4339
# weighted avg       0.54      0.53      0.52      4339
#
# predicted [1 1 1 ... 1 1 1]
# acc 0.5337635399861719
# sens  0.39626832518880495
# spec  0.6819923371647509
# prec  0.5116780452748833
# f1_score  0.584684869636625

# %%
tw= 0
tnw = 0
for i in predicted:
    if i == 1:
        tw += 1
    if i == 0:
        tnw += 1
print(tw)
print(tnw)
# Out:
# 1774
# 367

# %% [markdown]
# # Reference:
#
# https://lightgbm.readthedocs.io/en/latest/pythonapi/lightgbm.LGBMClassifier.html
#
# max_depth (int, optional (default=-1)) – Maximum tree depth for base learners, <=0 means no limit.
#
# learning_rate (float, optional (default=0.1)) – Boosting learning rate. You can use callbacks parameter of fit method to shrink/adapt learning rate in training using reset_parameter callback. Note, that this will ignore the learning_rate argument in training.
#
# n_estimators (int, optional (default=100)) – Number of boosted trees to fit.
#
# eval_metric (str, callable, list or None, optional (default=None)) – If str, it should be a built-in evaluation metric to use. If callable, it should be a custom evaluation metric, see note below for more details. If list, it can be a list of built-in metrics, a list of custom evaluation metrics, or a mix of both. In either case, the metric from the model parameters will be evaluated and used as well.
# Default: ‘l2’ for LGBMRegressor, **‘logloss’ for LGBMClassifier**, ‘ndcg’ for LGBMRanker.

# %%
# https://lightgbm.readthedocs.io/en/latest/pythonapi/lightgbm.LGBMClassifier.html
import lightgbm
random.seed(1000)
#Implementing cross validation 
kf = KFold(n_splits=5, random_state=1, shuffle=True)
model = lightgbm.LGBMClassifier(learning_rate=0.09,max_depth=-5,random_state=42)

from time import time
import timeit #imports timeit module
start_time = timeit.default_timer() #defines start time so computational time can be calculated

acc_score = [];
Truth = [];
Output = [];
 
for train_index , test_index in kf.split(df):
    
    X_train , X_test = df.iloc[train_index,5:18], df.iloc[test_index,5:18]
    Y_train , Y_test = df.iloc[train_index,-1], df.iloc[test_index,-1]
    
    # Create the LightGBM data containers
    model.fit(X_train,Y_train,eval_set=[(X_test,Y_test),(X_train,Y_train)],
          eval_metric='logloss')

    pred_values = model.predict(X_test)
     
    acc = accuracy_score(Y_test, pred_values)
    acc_score.append(acc)
    
    Truth.extend(Y_test.values.reshape(Y_test.shape[0])); ## it is a list
    Output.extend(pred_values); ## it is a list  
    
    #print(model.feature_importances_)
    Importance = pd.DataFrame({'Importance':(model.feature_importances_*100)[0:10]}, 
                          index = (X_train.columns)[0:10])
    Importance.sort_values(by = 'Importance', 
                       axis = 0, 
                       ascending = True).plot(kind = 'barh', 
                                              color = 'r')
    plt.xlabel('Variable Importance')
    plt.gca().legend_ = None
    #plt.savefig('plot1.png')


elapsed = timeit.default_timer() - start_time #gives total computation time
print("---Run time is %s seconds ---" % elapsed) #prints computation time
print()

print('Accuracy of each fold: \n {}'.format(acc_score))
print()
print('Avg accuracy : \n{}'.format(np.mean(acc_score))); 
print()
print('Std of accuracy : \n{}'.format(np.std(acc_score)))
#start here

print()
print('Accuracy of each fold: \n {}'.format(acc_score))
print("Avg accuracy: {}".format(np.mean(acc_score)))
print('Std of accuracy : \n{}'.format(np.std(acc_score)))
print()
print(confusion_matrix(Truth, Output))
print()
print(classification_report(Truth, Output))

cm = confusion_matrix(Truth, Output)

sensitivity = cm[0][0]/(cm[0][0]+cm[0][1])
specificity = cm[1][1]/(cm[1][0]+cm[1][1])
precision = (cm[0][0])/(cm[0][0]+cm[1][0])
f1_score = (2*precision*sensitivity)/(precision+sensitivity)

print("sens ",sensitivity)
print("spec ", specificity)
print("prec ", precision)
print("f1_score ", f1_score)

statallfeatures_dic['Accuracy'].append(np.mean(acc_score))
statallfeatures_dic['Standard Error'].append(np.std(acc_score))
statallfeatures_dic['Sensitivity'].append(sensitivity)
statallfeatures_dic['Specificity'].append(specificity)
statallfeatures_dic['Precision'].append(precision)
statallfeatures_dic['F1_Score'].append(f1_score)

indaccs_dic['LogReg']=acc_score
# Out:
# [1]	training's binary_logloss: 0.66859	valid_0's binary_logloss: 0.676304
# [2]	training's binary_logloss: 0.648127	valid_0's binary_logloss: 0.662072
# [3]	training's binary_logloss: 0.630771	valid_0's binary_logloss: 0.650296
# [4]	training's binary_logloss: 0.615183	valid_0's binary_logloss: 0.640509
# [5]	training's binary_logloss: 0.601424	valid_0's binary_logloss: 0.631712
# [6]	training's binary_logloss: 0.589587	valid_0's binary_logloss: 0.624349
# [7]	training's binary_logloss: 0.578811	valid_0's binary_logloss: 0.618102
# [8]	training's binary_logloss: 0.569133	valid_0's binary_logloss: 0.613137
# [9]	training's binary_logloss: 0.560736	valid_0's binary_logloss: 0.609465
# [10]	training's binary_logloss: 0.55292	valid_0's binary_logloss: 0.605083
# [11]	training's binary_logloss: 0.54537	valid_0's binary_logloss: 0.601173
# [12]	training's binary_logloss: 0.538556	valid_0's binary_logloss: 0.597931
# [13]	training's binary_logloss: 0.532547	valid_0's binary_logloss: 0.59544
# [14]	training's binary_logloss: 0.526927	valid_0's binary_logloss: 0.593857
# [15]	training's binary_logloss: 0.521421	valid_0's binary_logloss: 0.592883
# [16]	training's binary_logloss: 0.516058	valid_0's binary_logloss: 0.591865
# [17]	training's binary_logloss: 0.511148	valid_0's binary_logloss: 0.589923
# [18]	training's binary_logloss: 0.50654	valid_0's binary_logloss: 0.588954
# [19]	training's binary_logloss: 0.502165	valid_0's binary_logloss: 0.588681
# [20]	training's binary_logloss: 0.498044	valid_0's binary_logloss: 0.588086
# [21]	training's binary_logloss: 0.493947	valid_0's binary_logloss: 0.586898
# [22]	training's binary_logloss: 0.490001	valid_0's binary_logloss: 0.586353
# [23]	training's binary_logloss: 0.486361	valid_0's binary_logloss: 0.586272
# [24]	training's binary_logloss: 0.482687	valid_0's binary_logloss: 0.586503
# [25]	training's binary_logloss: 0.479673	valid_0's binary_logloss: 0.585936
# [26]	training's binary_logloss: 0.476328	valid_0's binary_logloss: 0.585779
# [27]	training's binary_logloss: 0.473065	valid_0's binary_logloss: 0.585907
# [28]	training's binary_logloss: 0.469861	valid_0's binary_logloss: 0.585838
# [29]	training's binary_logloss: 0.466576	valid_0's binary_logloss: 0.586227
# [30]	training's binary_logloss: 0.463646	valid_0's binary_logloss: 0.585415
# [31]	training's binary_logloss: 0.460742	valid_0's binary_logloss: 0.586246
# [32]	training's binary_logloss: 0.457667	valid_0's binary_logloss: 0.587581
# [33]	training's binary_logloss: 0.454751	valid_0's binary_logloss: 0.587936
# [34]	training's binary_logloss: 0.452222	valid_0's binary_logloss: 0.587991
# [35]	training's binary_logloss: 0.449615	valid_0's binary_logloss: 0.588707
# [36]	training's binary_logloss: 0.447352	valid_0's binary_logloss: 0.588664
# [37]	training's binary_logloss: 0.444893	valid_0's binary_logloss: 0.589184
# [38]	training's binary_logloss: 0.44279	valid_0's binary_logloss: 0.589861
# [39]	training's binary_logloss: 0.440929	valid_0's binary_logloss: 0.589825
# [40]	training's binary_logloss: 0.43871	valid_0's binary_logloss: 0.589383
# [41]	training's binary_logloss: 0.436219	valid_0's binary_logloss: 0.590159
# [42]	training's binary_logloss: 0.433832	valid_0's binary_logloss: 0.590501
# [43]	training's binary_logloss: 0.431564	valid_0's binary_logloss: 0.591943
# [44]	training's binary_logloss: 0.429432	valid_0's binary_logloss: 0.592957
# [45]	training's binary_logloss: 0.427222	valid_0's binary_logloss: 0.594146
# [46]	training's binary_logloss: 0.425001	valid_0's binary_logloss: 0.594575
# [47]	training's binary_logloss: 0.422926	valid_0's binary_logloss: 0.595477
# [48]	training's binary_logloss: 0.421033	valid_0's binary_logloss: 0.59659
# [49]	training's binary_logloss: 0.419367	valid_0's binary_logloss: 0.596418
# [50]	training's binary_logloss: 0.417616	valid_0's binary_logloss: 0.597475
# [51]	training's binary_logloss: 0.415806	valid_0's binary_logloss: 0.59825
# [52]	training's binary_logloss: 0.413442	valid_0's binary_logloss: 0.598203
# [53]	training's binary_logloss: 0.411554	valid_0's binary_logloss: 0.599479
# [54]	training's binary_logloss: 0.409597	valid_0's binary_logloss: 0.60072
# [55]	training's binary_logloss: 0.407904	valid_0's binary_logloss: 0.601022
# [56]	training's binary_logloss: 0.406175	valid_0's binary_logloss: 0.601759
# [57]	training's binary_logloss: 0.404572	valid_0's binary_logloss: 0.602764
# [58]	training's binary_logloss: 0.403058	valid_0's binary_logloss: 0.603825
# [59]	training's binary_logloss: 0.401431	valid_0's binary_logloss: 0.60444
# [60]	training's binary_logloss: 0.399795	valid_0's binary_logloss: 0.605548
# [61]	training's binary_logloss: 0.398409	valid_0's binary_logloss: 0.605604
# [62]	training's binary_logloss: 0.396701	valid_0's binary_logloss: 0.60684
# [63]	training's binary_logloss: 0.394794	valid_0's binary_logloss: 0.607736
# [64]	training's binary_logloss: 0.393199	valid_0's binary_logloss: 0.608529
# [65]	training's binary_logloss: 0.391618	valid_0's binary_logloss: 0.609808
# [66]	training's binary_logloss: 0.390353	valid_0's binary_logloss: 0.611378
# [67]	training's binary_logloss: 0.388965	valid_0's binary_logloss: 0.612268
# [68]	training's binary_logloss: 0.387498	valid_0's binary_logloss: 0.612626
# [69]	training's binary_logloss: 0.385816	valid_0's binary_logloss: 0.612732
# [70]	training's binary_logloss: 0.384491	valid_0's binary_logloss: 0.613667
# [71]	training's binary_logloss: 0.383221	valid_0's binary_logloss: 0.613578
# [72]	training's binary_logloss: 0.382038	valid_0's binary_logloss: 0.614724
# [73]	training's binary_logloss: 0.380748	valid_0's binary_logloss: 0.615363
# [74]	training's binary_logloss: 0.378857	valid_0's binary_logloss: 0.615932
# [75]	training's binary_logloss: 0.376501	valid_0's binary_logloss: 0.617437
# [76]	training's binary_logloss: 0.375332	valid_0's binary_logloss: 0.617391
# [77]	training's binary_logloss: 0.373425	valid_0's binary_logloss: 0.618058
# [78]	training's binary_logloss: 0.371015	valid_0's binary_logloss: 0.618908
# [79]	training's binary_logloss: 0.369225	valid_0's binary_logloss: 0.619392
# [80]	training's binary_logloss: 0.367886	valid_0's binary_logloss: 0.619423
# [81]	training's binary_logloss: 0.366573	valid_0's binary_logloss: 0.620366
# [82]	training's binary_logloss: 0.364879	valid_0's binary_logloss: 0.620351
# [83]	training's binary_logloss: 0.362743	valid_0's binary_logloss: 0.621926
# [84]	training's binary_logloss: 0.361092	valid_0's binary_logloss: 0.621903
# [85]	training's binary_logloss: 0.359902	valid_0's binary_logloss: 0.62329
# [86]	training's binary_logloss: 0.358703	valid_0's binary_logloss: 0.624351
# [87]	training's binary_logloss: 0.357404	valid_0's binary_logloss: 0.625234
# [88]	training's binary_logloss: 0.355706	valid_0's binary_logloss: 0.625454
# [89]	training's binary_logloss: 0.35344	valid_0's binary_logloss: 0.627722
# [90]	training's binary_logloss: 0.351969	valid_0's binary_logloss: 0.628369
# [91]	training's binary_logloss: 0.350995	valid_0's binary_logloss: 0.628413
# [92]	training's binary_logloss: 0.348711	valid_0's binary_logloss: 0.627
# [93]	training's binary_logloss: 0.346561	valid_0's binary_logloss: 0.627506
# [94]	training's binary_logloss: 0.345253	valid_0's binary_logloss: 0.627597
# [95]	training's binary_logloss: 0.344162	valid_0's binary_logloss: 0.628751
# [96]	training's binary_logloss: 0.342103	valid_0's binary_logloss: 0.629272
# [97]	training's binary_logloss: 0.341035	valid_0's binary_logloss: 0.629597
# [98]	training's binary_logloss: 0.339946	valid_0's binary_logloss: 0.629971
# [99]	training's binary_logloss: 0.33903	valid_0's binary_logloss: 0.630973
# [100]	training's binary_logloss: 0.337632	valid_0's binary_logloss: 0.632109
# [1]	training's binary_logloss: 0.66974	valid_0's binary_logloss: 0.673131
# [2]	training's binary_logloss: 0.649661	valid_0's binary_logloss: 0.658787
# [3]	training's binary_logloss: 0.632642	valid_0's binary_logloss: 0.646341
# [4]	training's binary_logloss: 0.617172	valid_0's binary_logloss: 0.635169
# [5]	training's binary_logloss: 0.603545	valid_0's binary_logloss: 0.625968
# [6]	training's binary_logloss: 0.591157	valid_0's binary_logloss: 0.618306
# [7]	training's binary_logloss: 0.579938	valid_0's binary_logloss: 0.610752
# [8]	training's binary_logloss: 0.57045	valid_0's binary_logloss: 0.605504
# [9]	training's binary_logloss: 0.561631	valid_0's binary_logloss: 0.601422
# [10]	training's binary_logloss: 0.553576	valid_0's binary_logloss: 0.597482
# [11]	training's binary_logloss: 0.546203	valid_0's binary_logloss: 0.594793
# [12]	training's binary_logloss: 0.53917	valid_0's binary_logloss: 0.592073
# [13]	training's binary_logloss: 0.532952	valid_0's binary_logloss: 0.590078
# [14]	training's binary_logloss: 0.527267	valid_0's binary_logloss: 0.588368
# [15]	training's binary_logloss: 0.521591	valid_0's binary_logloss: 0.587269
# [16]	training's binary_logloss: 0.516348	valid_0's binary_logloss: 0.585769
# [17]	training's binary_logloss: 0.51144	valid_0's binary_logloss: 0.584406
# [18]	training's binary_logloss: 0.506522	valid_0's binary_logloss: 0.584318
# [19]	training's binary_logloss: 0.502185	valid_0's binary_logloss: 0.584152
# [20]	training's binary_logloss: 0.49798	valid_0's binary_logloss: 0.58263
# [21]	training's binary_logloss: 0.494098	valid_0's binary_logloss: 0.58368
# [22]	training's binary_logloss: 0.490315	valid_0's binary_logloss: 0.583304
# [23]	training's binary_logloss: 0.486635	valid_0's binary_logloss: 0.583464
# [24]	training's binary_logloss: 0.483011	valid_0's binary_logloss: 0.583559
# [25]	training's binary_logloss: 0.479543	valid_0's binary_logloss: 0.582927
# [26]	training's binary_logloss: 0.47637	valid_0's binary_logloss: 0.583528
# [27]	training's binary_logloss: 0.47288	valid_0's binary_logloss: 0.583642
# [28]	training's binary_logloss: 0.469376	valid_0's binary_logloss: 0.583523
# [29]	training's binary_logloss: 0.466622	valid_0's binary_logloss: 0.584366
# [30]	training's binary_logloss: 0.46349	valid_0's binary_logloss: 0.584632
# [31]	training's binary_logloss: 0.46071	valid_0's binary_logloss: 0.583906
# [32]	training's binary_logloss: 0.458135	valid_0's binary_logloss: 0.583867
# [33]	training's binary_logloss: 0.455393	valid_0's binary_logloss: 0.584528
# [34]	training's binary_logloss: 0.452508	valid_0's binary_logloss: 0.584595
# [35]	training's binary_logloss: 0.450402	valid_0's binary_logloss: 0.584097
# [36]	training's binary_logloss: 0.447252	valid_0's binary_logloss: 0.584243
# [37]	training's binary_logloss: 0.444871	valid_0's binary_logloss: 0.583844
# [38]	training's binary_logloss: 0.442431	valid_0's binary_logloss: 0.584132
# [39]	training's binary_logloss: 0.440357	valid_0's binary_logloss: 0.584331
# [40]	training's binary_logloss: 0.437902	valid_0's binary_logloss: 0.584963
# [41]	training's binary_logloss: 0.43588	valid_0's binary_logloss: 0.585643
# [42]	training's binary_logloss: 0.434079	valid_0's binary_logloss: 0.586138
# [43]	training's binary_logloss: 0.431893	valid_0's binary_logloss: 0.587175
# [44]	training's binary_logloss: 0.430141	valid_0's binary_logloss: 0.587856
# [45]	training's binary_logloss: 0.427746	valid_0's binary_logloss: 0.58887
# [46]	training's binary_logloss: 0.426068	valid_0's binary_logloss: 0.590266
# [47]	training's binary_logloss: 0.423845	valid_0's binary_logloss: 0.591036
# [48]	training's binary_logloss: 0.422067	valid_0's binary_logloss: 0.591657
# [49]	training's binary_logloss: 0.419875	valid_0's binary_logloss: 0.592671
# [50]	training's binary_logloss: 0.418095	valid_0's binary_logloss: 0.593036
# [51]	training's binary_logloss: 0.416389	valid_0's binary_logloss: 0.592938
# [52]	training's binary_logloss: 0.414415	valid_0's binary_logloss: 0.591916
# [53]	training's binary_logloss: 0.412814	valid_0's binary_logloss: 0.592032
# [54]	training's binary_logloss: 0.411208	valid_0's binary_logloss: 0.592332
# [55]	training's binary_logloss: 0.409668	valid_0's binary_logloss: 0.593017
# [56]	training's binary_logloss: 0.40744	valid_0's binary_logloss: 0.594214
# [57]	training's binary_logloss: 0.405803	valid_0's binary_logloss: 0.595575
# [58]	training's binary_logloss: 0.403875	valid_0's binary_logloss: 0.596929
# [59]	training's binary_logloss: 0.401128	valid_0's binary_logloss: 0.597616
# [60]	training's binary_logloss: 0.398905	valid_0's binary_logloss: 0.598361
# [61]	training's binary_logloss: 0.396441	valid_0's binary_logloss: 0.598557
# [62]	training's binary_logloss: 0.394951	valid_0's binary_logloss: 0.599612
# [63]	training's binary_logloss: 0.393291	valid_0's binary_logloss: 0.600434
# [64]	training's binary_logloss: 0.39181	valid_0's binary_logloss: 0.60111
# [65]	training's binary_logloss: 0.389627	valid_0's binary_logloss: 0.601179
# [66]	training's binary_logloss: 0.388303	valid_0's binary_logloss: 0.601036
# [67]	training's binary_logloss: 0.386757	valid_0's binary_logloss: 0.60142
# [68]	training's binary_logloss: 0.384613	valid_0's binary_logloss: 0.602039
# [69]	training's binary_logloss: 0.383147	valid_0's binary_logloss: 0.602881
# [70]	training's binary_logloss: 0.381575	valid_0's binary_logloss: 0.603177
# [71]	training's binary_logloss: 0.379876	valid_0's binary_logloss: 0.603448
# [72]	training's binary_logloss: 0.378466	valid_0's binary_logloss: 0.604009
# [73]	training's binary_logloss: 0.376919	valid_0's binary_logloss: 0.604026
# [74]	training's binary_logloss: 0.374848	valid_0's binary_logloss: 0.603217
# [75]	training's binary_logloss: 0.373102	valid_0's binary_logloss: 0.603475
# [76]	training's binary_logloss: 0.370887	valid_0's binary_logloss: 0.603614
# [77]	training's binary_logloss: 0.36951	valid_0's binary_logloss: 0.6037
# [78]	training's binary_logloss: 0.367622	valid_0's binary_logloss: 0.604784
# [79]	training's binary_logloss: 0.366294	valid_0's binary_logloss: 0.605444
# [80]	training's binary_logloss: 0.364637	valid_0's binary_logloss: 0.606223
# [81]	training's binary_logloss: 0.363489	valid_0's binary_logloss: 0.606346
# [82]	training's binary_logloss: 0.361443	valid_0's binary_logloss: 0.60639
# [83]	training's binary_logloss: 0.359738	valid_0's binary_logloss: 0.606416
# [84]	training's binary_logloss: 0.358688	valid_0's binary_logloss: 0.607161
# [85]	training's binary_logloss: 0.357303	valid_0's binary_logloss: 0.607134
# [86]	training's binary_logloss: 0.356226	valid_0's binary_logloss: 0.607623
# [87]	training's binary_logloss: 0.354741	valid_0's binary_logloss: 0.607858
# [88]	training's binary_logloss: 0.353649	valid_0's binary_logloss: 0.608273
# [89]	training's binary_logloss: 0.352199	valid_0's binary_logloss: 0.609004
# [90]	training's binary_logloss: 0.349853	valid_0's binary_logloss: 0.609314
# [91]	training's binary_logloss: 0.348043	valid_0's binary_logloss: 0.609222
# [92]	training's binary_logloss: 0.346871	valid_0's binary_logloss: 0.609564
# [93]	training's binary_logloss: 0.346041	valid_0's binary_logloss: 0.610109
# [94]	training's binary_logloss: 0.344803	valid_0's binary_logloss: 0.611241
# [95]	training's binary_logloss: 0.343916	valid_0's binary_logloss: 0.611672
# [96]	training's binary_logloss: 0.342111	valid_0's binary_logloss: 0.611376
# [97]	training's binary_logloss: 0.341102	valid_0's binary_logloss: 0.61212
# [98]	training's binary_logloss: 0.339956	valid_0's binary_logloss: 0.612619
# [99]	training's binary_logloss: 0.337722	valid_0's binary_logloss: 0.612839
# [100]	training's binary_logloss: 0.336689	valid_0's binary_logloss: 0.613196
# [1]	training's binary_logloss: 0.66897	valid_0's binary_logloss: 0.675186
# [2]	training's binary_logloss: 0.648761	valid_0's binary_logloss: 0.66198
# [3]	training's binary_logloss: 0.631804	valid_0's binary_logloss: 0.650901
# [4]	training's binary_logloss: 0.616396	valid_0's binary_logloss: 0.639814
# [5]	training's binary_logloss: 0.602932	valid_0's binary_logloss: 0.631136
# [6]	training's binary_logloss: 0.590814	valid_0's binary_logloss: 0.625234
# [7]	training's binary_logloss: 0.580151	valid_0's binary_logloss: 0.620225
# [8]	training's binary_logloss: 0.570461	valid_0's binary_logloss: 0.614369
# [9]	training's binary_logloss: 0.561975	valid_0's binary_logloss: 0.609133
# [10]	training's binary_logloss: 0.55403	valid_0's binary_logloss: 0.606408
# [11]	training's binary_logloss: 0.546586	valid_0's binary_logloss: 0.603398
# [12]	training's binary_logloss: 0.540031	valid_0's binary_logloss: 0.600948
# [13]	training's binary_logloss: 0.53384	valid_0's binary_logloss: 0.598619
# [14]	training's binary_logloss: 0.527842	valid_0's binary_logloss: 0.59681
# [15]	training's binary_logloss: 0.522353	valid_0's binary_logloss: 0.596169
# [16]	training's binary_logloss: 0.517261	valid_0's binary_logloss: 0.59392
# [17]	training's binary_logloss: 0.512418	valid_0's binary_logloss: 0.592752
# [18]	training's binary_logloss: 0.507959	valid_0's binary_logloss: 0.592323
# [19]	training's binary_logloss: 0.503742	valid_0's binary_logloss: 0.591193
# [20]	training's binary_logloss: 0.500027	valid_0's binary_logloss: 0.590591
# [21]	training's binary_logloss: 0.496048	valid_0's binary_logloss: 0.589982
# [22]	training's binary_logloss: 0.4923	valid_0's binary_logloss: 0.589464
# [23]	training's binary_logloss: 0.488462	valid_0's binary_logloss: 0.588791
# [24]	training's binary_logloss: 0.484607	valid_0's binary_logloss: 0.588537
# [25]	training's binary_logloss: 0.481242	valid_0's binary_logloss: 0.5878
# [26]	training's binary_logloss: 0.47772	valid_0's binary_logloss: 0.587668
# [27]	training's binary_logloss: 0.474325	valid_0's binary_logloss: 0.587661
# [28]	training's binary_logloss: 0.471266	valid_0's binary_logloss: 0.587008
# [29]	training's binary_logloss: 0.468235	valid_0's binary_logloss: 0.586437
# [30]	training's binary_logloss: 0.465087	valid_0's binary_logloss: 0.586872
# [31]	training's binary_logloss: 0.462443	valid_0's binary_logloss: 0.587522
# [32]	training's binary_logloss: 0.459824	valid_0's binary_logloss: 0.587368
# [33]	training's binary_logloss: 0.457111	valid_0's binary_logloss: 0.587527
# [34]	training's binary_logloss: 0.454331	valid_0's binary_logloss: 0.588039
# [35]	training's binary_logloss: 0.451725	valid_0's binary_logloss: 0.587666
# [36]	training's binary_logloss: 0.449178	valid_0's binary_logloss: 0.587399
# [37]	training's binary_logloss: 0.446439	valid_0's binary_logloss: 0.588027
# [38]	training's binary_logloss: 0.444125	valid_0's binary_logloss: 0.588719
# [39]	training's binary_logloss: 0.441535	valid_0's binary_logloss: 0.589346
# [40]	training's binary_logloss: 0.439149	valid_0's binary_logloss: 0.590114
# [41]	training's binary_logloss: 0.436875	valid_0's binary_logloss: 0.590538
# [42]	training's binary_logloss: 0.43491	valid_0's binary_logloss: 0.591459
# [43]	training's binary_logloss: 0.432616	valid_0's binary_logloss: 0.591627
# [44]	training's binary_logloss: 0.430699	valid_0's binary_logloss: 0.591941
# [45]	training's binary_logloss: 0.42844	valid_0's binary_logloss: 0.592797
# [46]	training's binary_logloss: 0.42627	valid_0's binary_logloss: 0.592271
# [47]	training's binary_logloss: 0.424092	valid_0's binary_logloss: 0.592486
# [48]	training's binary_logloss: 0.422384	valid_0's binary_logloss: 0.59213
# [49]	training's binary_logloss: 0.420383	valid_0's binary_logloss: 0.592967
# [50]	training's binary_logloss: 0.418467	valid_0's binary_logloss: 0.593228
# [51]	training's binary_logloss: 0.416564	valid_0's binary_logloss: 0.593911
# [52]	training's binary_logloss: 0.414702	valid_0's binary_logloss: 0.594708
# [53]	training's binary_logloss: 0.412833	valid_0's binary_logloss: 0.596069
# [54]	training's binary_logloss: 0.411099	valid_0's binary_logloss: 0.596534
# [55]	training's binary_logloss: 0.409334	valid_0's binary_logloss: 0.597657
# [56]	training's binary_logloss: 0.407218	valid_0's binary_logloss: 0.597525
# [57]	training's binary_logloss: 0.405658	valid_0's binary_logloss: 0.598107
# [58]	training's binary_logloss: 0.404132	valid_0's binary_logloss: 0.599112
# [59]	training's binary_logloss: 0.402239	valid_0's binary_logloss: 0.600757
# [60]	training's binary_logloss: 0.400572	valid_0's binary_logloss: 0.601225
# [61]	training's binary_logloss: 0.398971	valid_0's binary_logloss: 0.601274
# [62]	training's binary_logloss: 0.397152	valid_0's binary_logloss: 0.602474
# [63]	training's binary_logloss: 0.395754	valid_0's binary_logloss: 0.602142
# [64]	training's binary_logloss: 0.39421	valid_0's binary_logloss: 0.602499
# [65]	training's binary_logloss: 0.392574	valid_0's binary_logloss: 0.602987
# [66]	training's binary_logloss: 0.390939	valid_0's binary_logloss: 0.60378
# [67]	training's binary_logloss: 0.389504	valid_0's binary_logloss: 0.603945
# [68]	training's binary_logloss: 0.387892	valid_0's binary_logloss: 0.60485
# [69]	training's binary_logloss: 0.386516	valid_0's binary_logloss: 0.604827
# [70]	training's binary_logloss: 0.383794	valid_0's binary_logloss: 0.605725
# [71]	training's binary_logloss: 0.382465	valid_0's binary_logloss: 0.60669
# [72]	training's binary_logloss: 0.381413	valid_0's binary_logloss: 0.606887
# [73]	training's binary_logloss: 0.380114	valid_0's binary_logloss: 0.607645
# [74]	training's binary_logloss: 0.378849	valid_0's binary_logloss: 0.608823
# [75]	training's binary_logloss: 0.37655	valid_0's binary_logloss: 0.609512
# [76]	training's binary_logloss: 0.374997	valid_0's binary_logloss: 0.609934
# [77]	training's binary_logloss: 0.372967	valid_0's binary_logloss: 0.610219
# [78]	training's binary_logloss: 0.371133	valid_0's binary_logloss: 0.610732
# [79]	training's binary_logloss: 0.36975	valid_0's binary_logloss: 0.610906
# [80]	training's binary_logloss: 0.368374	valid_0's binary_logloss: 0.610891
# [81]	training's binary_logloss: 0.366197	valid_0's binary_logloss: 0.611736
# [82]	training's binary_logloss: 0.364919	valid_0's binary_logloss: 0.612401
# [83]	training's binary_logloss: 0.363724	valid_0's binary_logloss: 0.612983
# [84]	training's binary_logloss: 0.362005	valid_0's binary_logloss: 0.613486
# [85]	training's binary_logloss: 0.359741	valid_0's binary_logloss: 0.61394
# [86]	training's binary_logloss: 0.358339	valid_0's binary_logloss: 0.614227
# [87]	training's binary_logloss: 0.35642	valid_0's binary_logloss: 0.614694
# [88]	training's binary_logloss: 0.354979	valid_0's binary_logloss: 0.615818
# [89]	training's binary_logloss: 0.352972	valid_0's binary_logloss: 0.617406
# [90]	training's binary_logloss: 0.351907	valid_0's binary_logloss: 0.617843
# [91]	training's binary_logloss: 0.350727	valid_0's binary_logloss: 0.61857
# [92]	training's binary_logloss: 0.348666	valid_0's binary_logloss: 0.618552
# [93]	training's binary_logloss: 0.347486	valid_0's binary_logloss: 0.618872
# [94]	training's binary_logloss: 0.345837	valid_0's binary_logloss: 0.619625
# [95]	training's binary_logloss: 0.343427	valid_0's binary_logloss: 0.620115
# [96]	training's binary_logloss: 0.342217	valid_0's binary_logloss: 0.62126
# [97]	training's binary_logloss: 0.34018	valid_0's binary_logloss: 0.621366
# [98]	training's binary_logloss: 0.338433	valid_0's binary_logloss: 0.622269
# [99]	training's binary_logloss: 0.336862	valid_0's binary_logloss: 0.622639
# [100]	training's binary_logloss: 0.33556	valid_0's binary_logloss: 0.622951
# [1]	training's binary_logloss: 0.669915	valid_0's binary_logloss: 0.672915
# [2]	training's binary_logloss: 0.650582	valid_0's binary_logloss: 0.656594
# [3]	training's binary_logloss: 0.633748	valid_0's binary_logloss: 0.64182
# [4]	training's binary_logloss: 0.619349	valid_0's binary_logloss: 0.630616
# [5]	training's binary_logloss: 0.606526	valid_0's binary_logloss: 0.619537
# [6]	training's binary_logloss: 0.595496	valid_0's binary_logloss: 0.609819
# [7]	training's binary_logloss: 0.585377	valid_0's binary_logloss: 0.602432
# [8]	training's binary_logloss: 0.576056	valid_0's binary_logloss: 0.596221
# [9]	training's binary_logloss: 0.567709	valid_0's binary_logloss: 0.591709
# [10]	training's binary_logloss: 0.559964	valid_0's binary_logloss: 0.587258
# [11]	training's binary_logloss: 0.552889	valid_0's binary_logloss: 0.583022
# [12]	training's binary_logloss: 0.545611	valid_0's binary_logloss: 0.579519
# [13]	training's binary_logloss: 0.539301	valid_0's binary_logloss: 0.575329
# [14]	training's binary_logloss: 0.533645	valid_0's binary_logloss: 0.573241
# [15]	training's binary_logloss: 0.528176	valid_0's binary_logloss: 0.570581
# [16]	training's binary_logloss: 0.52298	valid_0's binary_logloss: 0.568694
# [17]	training's binary_logloss: 0.517613	valid_0's binary_logloss: 0.566861
# [18]	training's binary_logloss: 0.51319	valid_0's binary_logloss: 0.565412
# [19]	training's binary_logloss: 0.508983	valid_0's binary_logloss: 0.564195
# [20]	training's binary_logloss: 0.50443	valid_0's binary_logloss: 0.563173
# [21]	training's binary_logloss: 0.500392	valid_0's binary_logloss: 0.562327
# [22]	training's binary_logloss: 0.496323	valid_0's binary_logloss: 0.56165
# [23]	training's binary_logloss: 0.49258	valid_0's binary_logloss: 0.56073
# [24]	training's binary_logloss: 0.488935	valid_0's binary_logloss: 0.560155
# [25]	training's binary_logloss: 0.4858	valid_0's binary_logloss: 0.560163
# [26]	training's binary_logloss: 0.482081	valid_0's binary_logloss: 0.559998
# [27]	training's binary_logloss: 0.479	valid_0's binary_logloss: 0.560321
# [28]	training's binary_logloss: 0.475904	valid_0's binary_logloss: 0.560078
# [29]	training's binary_logloss: 0.473044	valid_0's binary_logloss: 0.560275
# [30]	training's binary_logloss: 0.46976	valid_0's binary_logloss: 0.561089
# [31]	training's binary_logloss: 0.466808	valid_0's binary_logloss: 0.561107
# [32]	training's binary_logloss: 0.464508	valid_0's binary_logloss: 0.561343
# [33]	training's binary_logloss: 0.462004	valid_0's binary_logloss: 0.561398
# [34]	training's binary_logloss: 0.459138	valid_0's binary_logloss: 0.562252
# [35]	training's binary_logloss: 0.456635	valid_0's binary_logloss: 0.562254
# [36]	training's binary_logloss: 0.454218	valid_0's binary_logloss: 0.562876
# [37]	training's binary_logloss: 0.451459	valid_0's binary_logloss: 0.56281
# [38]	training's binary_logloss: 0.449412	valid_0's binary_logloss: 0.563343
# [39]	training's binary_logloss: 0.447229	valid_0's binary_logloss: 0.563854
# [40]	training's binary_logloss: 0.445134	valid_0's binary_logloss: 0.56277
# [41]	training's binary_logloss: 0.442497	valid_0's binary_logloss: 0.562292
# [42]	training's binary_logloss: 0.440546	valid_0's binary_logloss: 0.562068
# [43]	training's binary_logloss: 0.438033	valid_0's binary_logloss: 0.562219
# [44]	training's binary_logloss: 0.435635	valid_0's binary_logloss: 0.563042
# [45]	training's binary_logloss: 0.433636	valid_0's binary_logloss: 0.564059
# [46]	training's binary_logloss: 0.431405	valid_0's binary_logloss: 0.564704
# [47]	training's binary_logloss: 0.429111	valid_0's binary_logloss: 0.564736
# [48]	training's binary_logloss: 0.427086	valid_0's binary_logloss: 0.565296
# [49]	training's binary_logloss: 0.424915	valid_0's binary_logloss: 0.565697
# [50]	training's binary_logloss: 0.422905	valid_0's binary_logloss: 0.566086
# [51]	training's binary_logloss: 0.421212	valid_0's binary_logloss: 0.566471
# [52]	training's binary_logloss: 0.419512	valid_0's binary_logloss: 0.567399
# [53]	training's binary_logloss: 0.416538	valid_0's binary_logloss: 0.567316
# [54]	training's binary_logloss: 0.414799	valid_0's binary_logloss: 0.568301
# [55]	training's binary_logloss: 0.412899	valid_0's binary_logloss: 0.568763
# [56]	training's binary_logloss: 0.411233	valid_0's binary_logloss: 0.567952
# [57]	training's binary_logloss: 0.409695	valid_0's binary_logloss: 0.568012
# [58]	training's binary_logloss: 0.408134	valid_0's binary_logloss: 0.567665
# [59]	training's binary_logloss: 0.406699	valid_0's binary_logloss: 0.567785
# [60]	training's binary_logloss: 0.405077	valid_0's binary_logloss: 0.567964
# [61]	training's binary_logloss: 0.403604	valid_0's binary_logloss: 0.568014
# [62]	training's binary_logloss: 0.402092	valid_0's binary_logloss: 0.567874
# [63]	training's binary_logloss: 0.400215	valid_0's binary_logloss: 0.568129
# [64]	training's binary_logloss: 0.398071	valid_0's binary_logloss: 0.567957
# [65]	training's binary_logloss: 0.395832	valid_0's binary_logloss: 0.567998
# [66]	training's binary_logloss: 0.393193	valid_0's binary_logloss: 0.568609
# [67]	training's binary_logloss: 0.391791	valid_0's binary_logloss: 0.569279
# [68]	training's binary_logloss: 0.389954	valid_0's binary_logloss: 0.569256
# [69]	training's binary_logloss: 0.388606	valid_0's binary_logloss: 0.568677
# [70]	training's binary_logloss: 0.386978	valid_0's binary_logloss: 0.569372
# [71]	training's binary_logloss: 0.385658	valid_0's binary_logloss: 0.569604
# [72]	training's binary_logloss: 0.384209	valid_0's binary_logloss: 0.569555
# [73]	training's binary_logloss: 0.383106	valid_0's binary_logloss: 0.569246
# [74]	training's binary_logloss: 0.381628	valid_0's binary_logloss: 0.569462
# [75]	training's binary_logloss: 0.380415	valid_0's binary_logloss: 0.569086
# [76]	training's binary_logloss: 0.378606	valid_0's binary_logloss: 0.569132
# [77]	training's binary_logloss: 0.377305	valid_0's binary_logloss: 0.568787
# [78]	training's binary_logloss: 0.375953	valid_0's binary_logloss: 0.568489
# [79]	training's binary_logloss: 0.374694	valid_0's binary_logloss: 0.568502
# [80]	training's binary_logloss: 0.373339	valid_0's binary_logloss: 0.56875
# [81]	training's binary_logloss: 0.371204	valid_0's binary_logloss: 0.568763
# [82]	training's binary_logloss: 0.369036	valid_0's binary_logloss: 0.568455
# [83]	training's binary_logloss: 0.367026	valid_0's binary_logloss: 0.568859
# [84]	training's binary_logloss: 0.365901	valid_0's binary_logloss: 0.568457
# [85]	training's binary_logloss: 0.364866	valid_0's binary_logloss: 0.568957
# [86]	training's binary_logloss: 0.363187	valid_0's binary_logloss: 0.569109
# [87]	training's binary_logloss: 0.361493	valid_0's binary_logloss: 0.569489
# [88]	training's binary_logloss: 0.360463	valid_0's binary_logloss: 0.569503
# [89]	training's binary_logloss: 0.359178	valid_0's binary_logloss: 0.569204
# [90]	training's binary_logloss: 0.357017	valid_0's binary_logloss: 0.571147
# [91]	training's binary_logloss: 0.354769	valid_0's binary_logloss: 0.571487
# [92]	training's binary_logloss: 0.35301	valid_0's binary_logloss: 0.571785
# [93]	training's binary_logloss: 0.350929	valid_0's binary_logloss: 0.572505
# [94]	training's binary_logloss: 0.34964	valid_0's binary_logloss: 0.573585
# [95]	training's binary_logloss: 0.348216	valid_0's binary_logloss: 0.573075
# [96]	training's binary_logloss: 0.346911	valid_0's binary_logloss: 0.573755
# [97]	training's binary_logloss: 0.345947	valid_0's binary_logloss: 0.573787
# [98]	training's binary_logloss: 0.344828	valid_0's binary_logloss: 0.573953
# [99]	training's binary_logloss: 0.343629	valid_0's binary_logloss: 0.574136
# [100]	training's binary_logloss: 0.342523	valid_0's binary_logloss: 0.57457
# [1]	training's binary_logloss: 0.669143	valid_0's binary_logloss: 0.673921
# [2]	training's binary_logloss: 0.649597	valid_0's binary_logloss: 0.657817
# [3]	training's binary_logloss: 0.632679	valid_0's binary_logloss: 0.646468
# [4]	training's binary_logloss: 0.618058	valid_0's binary_logloss: 0.636235
# [5]	training's binary_logloss: 0.605295	valid_0's binary_logloss: 0.627492
# [6]	training's binary_logloss: 0.593229	valid_0's binary_logloss: 0.61963
# [7]	training's binary_logloss: 0.58273	valid_0's binary_logloss: 0.613197
# [8]	training's binary_logloss: 0.573477	valid_0's binary_logloss: 0.608379
# [9]	training's binary_logloss: 0.564853	valid_0's binary_logloss: 0.602478
# [10]	training's binary_logloss: 0.556881	valid_0's binary_logloss: 0.598476
# [11]	training's binary_logloss: 0.549604	valid_0's binary_logloss: 0.594348
# [12]	training's binary_logloss: 0.542779	valid_0's binary_logloss: 0.590822
# [13]	training's binary_logloss: 0.536357	valid_0's binary_logloss: 0.588486
# [14]	training's binary_logloss: 0.5308	valid_0's binary_logloss: 0.585888
# [15]	training's binary_logloss: 0.52496	valid_0's binary_logloss: 0.582516
# [16]	training's binary_logloss: 0.520053	valid_0's binary_logloss: 0.580974
# [17]	training's binary_logloss: 0.515181	valid_0's binary_logloss: 0.578452
# [18]	training's binary_logloss: 0.510676	valid_0's binary_logloss: 0.577194
# [19]	training's binary_logloss: 0.506152	valid_0's binary_logloss: 0.575909
# [20]	training's binary_logloss: 0.502236	valid_0's binary_logloss: 0.575184
# [21]	training's binary_logloss: 0.497601	valid_0's binary_logloss: 0.574747
# [22]	training's binary_logloss: 0.493211	valid_0's binary_logloss: 0.574503
# [23]	training's binary_logloss: 0.489492	valid_0's binary_logloss: 0.574332
# [24]	training's binary_logloss: 0.486053	valid_0's binary_logloss: 0.573887
# [25]	training's binary_logloss: 0.482611	valid_0's binary_logloss: 0.574083
# [26]	training's binary_logloss: 0.479004	valid_0's binary_logloss: 0.573988
# [27]	training's binary_logloss: 0.475422	valid_0's binary_logloss: 0.573222
# [28]	training's binary_logloss: 0.472131	valid_0's binary_logloss: 0.572721
# [29]	training's binary_logloss: 0.468827	valid_0's binary_logloss: 0.571908
# [30]	training's binary_logloss: 0.465791	valid_0's binary_logloss: 0.571595
# [31]	training's binary_logloss: 0.462852	valid_0's binary_logloss: 0.571065
# [32]	training's binary_logloss: 0.460507	valid_0's binary_logloss: 0.571445
# [33]	training's binary_logloss: 0.457548	valid_0's binary_logloss: 0.571508
# [34]	training's binary_logloss: 0.454731	valid_0's binary_logloss: 0.571473
# [35]	training's binary_logloss: 0.451822	valid_0's binary_logloss: 0.572982
# [36]	training's binary_logloss: 0.449057	valid_0's binary_logloss: 0.572903
# [37]	training's binary_logloss: 0.446862	valid_0's binary_logloss: 0.573076
# [38]	training's binary_logloss: 0.444018	valid_0's binary_logloss: 0.573363
# [39]	training's binary_logloss: 0.441868	valid_0's binary_logloss: 0.573649
# [40]	training's binary_logloss: 0.439799	valid_0's binary_logloss: 0.574219
# [41]	training's binary_logloss: 0.437337	valid_0's binary_logloss: 0.574794
# [42]	training's binary_logloss: 0.434922	valid_0's binary_logloss: 0.575644
# [43]	training's binary_logloss: 0.432834	valid_0's binary_logloss: 0.575909
# [44]	training's binary_logloss: 0.430911	valid_0's binary_logloss: 0.576538
# [45]	training's binary_logloss: 0.428818	valid_0's binary_logloss: 0.576859
# [46]	training's binary_logloss: 0.427035	valid_0's binary_logloss: 0.57657
# [47]	training's binary_logloss: 0.425294	valid_0's binary_logloss: 0.576847
# [48]	training's binary_logloss: 0.423371	valid_0's binary_logloss: 0.57686
# [49]	training's binary_logloss: 0.421548	valid_0's binary_logloss: 0.577154
# [50]	training's binary_logloss: 0.419257	valid_0's binary_logloss: 0.577955
# [51]	training's binary_logloss: 0.417701	valid_0's binary_logloss: 0.577871
# [52]	training's binary_logloss: 0.416039	valid_0's binary_logloss: 0.577688
# [53]	training's binary_logloss: 0.413862	valid_0's binary_logloss: 0.578011
# [54]	training's binary_logloss: 0.411951	valid_0's binary_logloss: 0.577844
# [55]	training's binary_logloss: 0.409802	valid_0's binary_logloss: 0.578153
# [56]	training's binary_logloss: 0.408189	valid_0's binary_logloss: 0.578262
# [57]	training's binary_logloss: 0.405767	valid_0's binary_logloss: 0.578388
# [58]	training's binary_logloss: 0.404177	valid_0's binary_logloss: 0.578921
# [59]	training's binary_logloss: 0.40286	valid_0's binary_logloss: 0.579039
# [60]	training's binary_logloss: 0.40126	valid_0's binary_logloss: 0.579699
# [61]	training's binary_logloss: 0.398808	valid_0's binary_logloss: 0.580161
# [62]	training's binary_logloss: 0.397318	valid_0's binary_logloss: 0.581219
# [63]	training's binary_logloss: 0.395709	valid_0's binary_logloss: 0.582139
# [64]	training's binary_logloss: 0.394067	valid_0's binary_logloss: 0.582843
# [65]	training's binary_logloss: 0.392473	valid_0's binary_logloss: 0.583813
# [66]	training's binary_logloss: 0.390784	valid_0's binary_logloss: 0.584054
# [67]	training's binary_logloss: 0.389092	valid_0's binary_logloss: 0.583709
# [68]	training's binary_logloss: 0.387205	valid_0's binary_logloss: 0.584186
# [69]	training's binary_logloss: 0.385602	valid_0's binary_logloss: 0.58453
# [70]	training's binary_logloss: 0.383969	valid_0's binary_logloss: 0.584651
# [71]	training's binary_logloss: 0.382628	valid_0's binary_logloss: 0.585057
# [72]	training's binary_logloss: 0.380973	valid_0's binary_logloss: 0.584803
# [73]	training's binary_logloss: 0.379432	valid_0's binary_logloss: 0.585324
# [74]	training's binary_logloss: 0.377828	valid_0's binary_logloss: 0.585618
# [75]	training's binary_logloss: 0.37611	valid_0's binary_logloss: 0.586047
# [76]	training's binary_logloss: 0.373822	valid_0's binary_logloss: 0.58707
# [77]	training's binary_logloss: 0.372349	valid_0's binary_logloss: 0.586627
# [78]	training's binary_logloss: 0.371378	valid_0's binary_logloss: 0.58707
# [79]	training's binary_logloss: 0.370018	valid_0's binary_logloss: 0.586812
# [80]	training's binary_logloss: 0.368626	valid_0's binary_logloss: 0.588374
# [81]	training's binary_logloss: 0.367361	valid_0's binary_logloss: 0.58887
# [82]	training's binary_logloss: 0.365978	valid_0's binary_logloss: 0.589478
# [83]	training's binary_logloss: 0.363844	valid_0's binary_logloss: 0.589827
# [84]	training's binary_logloss: 0.362575	valid_0's binary_logloss: 0.590101
# [85]	training's binary_logloss: 0.361299	valid_0's binary_logloss: 0.590281
# [86]	training's binary_logloss: 0.36026	valid_0's binary_logloss: 0.591031
# [87]	training's binary_logloss: 0.358925	valid_0's binary_logloss: 0.591826
# [88]	training's binary_logloss: 0.357709	valid_0's binary_logloss: 0.591271
# [89]	training's binary_logloss: 0.356368	valid_0's binary_logloss: 0.591704
# [90]	training's binary_logloss: 0.354047	valid_0's binary_logloss: 0.592488
# [91]	training's binary_logloss: 0.352721	valid_0's binary_logloss: 0.591694
# [92]	training's binary_logloss: 0.351385	valid_0's binary_logloss: 0.591393
# [93]	training's binary_logloss: 0.349831	valid_0's binary_logloss: 0.592509
# [94]	training's binary_logloss: 0.348733	valid_0's binary_logloss: 0.592749
# [95]	training's binary_logloss: 0.347561	valid_0's binary_logloss: 0.593059
# [96]	training's binary_logloss: 0.345477	valid_0's binary_logloss: 0.594111
# [97]	training's binary_logloss: 0.34436	valid_0's binary_logloss: 0.594724
# [98]	training's binary_logloss: 0.342431	valid_0's binary_logloss: 0.595991
# [99]	training's binary_logloss: 0.341355	valid_0's binary_logloss: 0.596076
# [100]	training's binary_logloss: 0.340388	valid_0's binary_logloss: 0.59549
# ---Run time is 0.7538048000023991 seconds ---
#
# Accuracy of each fold:
#  [0.6705069124423964, 0.6693548387096774, 0.684331797235023, 0.6912442396313364, 0.6770472895040369]
#
# Avg accuracy :
# 0.678497015504494
#
# Std of accuracy :
# 0.00831936595841168
#
# Accuracy of each fold:
#  [0.6705069124423964, 0.6693548387096774, 0.684331797235023, 0.6912442396313364, 0.6770472895040369]
# Avg accuracy: 0.678497015504494
# Std of accuracy :
# 0.00831936595841168
#
# [[1429  659]
#  [ 736 1515]]
#
#               precision    recall  f1-score   support
#
#            0       0.66      0.68      0.67      2088
#            1       0.70      0.67      0.68      2251
#
#     accuracy                           0.68      4339
#    macro avg       0.68      0.68      0.68      4339
# weighted avg       0.68      0.68      0.68      4339
#
# sens  0.6843869731800766
# spec  0.6730342070191027
# prec  0.6600461893764434
# f1_score  0.6719962379496826
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [138], in <cell line: 77>()
#      74 print("prec ", precision)
#      75 print("f1_score ", f1_score)
# ---> 77 statallfeatures_dic['Accuracy'].append(np.mean(acc_score))
#      78 statallfeatures_dic['Standard Error'].append(np.std(acc_score))
#      79 statallfeatures_dic['Sensitivity'].append(sensitivity)
#
# NameError: name 'statallfeatures_dic' is not defined

# %%
# THIS IS TESTING ONLY
Truth2 = []
Output2 = []
testing = df2.iloc[:,-1]
model.fit(df.iloc[:,5:18],df.iloc[:,-1])
predicted = model.predict(df2.iloc[:,5:18])
acc = accuracy_score(testing, predicted)
Truth2.extend(testing.values.reshape(testing.shape[0])); ## it is a list
Output2.extend(predicted);
print(confusion_matrix(Truth2, Output2))
print()
print(classification_report(Truth2, Output2))

cm2 = confusion_matrix(Truth2, Output2)

sensitivity = cm2[0][0]/(cm2[0][0]+cm2[0][1])
specificity = cm2[1][1]/(cm2[1][0]+cm2[1][1])
precision = (cm2[0][0])/(cm2[0][0]+cm2[1][0])
f1_score = (2*precision*sensitivity)/(precision+sensitivity)
print("predicted",predicted)
print("acc",acc)
print("sens ",specificity) 
print("spec ", sensitivity) 
print("prec ", precision)
print("f1_score ", f1_score)
# Out:
# [[ 934 1296]
#  [ 346 4229]]
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.42      0.53      2230
#            1       0.77      0.92      0.84      4575
#
#     accuracy                           0.76      6805
#    macro avg       0.75      0.67      0.68      6805
# weighted avg       0.75      0.76      0.74      6805
#
# predicted [1 1 1 ... 1 1 1]
# acc 0.7587068332108744
# sens  0.9243715846994536
# spec  0.4188340807174888
# prec  0.7296875
# f1_score  0.5321937321937321

# %%
##### print(confusion_matrix(Truth, Output))
print(classification_report(Truth, Output))

# %% [markdown]
# # CatBoosting

# %%
conda install -c conda-forge catboost

# %%
# https://catboost.ai/en/docs/concepts/python-quickstart
import catboost as cb
from catboost import CatBoostClassifier


print ('catboost version', cb.__version__)
# Out:
# catboost version 1.0.6

# %%
#Implementing cross validation 
random.seed(1000)
kf = KFold(n_splits=5, random_state=1, shuffle=True)

from time import time
import timeit #imports timeit module
start_time = timeit.default_timer() #defines start time so computational time can be calculated

acc_score = [];
Truth = [];
Output = [];
 
for train_index , test_index in kf.split(df):
    
    X_train , X_test = df.iloc[train_index,5:18], df.iloc[test_index,5:18]
    y_train , y_test = df.iloc[train_index,-1], df.iloc[test_index,-1]
    
    # Create CatBoost model
    model = CatBoostClassifier(iterations=100,
                           depth=4,
                           learning_rate=0.1,
                           loss_function='Logloss')
    # train the model
    model.fit(X_train, y_train, verbose=False)
    # make the prediction using the resulting model
    pred_values = model.predict(X_test)
    #preds_proba = model.predict_proba(test_data)
    #print("class = ", preds_class)
    #print("proba = ", preds_proba)
     
    acc = accuracy_score(y_test, pred_values)
    acc_score.append(acc)
    
    Truth.extend(y_test.values.reshape(y_test.shape[0])); ## it is a list
    Output.extend(pred_values); ## it is a list  
    
    #print(model.feature_importances_)
    Importance = pd.DataFrame({'Importance':(model.feature_importances_*100)[0:10]}, 
                          index = (X_train.columns)[0:10])
    Importance.sort_values(by = 'Importance', 
                       axis = 0, 
                       ascending = True).plot(kind = 'barh', 
                                              color = 'r')
    plt.xlabel('Variable Importance')
    plt.gca().legend_ = None
    #plt.savefig('plot1.png')


elapsed = timeit.default_timer() - start_time #gives total computation time
print("---Run time is %s seconds ---" % elapsed) #prints computation time
print()

print('Accuracy of each fold: \n {}'.format(acc_score))
print()
print('Avg accuracy : \n{}'.format(np.mean(acc_score))); 
print()
print('Std of accuracy : \n{}'.format(np.std(acc_score)))

#start here

print()
print('Accuracy of each fold: \n {}'.format(acc_score))
print("Avg accuracy: {}".format(np.mean(acc_score)))
print('Std of accuracy : \n{}'.format(np.std(acc_score)))
print()
print(confusion_matrix(Truth, Output))
print()
print(classification_report(Truth, Output))

cm = confusion_matrix(Truth, Output)

sensitivity = cm[0][0]/(cm[0][0]+cm[0][1])
specificity = cm[1][1]/(cm[1][0]+cm[1][1])
precision = (cm[0][0])/(cm[0][0]+cm[1][0])
f1_score = (2*precision*sensitivity)/(precision+sensitivity)

print("sens ",sensitivity)
print("spec ", specificity)
print("prec ", precision)
print("f1_score ", f1_score)

statallfeatures_dic['Accuracy'].append(np.mean(acc_score))
statallfeatures_dic['Standard Error'].append(np.std(acc_score))
statallfeatures_dic['Sensitivity'].append(sensitivity)
statallfeatures_dic['Specificity'].append(specificity)
statallfeatures_dic['Precision'].append(precision)
statallfeatures_dic['F1_Score'].append(f1_score)

indaccs_dic['LogReg']=acc_score
# Out:
# ---Run time is 0.8794087999995099 seconds ---
#
# Accuracy of each fold:
#  [0.6831797235023042, 0.7016129032258065, 0.684331797235023, 0.7119815668202765, 0.7047289504036909]
#
# Avg accuracy :
# 0.6971669882374203
#
# Std of accuracy :
# 0.011461298995436154
#
# Accuracy of each fold:
#  [0.6831797235023042, 0.7016129032258065, 0.684331797235023, 0.7119815668202765, 0.7047289504036909]
# Avg accuracy: 0.6971669882374203
# Std of accuracy :
# 0.011461298995436154
#
# [[1496  592]
#  [ 722 1529]]
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.72      0.69      2088
#            1       0.72      0.68      0.70      2251
#
#     accuracy                           0.70      4339
#    macro avg       0.70      0.70      0.70      4339
# weighted avg       0.70      0.70      0.70      4339
#
# sens  0.7164750957854407
# spec  0.679253665037761
# prec  0.6744815148782687
# f1_score  0.6948444031583836
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [140], in <cell line: 82>()
#      79 print("prec ", precision)
#      80 print("f1_score ", f1_score)
# ---> 82 statallfeatures_dic['Accuracy'].append(np.mean(acc_score))
#      83 statallfeatures_dic['Standard Error'].append(np.std(acc_score))
#      84 statallfeatures_dic['Sensitivity'].append(sensitivity)
#
# NameError: name 'statallfeatures_dic' is not defined

# %%
# TESTING ONLY
Truth2 = []
Output2 = []
testing = df2.iloc[:,-1]
model.fit(df.iloc[:,5:18],df.iloc[:,-1])
predicted = model.predict(df2.iloc[:,5:18])
acc = accuracy_score(testing, predicted)
Truth2.extend(testing.values.reshape(testing.shape[0])); ## it is a list
Output2.extend(predicted);
print(confusion_matrix(Truth2, Output2))
print()
print(classification_report(Truth2, Output2))

cm2 = confusion_matrix(Truth2, Output2)

sensitivity = cm2[0][0]/(cm2[0][0]+cm2[0][1])
specificity = cm2[1][1]/(cm2[1][0]+cm2[1][1])
precision = (cm2[0][0])/(cm2[0][0]+cm2[1][0])
f1_score = (2*precision*sensitivity)/(precision+sensitivity)
print("predicted",predicted)
print("acc",acc)
print("sens ",specificity) 
print("spec ", sensitivity) 
print("prec ", precision)
print("f1_score ", f1_score)
# Out:
# 0:	learn: 0.6774171	total: 1.84ms	remaining: 182ms
# 1:	learn: 0.6643620	total: 3.62ms	remaining: 177ms
# 2:	learn: 0.6521420	total: 5.52ms	remaining: 178ms
# 3:	learn: 0.6415811	total: 7.54ms	remaining: 181ms
# 4:	learn: 0.6319751	total: 8.92ms	remaining: 169ms
# 5:	learn: 0.6246913	total: 10ms	remaining: 157ms
# 6:	learn: 0.6179729	total: 11.1ms	remaining: 147ms
# 7:	learn: 0.6117830	total: 12.2ms	remaining: 140ms
# 8:	learn: 0.6074042	total: 13.2ms	remaining: 134ms
# 9:	learn: 0.6030684	total: 14.4ms	remaining: 130ms
# 10:	learn: 0.5987560	total: 15.8ms	remaining: 128ms
# 11:	learn: 0.5955844	total: 17ms	remaining: 125ms
# 12:	learn: 0.5924535	total: 18.1ms	remaining: 121ms
# 13:	learn: 0.5892495	total: 19.2ms	remaining: 118ms
# 14:	learn: 0.5872034	total: 20.3ms	remaining: 115ms
# 15:	learn: 0.5854501	total: 21.6ms	remaining: 113ms
# 16:	learn: 0.5828691	total: 22.8ms	remaining: 111ms
# 17:	learn: 0.5810420	total: 23.9ms	remaining: 109ms
# 18:	learn: 0.5794785	total: 25ms	remaining: 106ms
# 19:	learn: 0.5781295	total: 26.1ms	remaining: 105ms
# 20:	learn: 0.5765849	total: 27.3ms	remaining: 103ms
# 21:	learn: 0.5759055	total: 28.5ms	remaining: 101ms
# 22:	learn: 0.5749618	total: 29.8ms	remaining: 99.7ms
# 23:	learn: 0.5739851	total: 31ms	remaining: 98.1ms
# 24:	learn: 0.5734372	total: 32.2ms	remaining: 96.5ms
# 25:	learn: 0.5729289	total: 33.3ms	remaining: 94.8ms
# 26:	learn: 0.5716828	total: 34.5ms	remaining: 93.3ms
# 27:	learn: 0.5711955	total: 35.6ms	remaining: 91.5ms
# 28:	learn: 0.5702432	total: 36.7ms	remaining: 89.8ms
# 29:	learn: 0.5691556	total: 38ms	remaining: 88.7ms
# 30:	learn: 0.5684011	total: 39.2ms	remaining: 87.3ms
# 31:	learn: 0.5677484	total: 40.4ms	remaining: 85.9ms
# 32:	learn: 0.5668526	total: 41.6ms	remaining: 84.4ms
# 33:	learn: 0.5659874	total: 42.7ms	remaining: 82.8ms
# 34:	learn: 0.5655504	total: 43.9ms	remaining: 81.5ms
# 35:	learn: 0.5650269	total: 45ms	remaining: 80ms
# 36:	learn: 0.5645111	total: 46.2ms	remaining: 78.6ms
# 37:	learn: 0.5640699	total: 47.6ms	remaining: 77.7ms
# 38:	learn: 0.5635920	total: 48.8ms	remaining: 76.3ms
# 39:	learn: 0.5632465	total: 49.9ms	remaining: 74.9ms
# 40:	learn: 0.5625775	total: 51.1ms	remaining: 73.5ms
# 41:	learn: 0.5622503	total: 52.2ms	remaining: 72.1ms
# 42:	learn: 0.5620935	total: 53.4ms	remaining: 70.8ms
# 43:	learn: 0.5618084	total: 54.6ms	remaining: 69.5ms
# 44:	learn: 0.5614247	total: 55.7ms	remaining: 68.1ms
# 45:	learn: 0.5610444	total: 56.9ms	remaining: 66.8ms
# 46:	learn: 0.5604383	total: 58ms	remaining: 65.4ms
# 47:	learn: 0.5601163	total: 59.1ms	remaining: 64ms
# 48:	learn: 0.5597736	total: 60.3ms	remaining: 62.7ms
# 49:	learn: 0.5594369	total: 61.3ms	remaining: 61.3ms
# 50:	learn: 0.5590789	total: 62.4ms	remaining: 59.9ms
# 51:	learn: 0.5588795	total: 63.6ms	remaining: 58.7ms
# 52:	learn: 0.5585990	total: 64.6ms	remaining: 57.3ms
# 53:	learn: 0.5582873	total: 65.9ms	remaining: 56.1ms
# 54:	learn: 0.5579480	total: 67ms	remaining: 54.8ms
# 55:	learn: 0.5577078	total: 68.2ms	remaining: 53.6ms
# 56:	learn: 0.5572614	total: 69.4ms	remaining: 52.3ms
# 57:	learn: 0.5569312	total: 70.6ms	remaining: 51.1ms
# 58:	learn: 0.5563540	total: 71.8ms	remaining: 49.9ms
# 59:	learn: 0.5560622	total: 73ms	remaining: 48.7ms
# 60:	learn: 0.5556116	total: 74.2ms	remaining: 47.4ms
# 61:	learn: 0.5552658	total: 75.6ms	remaining: 46.4ms
# 62:	learn: 0.5550718	total: 76.9ms	remaining: 45.1ms
# 63:	learn: 0.5547395	total: 78ms	remaining: 43.9ms
# 64:	learn: 0.5542772	total: 79.2ms	remaining: 42.6ms
# 65:	learn: 0.5537112	total: 80.4ms	remaining: 41.4ms
# 66:	learn: 0.5534230	total: 81.5ms	remaining: 40.1ms
# 67:	learn: 0.5531074	total: 82.7ms	remaining: 38.9ms
# 68:	learn: 0.5528201	total: 84ms	remaining: 37.7ms
# 69:	learn: 0.5524825	total: 85.2ms	remaining: 36.5ms
# 70:	learn: 0.5520991	total: 86.3ms	remaining: 35.3ms
# 71:	learn: 0.5518743	total: 87.5ms	remaining: 34ms
# 72:	learn: 0.5514895	total: 88.8ms	remaining: 32.9ms
# 73:	learn: 0.5512658	total: 90.4ms	remaining: 31.8ms
# 74:	learn: 0.5510050	total: 91.7ms	remaining: 30.6ms
# 75:	learn: 0.5506336	total: 93ms	remaining: 29.4ms
# 76:	learn: 0.5504375	total: 94.3ms	remaining: 28.2ms
# 77:	learn: 0.5499814	total: 95.4ms	remaining: 26.9ms
# 78:	learn: 0.5498645	total: 96.6ms	remaining: 25.7ms
# 79:	learn: 0.5494725	total: 97.7ms	remaining: 24.4ms
# 80:	learn: 0.5491389	total: 98.9ms	remaining: 23.2ms
# 81:	learn: 0.5486485	total: 100ms	remaining: 22ms
# 82:	learn: 0.5483789	total: 101ms	remaining: 20.8ms
# 83:	learn: 0.5480993	total: 103ms	remaining: 19.5ms
# 84:	learn: 0.5479710	total: 104ms	remaining: 18.3ms
# 85:	learn: 0.5477779	total: 105ms	remaining: 17.1ms
# 86:	learn: 0.5475504	total: 106ms	remaining: 15.9ms
# 87:	learn: 0.5471417	total: 107ms	remaining: 14.6ms
# 88:	learn: 0.5470184	total: 108ms	remaining: 13.4ms
# 89:	learn: 0.5468936	total: 109ms	remaining: 12.2ms
# 90:	learn: 0.5464265	total: 111ms	remaining: 10.9ms
# 91:	learn: 0.5460488	total: 112ms	remaining: 9.71ms
# 92:	learn: 0.5458474	total: 113ms	remaining: 8.48ms
# 93:	learn: 0.5457087	total: 114ms	remaining: 7.26ms
# 94:	learn: 0.5452422	total: 115ms	remaining: 6.05ms
# 95:	learn: 0.5449091	total: 116ms	remaining: 4.83ms
# 96:	learn: 0.5446771	total: 117ms	remaining: 3.62ms
# 97:	learn: 0.5444369	total: 118ms	remaining: 2.41ms
# 98:	learn: 0.5443117	total: 119ms	remaining: 1.2ms
# 99:	learn: 0.5440493	total: 120ms	remaining: 0us
# [[ 489 1741]
#  [ 225 4350]]
#
#               precision    recall  f1-score   support
#
#            0       0.68      0.22      0.33      2230
#            1       0.71      0.95      0.82      4575
#
#     accuracy                           0.71      6805
#    macro avg       0.70      0.59      0.57      6805
# weighted avg       0.70      0.71      0.66      6805
#
# predicted [1 1 1 ... 1 1 1]
# acc 0.711094783247612
# sens  0.9508196721311475
# spec  0.21928251121076234
# prec  0.6848739495798319
# f1_score  0.3322010869565218

# %%
print(confusion_matrix(Truth, Output))
print(classification_report(Truth, Output))

# %% [markdown]
# # Please neglect: The following are some codes to be developed
#
# https://lightgbm.readthedocs.io/en/latest/pythonapi/lightgbm.Dataset.html

# %% [raw]
# #IGNORE EVERYTHING FROM HERE DOWN
# kf = KFold(n_splits=5, random_state=1, shuffle=True)
#
# from time import time
# import timeit #imports timeit module
# start_time = timeit.default_timer() #defines start time so computational time can be calculated
#
# acc_score = [];
# Truth = [];
# Output = [];
#
# for train_index , test_index in kf.split(df):
#
#     X_train , X_test = df.iloc[train_index,:-1], df.iloc[test_index,:-1]
#     y_train , y_test = df.iloc[train_index,-1], df.iloc[test_index,-1]
#
#     # Create the LightGBM data containers
#     categorical_features = [c for c, col in enumerate(X_train.columns) if 'cat' in col]
#     train_data = lightgbm.Dataset(X_train, label=y_train, categorical_feature=categorical_features)
#     test_data = lightgbm.Dataset(X_test, label=y_test)
#
#     parameters = {
#     'application': 'binary',
#     'objective': 'binary',
#     'metric': 'auc',
#     'is_unbalance': 'true',
#     'boosting': 'gbdt',
#     'num_leaves': 31,
#     'feature_fraction': 0.5,
#     'bagging_fraction': 0.5,
#     'bagging_freq': 20,
#     'learning_rate': 0.05,
#     'verbose': 0
#     }
#
#     model = lightgbm.train(parameters,
#                        train_data,
#                        valid_sets=test_data,
#                        num_boost_round=50)
# #    model.fit(X_train,y_train) ==> NO fitting for LGBM
#     pred_values = model.predict(X_test)
#
#     acc = accuracy_score(y_test, pred_values)
#     acc_score.append(acc)
#
#     Truth.extend(y_test.values.reshape(y_test.shape[0])); ## it is a list
#     Output.extend(pred_values); ## it is a list
#
# elapsed = timeit.default_timer() - start_time #gives total computation time
# print("---Run time is %s seconds ---" % elapsed) #prints computation time
# print()
#
# print('Accuracy of each fold: \n {}'.format(acc_score))
# print()
# print('Avg accuracy : \n{}'.format(np.mean(acc_score)));
# print()
# print('Std of accuracy : \n{}'.format(np.std(acc_score)))

# %% [raw]
# #https://stackoverflow.com/questions/25009284/how-to-plot-roc-curve-in-python
# import scikitplot as skplt
# skplt.metrics.plot_roc_curve(y_test, pred_prob)
# plt.show()

# %% [raw]
# xgb_model = xgboost.XGBClassifier(num_class=7,
#                                   learning_rate=0.1,
#                                   num_iterations=1000,
#                                   max_depth=10,
#                                   feature_fraction=0.7,
#                                   scale_pos_weight=1.5,
#                                   boosting='gbdt',
#                                   metric='multiclass',
#                                   eval_metric='mlogloss')
