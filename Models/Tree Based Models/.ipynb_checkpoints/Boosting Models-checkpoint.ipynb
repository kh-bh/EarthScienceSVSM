# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import KFold 
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import LeaveOneOut

from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix, classification_report

# %%
import xgboost as xgb
from sklearn import metrics
from lightgbm import LGBMClassifier

import lightgbm
import lightgbm as lgb
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.dpi'] = 70 #display 70 dpi in Jupyter Notebook, may consider100 dpi 
plt.rcParams['savefig.dpi'] = 300 #define 300 dpi for saving figures

import seaborn as sns
## here are some settings 
sns.set_style('whitegrid')
sns.set(rc={"figure.dpi":70, 'savefig.dpi':300}) #defining dpi setting
sns.set_context('notebook')
sns.set_style("ticks")
from IPython.display import set_matplotlib_formats

# %%
df2021 = pd.read_csv('SRER21_dataset_v1.csv', na_values='?').dropna()
df2017 = pd.read_csv('SRER_2017_training_bi.csv', na_values='?').dropna()
combinedDf = pd.concat([df2021,df2017])

dfFinal = combinedDf.replace('woody', 1)
dfFinal = dfFinal.replace('non-woody', 0)
print(dfFinal.dtypes)
dfFinal.head()
# Out:
# OID_              int64
# Id                int64
# gridcode          int64
# Shape_Length    float64
# Shape_Area      float64
# CH_mean         float64
# ARVI_mean       float64
# ARVI_med        float64
# ARVI_max        float64
# EVI_mean        float64
# EVI_med         float64
# EVI_max         float64
# NDVI_mean       float64
# NDVI_med        float64
# NDVI_max        float64
# SAVI_mean       float64
# SAVI_med        float64
# SAVI_max        float64
# Veg_class         int64
# dtype: object
#    OID_  Id  gridcode  Shape_Length  Shape_Area   CH_mean  ARVI_mean  \
# 0     2   2         2          20.4        2.38  1.000000   0.273945
# 1     3   3         3           8.2        1.32  1.000000   0.530156
# 2     4   4         4          55.8       24.43  0.920000   0.477979
# 3     5   5         5          15.2        1.88  1.000000   0.342945
# 4     6   6         6          27.2        9.29  0.142857   0.044382
#
#    ARVI_med  ARVI_max  EVI_mean   EVI_med   EVI_max  NDVI_mean  NDVI_med  \
# 0  0.273945  0.273945  0.323257  0.323257  0.323257   0.428208  0.428208
# 1  0.530156  0.530156  0.460513  0.460513  0.460513   0.611745  0.611745
# 2  0.501013  0.616707  0.381095  0.384718  0.447304   0.576437  0.596638
# 3  0.342945  0.342945  0.346714  0.346714  0.346714   0.468738  0.468738
# 4 -0.008903  0.265536  0.181714  0.147391  0.315684   0.223522  0.178629
#
#    NDVI_max  SAVI_mean  SAVI_med  SAVI_max  Veg_class
# 0  0.428208   0.311936  0.311936  0.311936          1
# 1  0.611745   0.416492  0.416492  0.416492          1
# 2  0.673767   0.359786  0.364317  0.414173          1
# 3  0.468738   0.323907  0.323907  0.323907          1
# 4  0.412030   0.177739  0.147325  0.299311          0

# %%
# https://xgboost.readthedocs.io/en/latest/python/python_api.html#module-xgboost.sklearn

# check xgboost version
import xgboost
import xgboost as xgb
from xgboost import XGBClassifier
print(xgboost.__version__)
from matplotlib import pyplot
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve, auc
import sklearn.metrics as metrics

#Implementing cross validation 
kf = KFold(n_splits=5, random_state=1, shuffle=True)
# Create the Extreme GBM
model = XGBClassifier(n_estimators=100, learning_rate = 0.1,use_label_encoder =False,verbose=None,
                max_depth = 5, eval_metric='logloss')
    
from time import time
import timeit #imports timeit module
start_time = timeit.default_timer() #defines start time so computational time can be calculated

acc_score = [];
Truth = [];
Output = [];

for train_index , test_index in kf.split(dfFinal):
     
    X_train , X_test = dfFinal.iloc[train_index,:-1], dfFinal.iloc[test_index,:-1]
    y_train , y_test = dfFinal.iloc[train_index,-1], dfFinal.iloc[test_index,-1]
    
    
    model.fit(X_train,y_train)

    pred_values = model.predict(X_test)
    pred_prob = model.predict_proba(X_test)[:, 1]
     
    # y values used only for accuracy
    acc = accuracy_score(y_test, pred_values)
    acc_score.append(acc)
        
    Truth.extend(y_test.values.reshape(y_test.shape[0])); ## it is a list
    Output.extend(pred_values); ## it is a list 
    
    #print(model.feature_importances_)
    Importance = pd.DataFrame({'Importance':(model.feature_importances_*100)[0:10]}, 
                          index = (X_train.columns)[0:10])
    Importance.sort_values(by = 'Importance', 
                       axis = 0, 
                       ascending = True).plot(kind = 'barh', 
                                              color = 'r')
    plt.xlabel('Variable Importance')
    plt.gca().legend_ = None
    plt.show()
    #plt.savefig('plot1.png')
    
    ##################################################
    #https://scikit-learn.org/stable/modules/generated/sklearn.metrics.roc_auc_score.html
    #Compute Area Under the Receiver Operating Characteristic Curve (ROC AUC) from prediction scores.
    print("roc_auc_score", roc_auc_score(y_test, pred_prob))
    
    # calculate the fpr and tpr for all thresholds of the classification
    #fpr, tpr, threshold = metrics.roc_curve(y_test, pred_prob)
    #roc_auc = metrics.auc(fpr, tpr)
    # method I: plt
    #import matplotlib.pyplot as plt
    #plt.title('Receiver Operating Characteristic')
    #plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
    #plt.legend(loc = 'lower right')
    #plt.plot([0, 1], [0, 1],'r--')
    #plt.xlim([-0.05, 1])
    #plt.ylim([0, 1.05])
    #plt.ylabel('True Positive Rate')
    #plt.xlabel('False Positive Rate')
    #plt.show()
    ##################################################
    
elapsed = timeit.default_timer() - start_time #gives total computation time
print("---Run time is %s seconds ---" % elapsed) #prints computation time
print()

print('Accuracy of each fold: \n {}'.format(acc_score))
print()
print('Avg accuracy : \n{}'.format(np.mean(acc_score))); 
print()
print('Std of accuracy : \n{}'.format(np.std(acc_score)))
# Out:
# 1.5.0
# roc_auc_score 0.8977261178861788
# roc_auc_score 0.8904884724707864
# roc_auc_score 0.9028922651879343
# roc_auc_score 0.8961171467758662
# roc_auc_score 0.88631592265023
# ---Run time is 9.217101600000206 seconds ---
#
# Accuracy of each fold:
#  [0.812862669245648, 0.7939042089985486, 0.8234155781325593, 0.8137397194000967, 0.7963231736816643]
#
# Avg accuracy :
# 0.8080490698917033
#
# Std of accuracy :
# 0.011218355830506297

# %%
# https://catboost.ai/en/docs/concepts/python-quickstart
import catboost as cb
from catboost import CatBoostClassifier


print ('catboost version', cb.__version__)
# Out:
# catboost version 1.0.6

# %%
#Implementing cross validation 
kf = KFold(n_splits=5, random_state=1, shuffle=True)

from time import time
import timeit #imports timeit module
start_time = timeit.default_timer() #defines start time so computational time can be calculated

acc_score = [];
Truth = [];
Output = [];
 
for train_index , test_index in kf.split(dfFinal):
    
    X_train , X_test = dfFinal.iloc[train_index,:-1], dfFinal.iloc[test_index,:-1]
    y_train , y_test = dfFinal.iloc[train_index,-1], dfFinal.iloc[test_index,-1]
    
    # Create CatBoost model
    model = CatBoostClassifier(iterations=100,
                           depth=4,
                           learning_rate=0.1,
                           loss_function='Logloss')
    # train the model
    model.fit(X_train, y_train, verbose=False)
    
    # make the prediction using the resulting model
    pred_values = model.predict(X_test)
    #preds_proba = model.predict_proba(test_data)
    #print("class = ", preds_class)
    #print("proba = ", preds_proba)
     
    acc = accuracy_score(y_test, pred_values)
    acc_score.append(acc)
    
    Truth.extend(y_test.values.reshape(y_test.shape[0])); ## it is a list
    Output.extend(pred_values); ## it is a list  
    
    #print(model.feature_importances_)
    Importance = pd.DataFrame({'Importance':(model.feature_importances_*100)[0:10]}, 
                          index = (X_train.columns)[0:10])
    Importance.sort_values(by = 'Importance', 
                       axis = 0, 
                       ascending = True).plot(kind = 'barh', 
                                              color = 'r')
    plt.xlabel('Variable Importance')
    plt.gca().legend_ = None
    #plt.savefig('plot1.png')


elapsed = timeit.default_timer() - start_time #gives total computation time
print("---Run time is %s seconds ---" % elapsed) #prints computation time
print()

print('Accuracy of each fold: \n {}'.format(acc_score))
print()
print('Avg accuracy : \n{}'.format(np.mean(acc_score))); 
print()
print('Std of accuracy : \n{}'.format(np.std(acc_score)))
# Out:
# ---Run time is 5.2802905999997165 seconds ---
#
# Accuracy of each fold:
#  [0.8060928433268859, 0.7929366231253023, 0.8059990324141267, 0.8050314465408805, 0.7890662796323173]
#
# Avg accuracy :
# 0.7998252450079025
#
# Std of accuracy :
# 0.007317259342429209

# %%
# https://lightgbm.readthedocs.io/en/latest/pythonapi/lightgbm.LGBMClassifier.html
import lightgbm

#Implementing cross validation 
kf = KFold(n_splits=5, random_state=1, shuffle=True)
model = lightgbm.LGBMClassifier(learning_rate=0.09,max_depth=-5,random_state=42)

from time import time
import timeit #imports timeit module
start_time = timeit.default_timer() #defines start time so computational time can be calculated

acc_score = [];
Truth = [];
Output = [];
 
for train_index , test_index in kf.split(dfFinal):
    
    X_train , X_test = dfFinal.iloc[train_index,:-1], dfFinal.iloc[test_index,:-1]
    y_train , y_test = dfFinal.iloc[train_index,-1], dfFinal.iloc[test_index,-1]
    
    # Create the LightGBM data containers
    model.fit(X_train,y_train,eval_set=[(X_test,y_test),(X_train,y_train)],
          eval_metric='logloss')

    pred_values = model.predict(X_test)
     
    acc = accuracy_score(y_test, pred_values)
    acc_score.append(acc)
    
    Truth.extend(y_test.values.reshape(y_test.shape[0])); ## it is a list
    Output.extend(pred_values); ## it is a list  
    
    #print(model.feature_importances_)
    Importance = pd.DataFrame({'Importance':(model.feature_importances_*100)[0:10]}, 
                          index = (X_train.columns)[0:10])
    Importance.sort_values(by = 'Importance', 
                       axis = 0, 
                       ascending = True).plot(kind = 'barh', 
                                              color = 'r')
    plt.xlabel('Variable Importance')
    plt.gca().legend_ = None
    #plt.savefig('plot1.png')


elapsed = timeit.default_timer() - start_time #gives total computation time
print("---Run time is %s seconds ---" % elapsed) #prints computation time
print()

print('Accuracy of each fold: \n {}'.format(acc_score))
print()
print('Avg accuracy : \n{}'.format(np.mean(acc_score))); 
print()
print('Std of accuracy : \n{}'.format(np.std(acc_score)))
# Out:
# [1]	training's binary_logloss: 0.633885	valid_0's binary_logloss: 0.637743
# [2]	training's binary_logloss: 0.603655	valid_0's binary_logloss: 0.608329
# [3]	training's binary_logloss: 0.578025	valid_0's binary_logloss: 0.583816
# [4]	training's binary_logloss: 0.555061	valid_0's binary_logloss: 0.56252
# [5]	training's binary_logloss: 0.535754	valid_0's binary_logloss: 0.544005
# [6]	training's binary_logloss: 0.518038	valid_0's binary_logloss: 0.527796
# [7]	training's binary_logloss: 0.503084	valid_0's binary_logloss: 0.514463
# [8]	training's binary_logloss: 0.488765	valid_0's binary_logloss: 0.501345
# [9]	training's binary_logloss: 0.476626	valid_0's binary_logloss: 0.489709
# [10]	training's binary_logloss: 0.46595	valid_0's binary_logloss: 0.480107
# [11]	training's binary_logloss: 0.455325	valid_0's binary_logloss: 0.471304
# [12]	training's binary_logloss: 0.445813	valid_0's binary_logloss: 0.464068
# [13]	training's binary_logloss: 0.437249	valid_0's binary_logloss: 0.457108
# [14]	training's binary_logloss: 0.429785	valid_0's binary_logloss: 0.451118
# [15]	training's binary_logloss: 0.422835	valid_0's binary_logloss: 0.445695
# [16]	training's binary_logloss: 0.41622	valid_0's binary_logloss: 0.439923
# [17]	training's binary_logloss: 0.410138	valid_0's binary_logloss: 0.435731
# [18]	training's binary_logloss: 0.404316	valid_0's binary_logloss: 0.431387
# [19]	training's binary_logloss: 0.398728	valid_0's binary_logloss: 0.427375
# [20]	training's binary_logloss: 0.393491	valid_0's binary_logloss: 0.423704
# [21]	training's binary_logloss: 0.388649	valid_0's binary_logloss: 0.42044
# [22]	training's binary_logloss: 0.384301	valid_0's binary_logloss: 0.417941
# [23]	training's binary_logloss: 0.380105	valid_0's binary_logloss: 0.414669
# [24]	training's binary_logloss: 0.376193	valid_0's binary_logloss: 0.412546
# [25]	training's binary_logloss: 0.372446	valid_0's binary_logloss: 0.410308
# [26]	training's binary_logloss: 0.369046	valid_0's binary_logloss: 0.408628
# [27]	training's binary_logloss: 0.365947	valid_0's binary_logloss: 0.406884
# [28]	training's binary_logloss: 0.362902	valid_0's binary_logloss: 0.40547
# [29]	training's binary_logloss: 0.360141	valid_0's binary_logloss: 0.404538
# [30]	training's binary_logloss: 0.356982	valid_0's binary_logloss: 0.402793
# [31]	training's binary_logloss: 0.353941	valid_0's binary_logloss: 0.401218
# [32]	training's binary_logloss: 0.351288	valid_0's binary_logloss: 0.40004
# [33]	training's binary_logloss: 0.348292	valid_0's binary_logloss: 0.398731
# [34]	training's binary_logloss: 0.345586	valid_0's binary_logloss: 0.397891
# [35]	training's binary_logloss: 0.343191	valid_0's binary_logloss: 0.396812
# [36]	training's binary_logloss: 0.341085	valid_0's binary_logloss: 0.396203
# [37]	training's binary_logloss: 0.338739	valid_0's binary_logloss: 0.395723
# [38]	training's binary_logloss: 0.336427	valid_0's binary_logloss: 0.395039
# [39]	training's binary_logloss: 0.333994	valid_0's binary_logloss: 0.394592
# [40]	training's binary_logloss: 0.331969	valid_0's binary_logloss: 0.394428
# [41]	training's binary_logloss: 0.329817	valid_0's binary_logloss: 0.394184
# [42]	training's binary_logloss: 0.327806	valid_0's binary_logloss: 0.392844
# [43]	training's binary_logloss: 0.325824	valid_0's binary_logloss: 0.39225
# [44]	training's binary_logloss: 0.323943	valid_0's binary_logloss: 0.392165
# [45]	training's binary_logloss: 0.321788	valid_0's binary_logloss: 0.391636
# [46]	training's binary_logloss: 0.320026	valid_0's binary_logloss: 0.391204
# [47]	training's binary_logloss: 0.318246	valid_0's binary_logloss: 0.390998
# [48]	training's binary_logloss: 0.316348	valid_0's binary_logloss: 0.390982
# [49]	training's binary_logloss: 0.314834	valid_0's binary_logloss: 0.390942
# [50]	training's binary_logloss: 0.313223	valid_0's binary_logloss: 0.390617
# [51]	training's binary_logloss: 0.311879	valid_0's binary_logloss: 0.390682
# [52]	training's binary_logloss: 0.310319	valid_0's binary_logloss: 0.39019
# [53]	training's binary_logloss: 0.308786	valid_0's binary_logloss: 0.390494
# [54]	training's binary_logloss: 0.30718	valid_0's binary_logloss: 0.390272
# [55]	training's binary_logloss: 0.305609	valid_0's binary_logloss: 0.389848
# [56]	training's binary_logloss: 0.304232	valid_0's binary_logloss: 0.389819
# [57]	training's binary_logloss: 0.302917	valid_0's binary_logloss: 0.389627
# [58]	training's binary_logloss: 0.301413	valid_0's binary_logloss: 0.389216
# [59]	training's binary_logloss: 0.300032	valid_0's binary_logloss: 0.389022
# [60]	training's binary_logloss: 0.298668	valid_0's binary_logloss: 0.388931
# [61]	training's binary_logloss: 0.297195	valid_0's binary_logloss: 0.388608
# [62]	training's binary_logloss: 0.29616	valid_0's binary_logloss: 0.38869
# [63]	training's binary_logloss: 0.294474	valid_0's binary_logloss: 0.389253
# [64]	training's binary_logloss: 0.293146	valid_0's binary_logloss: 0.389333
# [65]	training's binary_logloss: 0.291912	valid_0's binary_logloss: 0.389475
# [66]	training's binary_logloss: 0.290714	valid_0's binary_logloss: 0.389482
# [67]	training's binary_logloss: 0.289596	valid_0's binary_logloss: 0.389747
# [68]	training's binary_logloss: 0.288423	valid_0's binary_logloss: 0.389374
# [69]	training's binary_logloss: 0.287127	valid_0's binary_logloss: 0.389732
# [70]	training's binary_logloss: 0.28603	valid_0's binary_logloss: 0.389947
# [71]	training's binary_logloss: 0.284962	valid_0's binary_logloss: 0.389801
# [72]	training's binary_logloss: 0.283831	valid_0's binary_logloss: 0.390087
# [73]	training's binary_logloss: 0.282657	valid_0's binary_logloss: 0.390465
# [74]	training's binary_logloss: 0.281477	valid_0's binary_logloss: 0.389866
# [75]	training's binary_logloss: 0.28037	valid_0's binary_logloss: 0.390202
# [76]	training's binary_logloss: 0.279329	valid_0's binary_logloss: 0.389822
# [77]	training's binary_logloss: 0.278373	valid_0's binary_logloss: 0.39001
# [78]	training's binary_logloss: 0.277013	valid_0's binary_logloss: 0.390093
# [79]	training's binary_logloss: 0.27595	valid_0's binary_logloss: 0.38997
# [80]	training's binary_logloss: 0.275026	valid_0's binary_logloss: 0.389826
# [81]	training's binary_logloss: 0.274058	valid_0's binary_logloss: 0.389782
# [82]	training's binary_logloss: 0.272985	valid_0's binary_logloss: 0.389469
# [83]	training's binary_logloss: 0.271743	valid_0's binary_logloss: 0.389583
# [84]	training's binary_logloss: 0.270694	valid_0's binary_logloss: 0.389515
# [85]	training's binary_logloss: 0.269789	valid_0's binary_logloss: 0.389255
# [86]	training's binary_logloss: 0.268639	valid_0's binary_logloss: 0.389361
# [87]	training's binary_logloss: 0.267456	valid_0's binary_logloss: 0.389
# [88]	training's binary_logloss: 0.266657	valid_0's binary_logloss: 0.388904
# [89]	training's binary_logloss: 0.265709	valid_0's binary_logloss: 0.389349
# [90]	training's binary_logloss: 0.264907	valid_0's binary_logloss: 0.388959
# [91]	training's binary_logloss: 0.263966	valid_0's binary_logloss: 0.388996
# [92]	training's binary_logloss: 0.263128	valid_0's binary_logloss: 0.389089
# [93]	training's binary_logloss: 0.261861	valid_0's binary_logloss: 0.389316
# [94]	training's binary_logloss: 0.260758	valid_0's binary_logloss: 0.389283
# [95]	training's binary_logloss: 0.259555	valid_0's binary_logloss: 0.389349
# [96]	training's binary_logloss: 0.258643	valid_0's binary_logloss: 0.389359
# [97]	training's binary_logloss: 0.257767	valid_0's binary_logloss: 0.389554
# [98]	training's binary_logloss: 0.256426	valid_0's binary_logloss: 0.389746
# [99]	training's binary_logloss: 0.255273	valid_0's binary_logloss: 0.389811
# [100]	training's binary_logloss: 0.254339	valid_0's binary_logloss: 0.389866
# [1]	training's binary_logloss: 0.632262	valid_0's binary_logloss: 0.640992
# [2]	training's binary_logloss: 0.60129	valid_0's binary_logloss: 0.612871
# [3]	training's binary_logloss: 0.575438	valid_0's binary_logloss: 0.590545
# [4]	training's binary_logloss: 0.552329	valid_0's binary_logloss: 0.569056
# [5]	training's binary_logloss: 0.532225	valid_0's binary_logloss: 0.552827
# [6]	training's binary_logloss: 0.514648	valid_0's binary_logloss: 0.53779
# [7]	training's binary_logloss: 0.499377	valid_0's binary_logloss: 0.525157
# [8]	training's binary_logloss: 0.485579	valid_0's binary_logloss: 0.512999
# [9]	training's binary_logloss: 0.473523	valid_0's binary_logloss: 0.502613
# [10]	training's binary_logloss: 0.46261	valid_0's binary_logloss: 0.494153
# [11]	training's binary_logloss: 0.452364	valid_0's binary_logloss: 0.48543
# [12]	training's binary_logloss: 0.443385	valid_0's binary_logloss: 0.478071
# [13]	training's binary_logloss: 0.434605	valid_0's binary_logloss: 0.471278
# [14]	training's binary_logloss: 0.426941	valid_0's binary_logloss: 0.465731
# [15]	training's binary_logloss: 0.419675	valid_0's binary_logloss: 0.459491
# [16]	training's binary_logloss: 0.412658	valid_0's binary_logloss: 0.453954
# [17]	training's binary_logloss: 0.406929	valid_0's binary_logloss: 0.449328
# [18]	training's binary_logloss: 0.401153	valid_0's binary_logloss: 0.44493
# [19]	training's binary_logloss: 0.395799	valid_0's binary_logloss: 0.441038
# [20]	training's binary_logloss: 0.391004	valid_0's binary_logloss: 0.438024
# [21]	training's binary_logloss: 0.386762	valid_0's binary_logloss: 0.435667
# [22]	training's binary_logloss: 0.382239	valid_0's binary_logloss: 0.432973
# [23]	training's binary_logloss: 0.378113	valid_0's binary_logloss: 0.430183
# [24]	training's binary_logloss: 0.374137	valid_0's binary_logloss: 0.428002
# [25]	training's binary_logloss: 0.370487	valid_0's binary_logloss: 0.425876
# [26]	training's binary_logloss: 0.367246	valid_0's binary_logloss: 0.423711
# [27]	training's binary_logloss: 0.363859	valid_0's binary_logloss: 0.421865
# [28]	training's binary_logloss: 0.360629	valid_0's binary_logloss: 0.419103
# [29]	training's binary_logloss: 0.357796	valid_0's binary_logloss: 0.41787
# [30]	training's binary_logloss: 0.354594	valid_0's binary_logloss: 0.416298
# [31]	training's binary_logloss: 0.351577	valid_0's binary_logloss: 0.414044
# [32]	training's binary_logloss: 0.348786	valid_0's binary_logloss: 0.41321
# [33]	training's binary_logloss: 0.346104	valid_0's binary_logloss: 0.41138
# [34]	training's binary_logloss: 0.343447	valid_0's binary_logloss: 0.410556
# [35]	training's binary_logloss: 0.341252	valid_0's binary_logloss: 0.409056
# [36]	training's binary_logloss: 0.338765	valid_0's binary_logloss: 0.408874
# [37]	training's binary_logloss: 0.336612	valid_0's binary_logloss: 0.408032
# [38]	training's binary_logloss: 0.334652	valid_0's binary_logloss: 0.40762
# [39]	training's binary_logloss: 0.332736	valid_0's binary_logloss: 0.407414
# [40]	training's binary_logloss: 0.330687	valid_0's binary_logloss: 0.406769
# [41]	training's binary_logloss: 0.328493	valid_0's binary_logloss: 0.405721
# [42]	training's binary_logloss: 0.326497	valid_0's binary_logloss: 0.4053
# [43]	training's binary_logloss: 0.324743	valid_0's binary_logloss: 0.405007
# [44]	training's binary_logloss: 0.323099	valid_0's binary_logloss: 0.404412
# [45]	training's binary_logloss: 0.321434	valid_0's binary_logloss: 0.404126
# [46]	training's binary_logloss: 0.319765	valid_0's binary_logloss: 0.403814
# [47]	training's binary_logloss: 0.318104	valid_0's binary_logloss: 0.403567
# [48]	training's binary_logloss: 0.31661	valid_0's binary_logloss: 0.403248
# [49]	training's binary_logloss: 0.314869	valid_0's binary_logloss: 0.402609
# [50]	training's binary_logloss: 0.31281	valid_0's binary_logloss: 0.401843
# [51]	training's binary_logloss: 0.311171	valid_0's binary_logloss: 0.401448
# [52]	training's binary_logloss: 0.309856	valid_0's binary_logloss: 0.401388
# [53]	training's binary_logloss: 0.308281	valid_0's binary_logloss: 0.401149
# [54]	training's binary_logloss: 0.306871	valid_0's binary_logloss: 0.401244
# [55]	training's binary_logloss: 0.305187	valid_0's binary_logloss: 0.401229
# [56]	training's binary_logloss: 0.303675	valid_0's binary_logloss: 0.401751
# [57]	training's binary_logloss: 0.30219	valid_0's binary_logloss: 0.401426
# [58]	training's binary_logloss: 0.300984	valid_0's binary_logloss: 0.40127
# [59]	training's binary_logloss: 0.299643	valid_0's binary_logloss: 0.400989
# [60]	training's binary_logloss: 0.298168	valid_0's binary_logloss: 0.400976
# [61]	training's binary_logloss: 0.29706	valid_0's binary_logloss: 0.400919
# [62]	training's binary_logloss: 0.295604	valid_0's binary_logloss: 0.401224
# [63]	training's binary_logloss: 0.294302	valid_0's binary_logloss: 0.401071
# [64]	training's binary_logloss: 0.293089	valid_0's binary_logloss: 0.40116
# [65]	training's binary_logloss: 0.291997	valid_0's binary_logloss: 0.400603
# [66]	training's binary_logloss: 0.290727	valid_0's binary_logloss: 0.400307
# [67]	training's binary_logloss: 0.289604	valid_0's binary_logloss: 0.400531
# [68]	training's binary_logloss: 0.288622	valid_0's binary_logloss: 0.400316
# [69]	training's binary_logloss: 0.287242	valid_0's binary_logloss: 0.400229
# [70]	training's binary_logloss: 0.286253	valid_0's binary_logloss: 0.399947
# [71]	training's binary_logloss: 0.285115	valid_0's binary_logloss: 0.400114
# [72]	training's binary_logloss: 0.28403	valid_0's binary_logloss: 0.399967
# [73]	training's binary_logloss: 0.28304	valid_0's binary_logloss: 0.39977
# [74]	training's binary_logloss: 0.281944	valid_0's binary_logloss: 0.400012
# [75]	training's binary_logloss: 0.280945	valid_0's binary_logloss: 0.400275
# [76]	training's binary_logloss: 0.279797	valid_0's binary_logloss: 0.399752
# [77]	training's binary_logloss: 0.278954	valid_0's binary_logloss: 0.3997
# [78]	training's binary_logloss: 0.277595	valid_0's binary_logloss: 0.399751
# [79]	training's binary_logloss: 0.276602	valid_0's binary_logloss: 0.399452
# [80]	training's binary_logloss: 0.275636	valid_0's binary_logloss: 0.399056
# [81]	training's binary_logloss: 0.27464	valid_0's binary_logloss: 0.399026
# [82]	training's binary_logloss: 0.273429	valid_0's binary_logloss: 0.398818
# [83]	training's binary_logloss: 0.272531	valid_0's binary_logloss: 0.398412
# [84]	training's binary_logloss: 0.271703	valid_0's binary_logloss: 0.398418
# [85]	training's binary_logloss: 0.270843	valid_0's binary_logloss: 0.398504
# [86]	training's binary_logloss: 0.269903	valid_0's binary_logloss: 0.398191
# [87]	training's binary_logloss: 0.269079	valid_0's binary_logloss: 0.398345
# [88]	training's binary_logloss: 0.268034	valid_0's binary_logloss: 0.397972
# [89]	training's binary_logloss: 0.267216	valid_0's binary_logloss: 0.397848
# [90]	training's binary_logloss: 0.266038	valid_0's binary_logloss: 0.398125
# [91]	training's binary_logloss: 0.264791	valid_0's binary_logloss: 0.398071
# [92]	training's binary_logloss: 0.263799	valid_0's binary_logloss: 0.398177
# [93]	training's binary_logloss: 0.262632	valid_0's binary_logloss: 0.398069
# [94]	training's binary_logloss: 0.261481	valid_0's binary_logloss: 0.39817
# [95]	training's binary_logloss: 0.260285	valid_0's binary_logloss: 0.398274
# [96]	training's binary_logloss: 0.259336	valid_0's binary_logloss: 0.398588
# [97]	training's binary_logloss: 0.258562	valid_0's binary_logloss: 0.398693
# [98]	training's binary_logloss: 0.257495	valid_0's binary_logloss: 0.398969
# [99]	training's binary_logloss: 0.256647	valid_0's binary_logloss: 0.39869
# [100]	training's binary_logloss: 0.255719	valid_0's binary_logloss: 0.398823
# [1]	training's binary_logloss: 0.634341	valid_0's binary_logloss: 0.634752
# [2]	training's binary_logloss: 0.604361	valid_0's binary_logloss: 0.605619
# [3]	training's binary_logloss: 0.578511	valid_0's binary_logloss: 0.581162
# [4]	training's binary_logloss: 0.556301	valid_0's binary_logloss: 0.560171
# [5]	training's binary_logloss: 0.53635	valid_0's binary_logloss: 0.542105
# [6]	training's binary_logloss: 0.519481	valid_0's binary_logloss: 0.526409
# [7]	training's binary_logloss: 0.504631	valid_0's binary_logloss: 0.512942
# [8]	training's binary_logloss: 0.49035	valid_0's binary_logloss: 0.499837
# [9]	training's binary_logloss: 0.477829	valid_0's binary_logloss: 0.489185
# [10]	training's binary_logloss: 0.466137	valid_0's binary_logloss: 0.479327
# [11]	training's binary_logloss: 0.455808	valid_0's binary_logloss: 0.470443
# [12]	training's binary_logloss: 0.446531	valid_0's binary_logloss: 0.462052
# [13]	training's binary_logloss: 0.438102	valid_0's binary_logloss: 0.455567
# [14]	training's binary_logloss: 0.430699	valid_0's binary_logloss: 0.449417
# [15]	training's binary_logloss: 0.423656	valid_0's binary_logloss: 0.443534
# [16]	training's binary_logloss: 0.417175	valid_0's binary_logloss: 0.438483
# [17]	training's binary_logloss: 0.410845	valid_0's binary_logloss: 0.433941
# [18]	training's binary_logloss: 0.405308	valid_0's binary_logloss: 0.43011
# [19]	training's binary_logloss: 0.399817	valid_0's binary_logloss: 0.425534
# [20]	training's binary_logloss: 0.394946	valid_0's binary_logloss: 0.421783
# [21]	training's binary_logloss: 0.390369	valid_0's binary_logloss: 0.418549
# [22]	training's binary_logloss: 0.386258	valid_0's binary_logloss: 0.416412
# [23]	training's binary_logloss: 0.382464	valid_0's binary_logloss: 0.413836
# [24]	training's binary_logloss: 0.378704	valid_0's binary_logloss: 0.411571
# [25]	training's binary_logloss: 0.375354	valid_0's binary_logloss: 0.409765
# [26]	training's binary_logloss: 0.372019	valid_0's binary_logloss: 0.408193
# [27]	training's binary_logloss: 0.368877	valid_0's binary_logloss: 0.406279
# [28]	training's binary_logloss: 0.365957	valid_0's binary_logloss: 0.404319
# [29]	training's binary_logloss: 0.362453	valid_0's binary_logloss: 0.402165
# [30]	training's binary_logloss: 0.359752	valid_0's binary_logloss: 0.401342
# [31]	training's binary_logloss: 0.356812	valid_0's binary_logloss: 0.400029
# [32]	training's binary_logloss: 0.354497	valid_0's binary_logloss: 0.398918
# [33]	training's binary_logloss: 0.352238	valid_0's binary_logloss: 0.398021
# [34]	training's binary_logloss: 0.349511	valid_0's binary_logloss: 0.397164
# [35]	training's binary_logloss: 0.347199	valid_0's binary_logloss: 0.396109
# [36]	training's binary_logloss: 0.344878	valid_0's binary_logloss: 0.394669
# [37]	training's binary_logloss: 0.342743	valid_0's binary_logloss: 0.393869
# [38]	training's binary_logloss: 0.340359	valid_0's binary_logloss: 0.392698
# [39]	training's binary_logloss: 0.338078	valid_0's binary_logloss: 0.39135
# [40]	training's binary_logloss: 0.336199	valid_0's binary_logloss: 0.390393
# [41]	training's binary_logloss: 0.33408	valid_0's binary_logloss: 0.389225
# [42]	training's binary_logloss: 0.332339	valid_0's binary_logloss: 0.388505
# [43]	training's binary_logloss: 0.330517	valid_0's binary_logloss: 0.387991
# [44]	training's binary_logloss: 0.3287	valid_0's binary_logloss: 0.387787
# [45]	training's binary_logloss: 0.326739	valid_0's binary_logloss: 0.387204
# [46]	training's binary_logloss: 0.32499	valid_0's binary_logloss: 0.386833
# [47]	training's binary_logloss: 0.323381	valid_0's binary_logloss: 0.386919
# [48]	training's binary_logloss: 0.321588	valid_0's binary_logloss: 0.386374
# [49]	training's binary_logloss: 0.320111	valid_0's binary_logloss: 0.386047
# [50]	training's binary_logloss: 0.318372	valid_0's binary_logloss: 0.385737
# [51]	training's binary_logloss: 0.316959	valid_0's binary_logloss: 0.385667
# [52]	training's binary_logloss: 0.315504	valid_0's binary_logloss: 0.385565
# [53]	training's binary_logloss: 0.313942	valid_0's binary_logloss: 0.385279
# [54]	training's binary_logloss: 0.312342	valid_0's binary_logloss: 0.384891
# [55]	training's binary_logloss: 0.310894	valid_0's binary_logloss: 0.384819
# [56]	training's binary_logloss: 0.309542	valid_0's binary_logloss: 0.384824
# [57]	training's binary_logloss: 0.308159	valid_0's binary_logloss: 0.384828
# [58]	training's binary_logloss: 0.306779	valid_0's binary_logloss: 0.384426
# [59]	training's binary_logloss: 0.305552	valid_0's binary_logloss: 0.384298
# [60]	training's binary_logloss: 0.304376	valid_0's binary_logloss: 0.384529
# [61]	training's binary_logloss: 0.303013	valid_0's binary_logloss: 0.384263
# [62]	training's binary_logloss: 0.301656	valid_0's binary_logloss: 0.384112
# [63]	training's binary_logloss: 0.300482	valid_0's binary_logloss: 0.384088
# [64]	training's binary_logloss: 0.299328	valid_0's binary_logloss: 0.384001
# [65]	training's binary_logloss: 0.297984	valid_0's binary_logloss: 0.384288
# [66]	training's binary_logloss: 0.2964	valid_0's binary_logloss: 0.383434
# [67]	training's binary_logloss: 0.29529	valid_0's binary_logloss: 0.38304
# [68]	training's binary_logloss: 0.294167	valid_0's binary_logloss: 0.383001
# [69]	training's binary_logloss: 0.292685	valid_0's binary_logloss: 0.382892
# [70]	training's binary_logloss: 0.291541	valid_0's binary_logloss: 0.382641
# [71]	training's binary_logloss: 0.289975	valid_0's binary_logloss: 0.382544
# [72]	training's binary_logloss: 0.288862	valid_0's binary_logloss: 0.38264
# [73]	training's binary_logloss: 0.287874	valid_0's binary_logloss: 0.382581
# [74]	training's binary_logloss: 0.286398	valid_0's binary_logloss: 0.382254
# [75]	training's binary_logloss: 0.285149	valid_0's binary_logloss: 0.381959
# [76]	training's binary_logloss: 0.28418	valid_0's binary_logloss: 0.38192
# [77]	training's binary_logloss: 0.282783	valid_0's binary_logloss: 0.38222
# [78]	training's binary_logloss: 0.281572	valid_0's binary_logloss: 0.382097
# [79]	training's binary_logloss: 0.280509	valid_0's binary_logloss: 0.382049
# [80]	training's binary_logloss: 0.279714	valid_0's binary_logloss: 0.382139
# [81]	training's binary_logloss: 0.278712	valid_0's binary_logloss: 0.381994
# [82]	training's binary_logloss: 0.277213	valid_0's binary_logloss: 0.381697
# [83]	training's binary_logloss: 0.276159	valid_0's binary_logloss: 0.381356
# [84]	training's binary_logloss: 0.275018	valid_0's binary_logloss: 0.381577
# [85]	training's binary_logloss: 0.273977	valid_0's binary_logloss: 0.381454
# [86]	training's binary_logloss: 0.272628	valid_0's binary_logloss: 0.38162
# [87]	training's binary_logloss: 0.271327	valid_0's binary_logloss: 0.381465
# [88]	training's binary_logloss: 0.270664	valid_0's binary_logloss: 0.38117
# [89]	training's binary_logloss: 0.269714	valid_0's binary_logloss: 0.3816
# [90]	training's binary_logloss: 0.268514	valid_0's binary_logloss: 0.381155
# [91]	training's binary_logloss: 0.267673	valid_0's binary_logloss: 0.381325
# [92]	training's binary_logloss: 0.266753	valid_0's binary_logloss: 0.381338
# [93]	training's binary_logloss: 0.265758	valid_0's binary_logloss: 0.381204
# [94]	training's binary_logloss: 0.264605	valid_0's binary_logloss: 0.381235
# [95]	training's binary_logloss: 0.263676	valid_0's binary_logloss: 0.381608
# [96]	training's binary_logloss: 0.262831	valid_0's binary_logloss: 0.381606
# [97]	training's binary_logloss: 0.261992	valid_0's binary_logloss: 0.381859
# [98]	training's binary_logloss: 0.261317	valid_0's binary_logloss: 0.381743
# [99]	training's binary_logloss: 0.26002	valid_0's binary_logloss: 0.381861
# [100]	training's binary_logloss: 0.25936	valid_0's binary_logloss: 0.381448
# [1]	training's binary_logloss: 0.634617	valid_0's binary_logloss: 0.635349
# [2]	training's binary_logloss: 0.604108	valid_0's binary_logloss: 0.606693
# [3]	training's binary_logloss: 0.577847	valid_0's binary_logloss: 0.582429
# [4]	training's binary_logloss: 0.555185	valid_0's binary_logloss: 0.561295
# [5]	training's binary_logloss: 0.535478	valid_0's binary_logloss: 0.542381
# [6]	training's binary_logloss: 0.518166	valid_0's binary_logloss: 0.526946
# [7]	training's binary_logloss: 0.502566	valid_0's binary_logloss: 0.513011
# [8]	training's binary_logloss: 0.488665	valid_0's binary_logloss: 0.500907
# [9]	training's binary_logloss: 0.476415	valid_0's binary_logloss: 0.490577
# [10]	training's binary_logloss: 0.464874	valid_0's binary_logloss: 0.480945
# [11]	training's binary_logloss: 0.454664	valid_0's binary_logloss: 0.47219
# [12]	training's binary_logloss: 0.445453	valid_0's binary_logloss: 0.464548
# [13]	training's binary_logloss: 0.436904	valid_0's binary_logloss: 0.457586
# [14]	training's binary_logloss: 0.429186	valid_0's binary_logloss: 0.451341
# [15]	training's binary_logloss: 0.422174	valid_0's binary_logloss: 0.445286
# [16]	training's binary_logloss: 0.415909	valid_0's binary_logloss: 0.440719
# [17]	training's binary_logloss: 0.410182	valid_0's binary_logloss: 0.436701
# [18]	training's binary_logloss: 0.404655	valid_0's binary_logloss: 0.432473
# [19]	training's binary_logloss: 0.399656	valid_0's binary_logloss: 0.428732
# [20]	training's binary_logloss: 0.394543	valid_0's binary_logloss: 0.42504
# [21]	training's binary_logloss: 0.390351	valid_0's binary_logloss: 0.421548
# [22]	training's binary_logloss: 0.385958	valid_0's binary_logloss: 0.418104
# [23]	training's binary_logloss: 0.382069	valid_0's binary_logloss: 0.415397
# [24]	training's binary_logloss: 0.378219	valid_0's binary_logloss: 0.412048
# [25]	training's binary_logloss: 0.374609	valid_0's binary_logloss: 0.409659
# [26]	training's binary_logloss: 0.371267	valid_0's binary_logloss: 0.40684
# [27]	training's binary_logloss: 0.368067	valid_0's binary_logloss: 0.40438
# [28]	training's binary_logloss: 0.365086	valid_0's binary_logloss: 0.402736
# [29]	training's binary_logloss: 0.362199	valid_0's binary_logloss: 0.40136
# [30]	training's binary_logloss: 0.359093	valid_0's binary_logloss: 0.399499
# [31]	training's binary_logloss: 0.356109	valid_0's binary_logloss: 0.397629
# [32]	training's binary_logloss: 0.35344	valid_0's binary_logloss: 0.396443
# [33]	training's binary_logloss: 0.350893	valid_0's binary_logloss: 0.395201
# [34]	training's binary_logloss: 0.348569	valid_0's binary_logloss: 0.393863
# [35]	training's binary_logloss: 0.346273	valid_0's binary_logloss: 0.392616
# [36]	training's binary_logloss: 0.343853	valid_0's binary_logloss: 0.391812
# [37]	training's binary_logloss: 0.341586	valid_0's binary_logloss: 0.391117
# [38]	training's binary_logloss: 0.339481	valid_0's binary_logloss: 0.390443
# [39]	training's binary_logloss: 0.337621	valid_0's binary_logloss: 0.390199
# [40]	training's binary_logloss: 0.335756	valid_0's binary_logloss: 0.389887
# [41]	training's binary_logloss: 0.333755	valid_0's binary_logloss: 0.389183
# [42]	training's binary_logloss: 0.331859	valid_0's binary_logloss: 0.388225
# [43]	training's binary_logloss: 0.330073	valid_0's binary_logloss: 0.387711
# [44]	training's binary_logloss: 0.328424	valid_0's binary_logloss: 0.38736
# [45]	training's binary_logloss: 0.326625	valid_0's binary_logloss: 0.386617
# [46]	training's binary_logloss: 0.324708	valid_0's binary_logloss: 0.385468
# [47]	training's binary_logloss: 0.32325	valid_0's binary_logloss: 0.385139
# [48]	training's binary_logloss: 0.321711	valid_0's binary_logloss: 0.385192
# [49]	training's binary_logloss: 0.320326	valid_0's binary_logloss: 0.385041
# [50]	training's binary_logloss: 0.318637	valid_0's binary_logloss: 0.38528
# [51]	training's binary_logloss: 0.317279	valid_0's binary_logloss: 0.384599
# [52]	training's binary_logloss: 0.315462	valid_0's binary_logloss: 0.384003
# [53]	training's binary_logloss: 0.313953	valid_0's binary_logloss: 0.383899
# [54]	training's binary_logloss: 0.312627	valid_0's binary_logloss: 0.383685
# [55]	training's binary_logloss: 0.311156	valid_0's binary_logloss: 0.383199
# [56]	training's binary_logloss: 0.309644	valid_0's binary_logloss: 0.383152
# [57]	training's binary_logloss: 0.308373	valid_0's binary_logloss: 0.382803
# [58]	training's binary_logloss: 0.306736	valid_0's binary_logloss: 0.382676
# [59]	training's binary_logloss: 0.305675	valid_0's binary_logloss: 0.382768
# [60]	training's binary_logloss: 0.304166	valid_0's binary_logloss: 0.38256
# [61]	training's binary_logloss: 0.303072	valid_0's binary_logloss: 0.382592
# [62]	training's binary_logloss: 0.301881	valid_0's binary_logloss: 0.3824
# [63]	training's binary_logloss: 0.300792	valid_0's binary_logloss: 0.382165
# [64]	training's binary_logloss: 0.29958	valid_0's binary_logloss: 0.382047
# [65]	training's binary_logloss: 0.298395	valid_0's binary_logloss: 0.381741
# [66]	training's binary_logloss: 0.296921	valid_0's binary_logloss: 0.381593
# [67]	training's binary_logloss: 0.29583	valid_0's binary_logloss: 0.381469
# [68]	training's binary_logloss: 0.294673	valid_0's binary_logloss: 0.381114
# [69]	training's binary_logloss: 0.293341	valid_0's binary_logloss: 0.380702
# [70]	training's binary_logloss: 0.292171	valid_0's binary_logloss: 0.38042
# [71]	training's binary_logloss: 0.290879	valid_0's binary_logloss: 0.380525
# [72]	training's binary_logloss: 0.289349	valid_0's binary_logloss: 0.380286
# [73]	training's binary_logloss: 0.287971	valid_0's binary_logloss: 0.379769
# [74]	training's binary_logloss: 0.286918	valid_0's binary_logloss: 0.37988
# [75]	training's binary_logloss: 0.285804	valid_0's binary_logloss: 0.379504
# [76]	training's binary_logloss: 0.284647	valid_0's binary_logloss: 0.379297
# [77]	training's binary_logloss: 0.283726	valid_0's binary_logloss: 0.379459
# [78]	training's binary_logloss: 0.28273	valid_0's binary_logloss: 0.379334
# [79]	training's binary_logloss: 0.281281	valid_0's binary_logloss: 0.378981
# [80]	training's binary_logloss: 0.28038	valid_0's binary_logloss: 0.379007
# [81]	training's binary_logloss: 0.27901	valid_0's binary_logloss: 0.37892
# [82]	training's binary_logloss: 0.278026	valid_0's binary_logloss: 0.378737
# [83]	training's binary_logloss: 0.277165	valid_0's binary_logloss: 0.378668
# [84]	training's binary_logloss: 0.275784	valid_0's binary_logloss: 0.378635
# [85]	training's binary_logloss: 0.274966	valid_0's binary_logloss: 0.378522
# [86]	training's binary_logloss: 0.274022	valid_0's binary_logloss: 0.378322
# [87]	training's binary_logloss: 0.273295	valid_0's binary_logloss: 0.378084
# [88]	training's binary_logloss: 0.272075	valid_0's binary_logloss: 0.377931
# [89]	training's binary_logloss: 0.270777	valid_0's binary_logloss: 0.378093
# [90]	training's binary_logloss: 0.269611	valid_0's binary_logloss: 0.377852
# [91]	training's binary_logloss: 0.268448	valid_0's binary_logloss: 0.377952
# [92]	training's binary_logloss: 0.267493	valid_0's binary_logloss: 0.37812
# [93]	training's binary_logloss: 0.26665	valid_0's binary_logloss: 0.378453
# [94]	training's binary_logloss: 0.265392	valid_0's binary_logloss: 0.378475
# [95]	training's binary_logloss: 0.264508	valid_0's binary_logloss: 0.378649
# [96]	training's binary_logloss: 0.263427	valid_0's binary_logloss: 0.378475
# [97]	training's binary_logloss: 0.262629	valid_0's binary_logloss: 0.378587
# [98]	training's binary_logloss: 0.261728	valid_0's binary_logloss: 0.378318
# [99]	training's binary_logloss: 0.260823	valid_0's binary_logloss: 0.378002
# [100]	training's binary_logloss: 0.260062	valid_0's binary_logloss: 0.378457
# [1]	training's binary_logloss: 0.634381	valid_0's binary_logloss: 0.635028
# [2]	training's binary_logloss: 0.60408	valid_0's binary_logloss: 0.607737
# [3]	training's binary_logloss: 0.577277	valid_0's binary_logloss: 0.584021
# [4]	training's binary_logloss: 0.553903	valid_0's binary_logloss: 0.563349
# [5]	training's binary_logloss: 0.534185	valid_0's binary_logloss: 0.546759
# [6]	training's binary_logloss: 0.516722	valid_0's binary_logloss: 0.532717
# [7]	training's binary_logloss: 0.501133	valid_0's binary_logloss: 0.519716
# [8]	training's binary_logloss: 0.487127	valid_0's binary_logloss: 0.507791
# [9]	training's binary_logloss: 0.474465	valid_0's binary_logloss: 0.49767
# [10]	training's binary_logloss: 0.463295	valid_0's binary_logloss: 0.488485
# [11]	training's binary_logloss: 0.453476	valid_0's binary_logloss: 0.481431
# [12]	training's binary_logloss: 0.44406	valid_0's binary_logloss: 0.473972
# [13]	training's binary_logloss: 0.435246	valid_0's binary_logloss: 0.467322
# [14]	training's binary_logloss: 0.427655	valid_0's binary_logloss: 0.461189
# [15]	training's binary_logloss: 0.420115	valid_0's binary_logloss: 0.455851
# [16]	training's binary_logloss: 0.413749	valid_0's binary_logloss: 0.451596
# [17]	training's binary_logloss: 0.407418	valid_0's binary_logloss: 0.447265
# [18]	training's binary_logloss: 0.401528	valid_0's binary_logloss: 0.443499
# [19]	training's binary_logloss: 0.395866	valid_0's binary_logloss: 0.440296
# [20]	training's binary_logloss: 0.390649	valid_0's binary_logloss: 0.437018
# [21]	training's binary_logloss: 0.385934	valid_0's binary_logloss: 0.434118
# [22]	training's binary_logloss: 0.381774	valid_0's binary_logloss: 0.431269
# [23]	training's binary_logloss: 0.377527	valid_0's binary_logloss: 0.428796
# [24]	training's binary_logloss: 0.373461	valid_0's binary_logloss: 0.426757
# [25]	training's binary_logloss: 0.369654	valid_0's binary_logloss: 0.424818
# [26]	training's binary_logloss: 0.366219	valid_0's binary_logloss: 0.422927
# [27]	training's binary_logloss: 0.362888	valid_0's binary_logloss: 0.421472
# [28]	training's binary_logloss: 0.359919	valid_0's binary_logloss: 0.419711
# [29]	training's binary_logloss: 0.356328	valid_0's binary_logloss: 0.418181
# [30]	training's binary_logloss: 0.353025	valid_0's binary_logloss: 0.417161
# [31]	training's binary_logloss: 0.350236	valid_0's binary_logloss: 0.416
# [32]	training's binary_logloss: 0.347581	valid_0's binary_logloss: 0.414655
# [33]	training's binary_logloss: 0.344772	valid_0's binary_logloss: 0.414014
# [34]	training's binary_logloss: 0.342264	valid_0's binary_logloss: 0.413205
# [35]	training's binary_logloss: 0.339738	valid_0's binary_logloss: 0.412234
# [36]	training's binary_logloss: 0.337455	valid_0's binary_logloss: 0.411332
# [37]	training's binary_logloss: 0.335499	valid_0's binary_logloss: 0.410945
# [38]	training's binary_logloss: 0.333231	valid_0's binary_logloss: 0.41051
# [39]	training's binary_logloss: 0.331168	valid_0's binary_logloss: 0.409927
# [40]	training's binary_logloss: 0.329212	valid_0's binary_logloss: 0.409574
# [41]	training's binary_logloss: 0.327543	valid_0's binary_logloss: 0.409301
# [42]	training's binary_logloss: 0.325785	valid_0's binary_logloss: 0.409063
# [43]	training's binary_logloss: 0.323998	valid_0's binary_logloss: 0.408468
# [44]	training's binary_logloss: 0.322228	valid_0's binary_logloss: 0.408198
# [45]	training's binary_logloss: 0.320468	valid_0's binary_logloss: 0.407848
# [46]	training's binary_logloss: 0.31864	valid_0's binary_logloss: 0.407131
# [47]	training's binary_logloss: 0.317018	valid_0's binary_logloss: 0.40683
# [48]	training's binary_logloss: 0.31551	valid_0's binary_logloss: 0.406685
# [49]	training's binary_logloss: 0.313958	valid_0's binary_logloss: 0.406736
# [50]	training's binary_logloss: 0.312019	valid_0's binary_logloss: 0.406284
# [51]	training's binary_logloss: 0.310471	valid_0's binary_logloss: 0.406324
# [52]	training's binary_logloss: 0.308918	valid_0's binary_logloss: 0.40633
# [53]	training's binary_logloss: 0.307251	valid_0's binary_logloss: 0.406129
# [54]	training's binary_logloss: 0.305722	valid_0's binary_logloss: 0.406078
# [55]	training's binary_logloss: 0.304002	valid_0's binary_logloss: 0.406229
# [56]	training's binary_logloss: 0.30265	valid_0's binary_logloss: 0.405805
# [57]	training's binary_logloss: 0.301353	valid_0's binary_logloss: 0.405544
# [58]	training's binary_logloss: 0.299925	valid_0's binary_logloss: 0.405656
# [59]	training's binary_logloss: 0.298459	valid_0's binary_logloss: 0.40593
# [60]	training's binary_logloss: 0.296986	valid_0's binary_logloss: 0.406013
# [61]	training's binary_logloss: 0.295911	valid_0's binary_logloss: 0.40586
# [62]	training's binary_logloss: 0.294254	valid_0's binary_logloss: 0.406398
# [63]	training's binary_logloss: 0.29321	valid_0's binary_logloss: 0.406292
# [64]	training's binary_logloss: 0.291812	valid_0's binary_logloss: 0.406697
# [65]	training's binary_logloss: 0.29029	valid_0's binary_logloss: 0.406895
# [66]	training's binary_logloss: 0.289026	valid_0's binary_logloss: 0.407197
# [67]	training's binary_logloss: 0.28779	valid_0's binary_logloss: 0.407312
# [68]	training's binary_logloss: 0.286558	valid_0's binary_logloss: 0.407376
# [69]	training's binary_logloss: 0.285209	valid_0's binary_logloss: 0.407252
# [70]	training's binary_logloss: 0.283673	valid_0's binary_logloss: 0.407126
# [71]	training's binary_logloss: 0.282625	valid_0's binary_logloss: 0.407289
# [72]	training's binary_logloss: 0.281355	valid_0's binary_logloss: 0.407195
# [73]	training's binary_logloss: 0.280032	valid_0's binary_logloss: 0.406979
# [74]	training's binary_logloss: 0.278923	valid_0's binary_logloss: 0.407223
# [75]	training's binary_logloss: 0.277593	valid_0's binary_logloss: 0.40666
# [76]	training's binary_logloss: 0.276626	valid_0's binary_logloss: 0.407061
# [77]	training's binary_logloss: 0.275566	valid_0's binary_logloss: 0.407244
# [78]	training's binary_logloss: 0.274189	valid_0's binary_logloss: 0.407692
# [79]	training's binary_logloss: 0.273101	valid_0's binary_logloss: 0.407749
# [80]	training's binary_logloss: 0.271869	valid_0's binary_logloss: 0.407898
# [81]	training's binary_logloss: 0.27093	valid_0's binary_logloss: 0.408045
# [82]	training's binary_logloss: 0.269852	valid_0's binary_logloss: 0.408136
# [83]	training's binary_logloss: 0.268851	valid_0's binary_logloss: 0.408104
# [84]	training's binary_logloss: 0.267698	valid_0's binary_logloss: 0.40844
# [85]	training's binary_logloss: 0.266872	valid_0's binary_logloss: 0.408437
# [86]	training's binary_logloss: 0.265781	valid_0's binary_logloss: 0.40841
# [87]	training's binary_logloss: 0.264692	valid_0's binary_logloss: 0.408226
# [88]	training's binary_logloss: 0.263297	valid_0's binary_logloss: 0.408813
# [89]	training's binary_logloss: 0.262373	valid_0's binary_logloss: 0.408951
# [90]	training's binary_logloss: 0.261249	valid_0's binary_logloss: 0.409174
# [91]	training's binary_logloss: 0.26031	valid_0's binary_logloss: 0.409056
# [92]	training's binary_logloss: 0.259356	valid_0's binary_logloss: 0.408931
# [93]	training's binary_logloss: 0.25824	valid_0's binary_logloss: 0.409085
# [94]	training's binary_logloss: 0.257298	valid_0's binary_logloss: 0.409173
# [95]	training's binary_logloss: 0.256267	valid_0's binary_logloss: 0.409141
# [96]	training's binary_logloss: 0.255108	valid_0's binary_logloss: 0.409298
# [97]	training's binary_logloss: 0.254317	valid_0's binary_logloss: 0.409472
# [98]	training's binary_logloss: 0.253429	valid_0's binary_logloss: 0.409779
# [99]	training's binary_logloss: 0.252218	valid_0's binary_logloss: 0.409874
# [100]	training's binary_logloss: 0.250764	valid_0's binary_logloss: 0.409679
# ---Run time is 1.6016511000007085 seconds ---
#
# Accuracy of each fold:
#  [0.8152804642166345, 0.7934204160619255, 0.8209966134494436, 0.8190614417029511, 0.7987421383647799]
#
# Avg accuracy :
# 0.8095002147591469
#
# Std of accuracy :
# 0.011236473300445917
